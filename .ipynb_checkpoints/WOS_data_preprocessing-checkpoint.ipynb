# %% [markdown]
# # WosClient

# %%
# !pip install suds-jurko

from suds import client
from base64 import b64encode as _b64encode
from collections import OrderedDict as _OrderedDict

class WosClient():
    """Query the Web of Science.
       You must provide user and password only to user premium WWS service.
       with WosClient() as wos:
           results = wos.search(...)"""

    base_url = 'http://search.webofknowledge.com'
    auth_url = base_url + '/esti/wokmws/ws/WOKMWSAuthenticate?wsdl'
    search_url = base_url + '/esti/wokmws/ws/WokSearch?wsdl'
    searchlite_url = base_url + '/esti/wokmws/ws/WokSearchLite?wsdl'

    def __init__(self, user=None, password=None, SID=None, close_on_exit=True,
                 lite=False):
        """Create the SOAP clients. user and password for premium access."""

        self._SID = SID
        self._close_on_exit = close_on_exit
        search_wsdl = self.searchlite_url if lite else self.search_url
        self._auth = client.Client(self.auth_url)
        self._search = client.Client(search_wsdl)

        if user and password:
            auth = '%s:%s' % (user, password)
            auth = _b64encode(auth.encode('utf-8')).decode('utf-8')
            headers = {'Authorization': ('Basic %s' % auth).strip()}
            self._auth.set_options(headers=headers)

    def __enter__(self):
        """Automatically connect when used with 'with' statements."""
        self.connect()
        return self

    def __exit__(self, exc_type, exc_value, traceback):
        """Close connection after closing the 'with' statement."""
        if self._close_on_exit:
            self.close()

    def __del__(self):
        """Close connection when deleting the object."""
        if self._close_on_exit:
            self.close()

    def connect(self):
        """Authenticate to WOS and set the SID cookie."""
        if not self._SID:
            self._SID = self._auth.service.authenticate()
            print('Authenticated (SID: %s)' % self._SID)

        self._search.set_options(headers={'Cookie': 'SID="%s"' % self._SID})
        self._auth.options.headers.update({'Cookie': 'SID="%s"' % self._SID})
        return self._SID

    def close(self):
        """Close the session."""
        if self._SID:
            self._auth.service.closeSession()
            self._SID = None

    def search(self, query, count=5, offset=1):
    # def search(self, query, offset=1):
        """Perform a query. Check the WOS documentation for v3 syntax."""
        if not self._SID:
            raise RuntimeError('Session not open. Invoke .connect() before.')

        qparams = _OrderedDict([('databaseId', 'WOS'),
                                ('userQuery', query),
                                ('queryLanguage', 'en')])

        rparams = _OrderedDict([('firstRecord', offset),
                                ('count', count),
                                ('sortField', _OrderedDict([('name', 'RS'),
                                                            ('sort', 'D')]))])

        return self._search.service.search(qparams, rparams)

# %%
from xml.etree import ElementTree as _ET
from xml.dom import minidom as _minidom
import re as _re

def single(wosclient, wos_query, xml_query=None, count=10, offset=1):
    """Perform a single Web of Science query and then XML query the results."""
    result = wosclient.search(wos_query, count, offset)
    print (result)
    xml = _re.sub(' xmlns="[^"]+"', '', result.records, count=1).encode('utf-8')
    if xml_query:
        xml = _ET.fromstring(xml)
        return [el.text for el in xml.findall(xml_query)]
    else:
        return _minidom.parseString(xml).toprettyxml()

def query(wosclient, wos_query, xml_query=None, count=10, offset=1, limit=100):
    """Query Web of Science and XML query results with multiple requests."""
    results = [single(wosclient, wos_query, xml_query, min(limit, count-x+1), x) for x in range(offset, count+1, limit)]
    if xml_query:
        return [el for res in results for el in res]
    else:
        pattern = _re.compile(r'.*?<records>|</records>.*', _re.DOTALL)
        return ('<?xml version="1.0" ?>\n<records>' +
                '\n'.join(pattern.sub('', res) for res in results) +
                '</records>')

def doi_to_wos(wosclient, doi):
    """Convert DOI to WOS identifier."""
    results = query(wosclient, 'DO=%s' % doi, './REC/UID', count=1)
    return results[0].lstrip('WOS:') if results else None

# %%
soap = WosClient(lite=True)
soap.connect()
# Out:
# Authenticated (SID: C3Zd58MausSMSX4Afox)
# C3Zd58MausSMSX4Afox

# %% [markdown]
# # Exchange the Given and Family Name

# %%
searchnames = []
i=0
for line in open('Dismis_Acad_List_CLEAN.txt','r'):
    QueryString = line.strip()
    QueryString = "AU="+line.split(',')[0].split()[-1]+' '+line.split(',')[0].split()[0]
    print('QueryString:', QueryString)
    searchnames.append(QueryString)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-1355da3a3136> in <module>()
#       1 searchnames = []
#       2 i=0
# ----> 3 for line in open('Dismis_Acad_List_CLEAN.txt','r'):
#       4     QueryString = line.strip()
#       5     QueryString = "AU="+line.split(',')[0].split()[-1]+' '+line.split(',')[0].split()[0]
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Dismis_Acad_List_CLEAN.txt'

# %%
len(searchnames)
# Out:
# 3575

# %%
import pandas as pd

# %%
pd.DataFrame(searchnames,columns=['SearchNames']).to_csv('SearchNames.csv')

# %%
SearchNames = pd.read_csv('SearchNames.csv')

# %%
SearchNames.SearchNames[0].strip().split('=')[1]
# Out:
# 'AYDIN AYDIN'

# %%
names = []
lens = []
i=0
for i in range(len(SearchNames)):
    line = SearchNames.SearchNames[i]
    QueryString = line.strip()
    print(QueryString)
    if i == 2400:
        soap = WosClient(lite=True)
        soap.connect()
    results = soap.search(QueryString)
    print(results.recordsFound)
    names.append(QueryString.split('=')[1])
    lens.append(results.recordsFound)
    time.sleep(0.5)
    i=i+1
# Out:
# AU=AYDIN AYDIN
# 4
# AU=GILGIL ERDAL
# 5
# AU=HALAC METIN
# 63
# AU=YUCE ABDULHAKIM
# 0
# AU=KIRIS ABDULKADIR
# 54
# AU=KUCUKBAYRAK ABDULKADIR
# 30
# AU=YILDIRIM ABDULKADIR
# 33
# AU=CEKIN ABDULKADIR
# 0
# AU=SENGUN ABDULKADIR
# 13
# AU=BEDIR ABDULKERIM
# 38
# AU=AKPINAR ABDULLAH
# 38
# AU=BAL ABDULLAH
# 26
# AU=SENGUL ABDULLAH
# 3
# AU=DEMIR ABDULLAH
# 54
# AU=DOGAN ABDULLAH
# 112
# AU=EKIZER ABDULLAH
# 13
# AU=ERDIL ABDULLAH
# 5
# AU=ERGIN ABDULLAH
# 3
# AU=SECKIN ABDULLAH
# 1
# AU=KIRAN ABDULLAH
# 0
# AU=USTUN ABDULLAH
# 5
# AU=CINGU ABDULLAH
# 46
# AU=AKSOY ABDULLAH
# 1
# AU=TUNCER ABDULLAH
# 0
# AU=MUTLU ABDULLAH
# 0
# AU=KILDAN ABDULLAH
# 2
# AU=POS ABDULLAH
# 0
# AU=SONMEZ ABDULLAH
# 22
# AU=URAL ABDULLAH
# 1
# AU=YORDEM ABDULLAH
# 0
# AU=TARIKULU ABDULLAH
# 0
# AU=CIM ABDULLAH
# 14
# AU=INALCIK ABDULLAH
# 5
# AU=ASLAN ABDULSELAM
# 8
# AU=GOK ABDULVAHAP
# 10
# AU=OZTURK ABDURAHMAN
# 0
# AU=ABAKAY ABDURRAHMAN
# 34
# AU=DALGIC ABDURRAHMAN
# 0
# AU=ELMALI ABDURRAHMAN
# 1
# AU=GENC ABDURRAHMAN
# 21
# AU=KADAYIFCI ABDURRAHMAN
# 53
# AU=KUZHAN ABDURRAHMAN
# 4
# AU=KIREMITCI ABDURRAHMAN
# 20
# AU=BODUR ABDURRAHMAN
# 4
# AU=SAHIN ABDURRAHMAN
# 64
# AU=ELDEMIR ABDURRAHIM
# 0
# AU=EMHAN ABDURRAHIM
# 3
# AU=GOZEN ABDURRAHIM
# 3
# AU=AKTAS ABDURRAZZAK
# 5
# AU=BOLUKBASI ABDURREHIM
# 1
# AU=BOREKCI ABDURREZZAK
# 19
# AU=OZSEVIK ABDUL
# 9
# AU=UGU ABDULHADI
# 0
# AU=OZDENIZ ABDULHADI
# 1
# AU=ISIK ABDULKADIR
# 0
# AU=KOCER ABDULKADIR
# 36
# AU=OZTURK ABDULKADIR
# 3
# AU=KARSLI ABDURRAHIM
# 0
# AU=ARTIS ABDUSSELAM
# 0
# AU=DEMIR ADALET
# 39
# AU=BEKLER ADEM
# 37
# AU=EREN ADEM
# 0
# AU=ERKUT ADEM
# 6
# AU=GUL ADEM
# 21
# AU=GUNGOR ADEM
# 33
# AU=ISIK ADEM
# 2
# AU=KARA ADEM
# 25
# AU=KARACA ADEM
# 16
# AU=KARATAS ADEM
# 20
# AU=KORUKCU ADEM
# 0
# AU=KUSGOZ ADEM
# 24
# AU=SOLAK ADEM
# 2
# AU=TOK ADEM
# 16
# AU=TOPKARA ADEM
# 15
# AU=OCAL ADEM
# 5
# AU=OZKAN ADEM
# 23
# AU=OGUT ADEM
# 1
# AU=UN ADEM
# 8
# AU=AKSOY ADNAN
# 20
# AU=ASLAN ADNAN
# 10
# AU=BARUT ADNAN
# 0
# AU=CEYLAN ADNAN
# 6
# AU=DOGAN ADNAN
# 23
# AU=GUL ADNAN
# 18
# AU=GURBUZ ADNAN
# 0
# AU=KARADUZ ADNAN
# 1
# AU=PARLAK ADNAN
# 26
# AU=YAVUZ ADNAN
# 9
# AU=CINAL ADNAN
# 17
# AU=OZYILMAZ ADNAN
# 4
# AU=BUCAKTEPE ADIL
# 0
# AU=KARADAG ADIL
# 21
# AU=KILIC ADIL
# 20
# AU=OKSUZ ADIL
# 0
# AU=DENK AFFAN
# 14
# AU=KARAVELIOGLU AFKA
# 0
# AU=EKINCI AFRA
# 3
# AU=GUMUSCU AHHMET
# 0
# AU=AGIR AHME
# 0
# AU=AYAC AHME
# 0
# AU=TANRIKULU AHMED
# 2
# AU=TEKINAY AHMET
# 9
# AU=AFYON AHMET
# 7
# AU=AKBAS AHMET
# 15
# AU=AKTURK AHMET
# 11
# AU=AKCAY AHMET
# 48
# AU=ALTINTAS AHMET
# 27
# AU=SANCAKTUTAR AHMET
# 107
# AU=ATLI AHMET
# 0
# AU=AYPAY AHMET
# 11
# AU=BAL AHMET
# 22
# AU=BAYLAR AHMET
# 24
# AU=BAYRAKTAR AHMET
# 6
# AU=BAYTAK AHMET
# 8
# AU=BEDIR AHMET
# 1
# AU=BEKIR AHMET
# 118
# AU=BESKAYA AHMET
# 0
# AU=BIYIK AHMET
# 0
# AU=BOYACI AHMET
# 30
# AU=BULUT AHMET
# 67
# AU=TURHAN AHMET
# 39
# AU=SENGUL AHMET
# 12
# AU=DURAK AHMET
# 14
# AU=YENIDUNYA AHMET
# 0
# AU=DAGDAS AHMET
# 8
# AU=DEMIR AHMET
# 221
# AU=DEMIRER AHMET
# 5
# AU=AYSEV AHMET
# 8
# AU=DURAN AHMET
# 86
# AU=DUVAN AHMET
# 0
# AU=DILEK AHMET
# 21
# AU=DIRIER AHMET
# 16
# AU=MUFTUOGLU AHMET
# 1
# AU=EKMEKYAPAR AHMET
# 10
# AU=SEKERCI AHMET
# 52
# AU=ERDINC AHMET
# 10
# AU=EROL AHMET
# 11
# AU=EYIBILEN AHMET
# 31
# AU=KILIC AHMET
# 204
# AU=YUCEL AHMET
# 58
# AU=GAYRETLI AHMET
# 3
# AU=GOKGOZ AHMET
# 1
# AU=GOKCIMEN AHMET
# 2
# AU=GUNER AHMET
# 57
# AU=GUNES AHMET
# 18
# AU=GUREL AHMET
# 37
# AU=GUZEL AHMET
# 92
# AU=ERTAS AHMET
# 36
# AU=KOSE AHMET
# 18
# AU=EROGLU AHMET
# 59
# AU=KAHRAMAN AHMET
# 106
# AU=KARAASLAN AHMET
# 43
# AU=KARADAG AHMET
# 84
# AU=KARATAS AHMET
# 77
# AU=KAYA AHMET
# 240
# AU=GULTEKIN AHMET
# 6
# AU=KESKIN AHMET
# 36
# AU=KILIC AHMET
# 204
# AU=KUNDURACIOGLU AHMET
# 8
# AU=KIZIRGIL AHMET
# 6
# AU=UGUR AHMET
# 22
# AU=MENKU AHMET
# 21
# AU=ONAT AHMET
# 125
# AU=AYTEKIN AHMET
# 22
# AU=PIINAR AHMET
# 0
# AU=GUNES AHMET
# 18
# AU=NACAR AHMET
# 28
# AU=SIRKECIOGLU AHMET
# 18
# AU=OZCIVAN AHMET
# 0
# AU=OKUMUS AHMET
# 3
# AU=CELIK AHMET
# 195
# AU=PASINLI AHMET
# 10
# AU=PEKCAN AHMET
# 0
# AU=YAYLA AHMET
# 2
# AU=DIZKIRICI AHMET
# 0
# AU=SONGUR AHMET
# 34
# AU=SOYSAL AHMET
# 71
# AU=SURUCU AHMET
# 5
# AU=TEMIZ AHMET
# 56
# AU=TEMIZYUREK AHMET
# 0
# AU=ULUS AHMET
# 16
# AU=OZCERIT AHMET
# 12
# AU=TUTOGLU AHMET
# 30
# AU=ULUDAG AHMET
# 36
# AU=UYSAL AHMET
# 120
# AU=UCAR AHMET
# 67
# AU=UCAR AHMET
# 67
# AU=VAR AHMET
# 31
# AU=VURAL AHMET
# 58
# AU=GUNGOR AHMET
# 20
# AU=YESILDAG AHMET
# 25
# AU=YILDIRIM AHMET
# 256
# AU=ATA AHMET
# 3
# AU=YULAFCI AHMET
# 1
# AU=YUMUSAK AHMET
# 1
# AU=YONEM AHMET
# 0
# AU=CALISKAN AHMET
# 71
# AU=CAVDAR AHMET
# 16
# AU=CELIK AHMET
# 195
# AU=CAN AHMET
# 61
# AU=CETINKAYA AHMET
# 39
# AU=CINKAYA AHMET
# 8
# AU=CINI AHMET
# 0
# AU=OKSUZ AHMET
# 4
# AU=ORNEK AHMET
# 16
# AU=OZ AHMET
# 37
# AU=OZ AHMET
# 37
# AU=OZCAN AHMET
# 27
# AU=AKTAN AHMET
# 4
# AU=OZER AHMET
# 74
# AU=OGRETEN AHMET
# 0
# AU=DUNDAR AHMET
# 0
# AU=ISLEYEN AHMET
# 27
# AU=SAHBAZ AHMET
# 29
# AU=SAHIN AHMET
# 214
# AU=SAHIN AHMET
# 214
# AU=KABLAMACI AHSEN
# 0
# AU=KAHVECI AJDA
# 7
# AU=KARAKUS AKAN
# 6
# AU=ALSARAN AKGUN
# 9
# AU=AYDOGAN AKIN
# 19
# AU=ATAGUN AKIN
# 15
# AU=PALA AKIN
# 12
# AU=CELIK AKIN
# 0
# AU=ONDER AKIN
# 37
# AU=ACAY AKIF
# 14
# AU=ARSLAN AKIF
# 45
# AU=KARATEPE AKIF
# 1
# AU=KOC AKIF
# 13
# AU=KUTLU AKIF
# 8
# AU=RENCBER AKIF
# 0
# AU=SIRIKCI AKIF
# 17
# AU=AKTAS ALAATTIN
# 23
# AU=DIKMEN ALAATTIN
# 0
# AU=KAYA ALAATTIN
# 27
# AU=ERTEKIN ALAATTIN
# 4
# AU=ILGEN ALDULKADIR
# 0
# AU=BAYRAKTAR ALEMDAR
# 122
# AU=KOYUTURK ALP
# 15
# AU=BIRDANE ALPARSLAN
# 36
# AU=SAHIN ALPARSLAN
# 86
# AU=GORMUS ALPARSLAN
# 1
# AU=KILICARSLAN ALPASLAN
# 11
# AU=ERSOZLU ALPAY
# 4
# AU=HAKTANIR ALPAY
# 20
# AU=NACAR ALPER
# 23
# AU=CAN ALPER
# 25
# AU=KARAHAN ALPER
# 10
# AU=KETEN ALPER
# 15
# AU=KUCUKDURMAZ ALPER
# 0
# AU=SEVINC ALPER
# 144
# AU=AKARSUBASI ALPER
# 8
# AU=YAZICI ALPER
# 30
# AU=YIGIT ALPER
# 0
# AU=CETIN ALTAN
# 9
# AU=ACILAR ALI
# 0
# AU=ALKAN ALI
# 43
# AU=ANNAGUR ALI
# 29
# AU=ARASOGLU ALI
# 5
# AU=ARSLAN ALI
# 59
# AU=BAL ALI
# 12
# AU=ASLANTAS ALI
# 3
# AU=AYDIN ALI
# 170
# AU=YAVUZ ALI
# 19
# AU=AYTEKIN ALI
# 7
# AU=BAY ALI
# 57
# AU=BAYRAM ALI
# 72
# AU=BEKTAS ALI
# 3
# AU=KURT ALI
# 56
# AU=AVCI ALI
# 44
# AU=BORA ALI
# 0
# AU=BUDAK ALI
# 16
# AU=CAN ALI
# 26
# AU=CAN ALI
# 26
# AU=EREN ALI
# 16
# AU=CETIN ALI
# 97
# AU=DELICE ALI
# 20
# AU=DURSUN ALI
# 65
# AU=DOGAN ALI
# 130
# AU=MUFTUOGLU ALI
# 20
# AU=EKIN ALI
# 2
# AU=ELEREN ALI
# 1
# AU=ERAYMAN ALI
# 11
# AU=ERGUN ALI
# 30
# AU=ALAC ALI
# 0
# AU=ERZURUMLUOGLU ALI
# 0
# AU=DOGAN ALI
# 130
# AU=FILIZ ALI
# 25
# AU=ONAL ALI
# 6
# AU=GURBUZ ALI
# 208
# AU=GUVERCIN ALI
# 7
# AU=KARADENIZ ALI
# 18
# AU=KARAKUS ALI
# 32
# AU=KARATAY ALI
# 1
# AU=KARAISA ALI
# 22
# AU=UZUNLAR ALI
# 23
# AU=KESKIN ALI
# 68
# AU=KORKUT ALI
# 10
# AU=KOZAN ALI
# 1
# AU=KOCYIGIT ALI
# 66
# AU=KURSUN ALI
# 11
# AU=AKTAN ALI
# 27
# AU=CEYHAN ALI
# 28
# AU=KALENDER ALI
# 23
# AU=SUNBUL ALI
# 7
# AU=TANKUT ALI
# 12
# AU=OKUYUCU ALI
# 33
# AU=SOLAK ALI
# 59
# AU=SOLMAZ ALI
# 19
# AU=ONCEL ALI
# 2
# AU=AKTAS ALI
# 10
# AU=ARSLAN ALI
# 59
# AU=ERDEM ALI
# 51
# AU=ERDEM ALI
# 51
# AU=SEVER ALI
# 71
# AU=SEYDI ALI
# 1
# AU=TARAKCILAR ALI
# 9
# AU=COBAN ALI
# 1
# AU=OZDEMIR ALI
# 66
# AU=SEKERCI ALI
# 2
# AU=SALLI ALI
# 32
# AU=KIVRAK ALI
# 52
# AU=TEKIN ALI
# 69
# AU=SEYYAR ALI
# 0
# AU=SICAK ALI
# 0
# AU=GUMUS ALI
# 0
# AU=TURKAN ALI
# 8
# AU=UZER ALI
# 13
# AU=YALCIN ALI
# 38
# AU=YAVUZ ALI
# 19
# AU=YILDIRIM ALI
# 271
# AU=YILDIZ ALI
# 177
# AU=CALISKAN ALI
# 16
# AU=DENIZ ALI
# 79
# AU=CELIK ALI
# 125
# AU=CELIKSOZ ALI
# 7
# AU=CETINKAYA ALI
# 45
# AU=COLAK ALI
# 3
# AU=COSKUN ALI
# 195
# AU=OZCAN ALI
# 80
# AU=OZEL ALI
# 18
# AU=YENER ALI
# 42
# AU=BOZKURT ALI
# 53
# AU=KAYTAZ ALI
# 0
# AU=NESLITURK ALI
# 3
# AU=GUL ALI
# 41
# AU=ISKURT ALI
# 8
# AU=SAHIN ALI
# 110
# AU=SENOL ALI
# 5
# AU=KAPTI ALICAN
# 2
# AU=AYDIN ALIHAN
# 0
# AU=ERDEM ALIM
# 55
# AU=GUR ALIM
# 0
# AU=GUNES ALIME
# 25
# AU=KIYAK ALIYE
# 0
# AU=OZENOGLU ALIYE
# 13
# AU=KAYACIER AMED
# 0
# AU=CAMAS ANIL
# 4
# AU=YONDEN ARZU
# 0
# AU=YALCIN ARZU
# 64
# AU=AKGUL ARIF
# 3
# AU=DANE ARIF
# 2
# AU=DAGLI ARIF
# 0
# AU=DURAN ARIF
# 21
# AU=KARAKAS ARIF
# 8
# AU=KAYA ARIF
# 36
# AU=KECELI ARIF
# 1
# AU=AYAN ARIF
# 26
# AU=ULU ARIF
# 0
# AU=IPEK ARIF
# 27
# AU=EKINCI ARIFE
# 5
# AU=CENGIZ ASIM
# 8
# AU=DANE ASIM
# 7
# AU=BILICI ASLAN
# 35
# AU=TEKATAS ASLAN
# 15
# AU=KAYA ASLI
# 8
# AU=AVCI ASLI
# 2
# AU=VATANSEVER ASLI
# 1
# AU=KARTAL ASLIHAN
# 13
# AU=BAYRAKTAR ASLIHAN
# 12
# AU=CINCIOGLU ASUMAN
# 0
# AU=CELIKBILEK ASUMAN
# 27
# AU=TIGLI ASIYE
# 0
# AU=ARI ATEM
# 0
# AU=ERKAL ATILA
# 0
# AU=GUNEY ATILLA
# 0
# AU=ILHAN ATILLA
# 22
# AU=ICLI ATILLA
# 65
# AU=OZTURK ATIYE
# 4
# AU=DURMUSOGLU ATIYE
# 0
# AU=TOPRAK AYBALA
# 12
# AU=GUR AYCAN
# 13
# AU=TELLIOGLU AYDA
# 4
# AU=OKAY AYDEMIR
# 1
# AU=BORA AYDIN
# 37
# AU=DEMIRCAN AYDIN
# 19
# AU=ECE AYDIN
# 35
# AU=GUZELOGLU AYDIN
# 23
# AU=KURNAZ AYDIN
# 7
# AU=TEMIZER AYDIN
# 1
# AU=ERTEKIN AYFER
# 5
# AU=UDAK AYFER
# 0
# AU=DAGDELEN AYHAN
# 7
# AU=GUNEY AYHAN
# 0
# AU=KIRAZ AYHAN
# 2
# AU=SELCUK AYHAN
# 0
# AU=SOGUT AYHAN
# 33
# AU=TERGIP AYHAN
# 0
# AU=USTA AYHAN
# 26
# AU=YILDIRIM AYHAN
# 23
# AU=CELIK AYHAN
# 32
# AU=CINICI AYHAN
# 4
# AU=DEMIRKOL AYHMET
# 0
# AU=COBAN AYKUT
# 0
# AU=OKUR AYLIN
# 53
# AU=KIRBAS AYNUR
# 43
# AU=OZUGURLU AYNUR
# 0
# AU=KADERLI AYSEL
# 31
# AU=KOCAEREN AYSEL
# 6
# AU=KURT AYSEL
# 10
# AU=TUNCA AYSEL
# 1
# AU=KARABULUT AYSUN
# 55
# AU=TOKER AYSUN
# 56
# AU=ALCELIK AYTEKIN
# 43
# AU=DEMIRCIOGLU AYTEKIN
# 2
# AU=ERYILMAZ AYTEKIN
# 15
# AU=POLAT AYTEKIN
# 10
# AU=SIR AYTEKIN
# 17
# AU=YESILAY AYTEKIN
# 2
# AU=CIKMAN AYTEKIN
# 25
# AU=DERINGOZ AYSE
# 0
# AU=AYNALI AYSE
# 11
# AU=BALKAN AYSE
# 0
# AU=TEKINAY AYSE
# 96
# AU=BASTERZI AYSE
# 9
# AU=ALPKAYA AYSE
# 0
# AU=YILGOR AYSE
# 0
# AU=HOWISON AYSE
# 0
# AU=KILINCASLAN AYSE
# 24
# AU=YEKSAN AYSE
# 6
# AU=GUNGOR AYSE
# 35
# AU=KORKMAZ AYSE
# 58
# AU=SAGIROGLU AYSE
# 9
# AU=SEZGIN AYSE
# 7
# AU=KURT AYSE
# 12
# AU=ULU AYSE
# 1
# AU=YIGIT AYSE
# 19
# AU=KIZILKAN AYSE
# 0
# AU=SARAC AYSEGUL
# 14
# AU=KALKAN AYSEGUL
# 0
# AU=TURKYILMAZ AYSEGUL
# 30
# AU=KURNAZ AYSEGUL
# 0
# AU=AYSEUMUL AYSEUMUL
# 0
# AU=ULUDAG AYSEUL
# 0
# AU=ILBAY AZMI
# 1
# AU=ILHAN AZIME
# 1
# AU=ASAN AZIZ
# 0
# AU=GUMUS AZIZ
# 17
# AU=HARMAN AZIZ
# 6
# AU=KILINC AZIZ
# 2
# AU=MERHAN AZIZ
# 2
# AU=POLAT AZIZ
# 31
# AU=TUNC AZIZ
# 3
# AU=TURKOGLU AZIZ
# 19
# AU=ARTIS AISE
# 1
# AU=GENC ASIR
# 10
# AU=ORENC ASIR
# 0
# AU=YILDIRIM ASKIN
# 0
# AU=SEKER ASKIN
# 43
# AU=OZDEMIR ASUR
# 0
# AU=GUNEY BAHA
# 0
# AU=BOZOGLAN BAHADIR
# 6
# AU=KUMRAL BAHADIR
# 16
# AU=TANTAY BAHADIR
# 0
# AU=ERDINC BAHATTIN
# 13
# AU=TUNC BAHATTIN
# 88
# AU=ERMIS BAHRI
# 15
# AU=ARSLAN BAHRIYE
# 5
# AU=DURSUN BAHTIYAR
# 19
# AU=SARIBOGA BAHTIYAR
# 13
# AU=SARITAS BAKI
# 0
# AU=TURKKAN BAKI
# 6
# AU=ALTAN BANU
# 0
# AU=KALE BANU
# 4
# AU=UYSAL BANU
# 12
# AU=IZGI BANU
# 0
# AU=GUNAY BANIHAN
# 12
# AU=COREKCI BARAM
# 0
# AU=GENCER BARAN
# 37
# AU=ASCI BARIS
# 3
# AU=ERCAL BARIS
# 17
# AU=GULHAN BARIS
# 12
# AU=KIREMITCI BARIS
# 2
# AU=YALINKILIC BARIS
# 5
# AU=ALKAWASMEI BASSAM
# 0
# AU=DIKMEN BAYAZIT
# 49
# AU=AKARSU BAYRAM
# 2
# AU=ALTUNTAS BAYRAM
# 34
# AU=ABALI BAYRAM
# 0
# AU=CETISLI BAYRAM
# 21
# AU=ERZURUMLUOGLU BAYRAM
# 0
# AU=KAHRAMAN BAYRAM
# 17
# AU=KOKSAL BAYRAM
# 0
# AU=CIRAK BAYRAM
# 17
# AU=INCE BAYRAM
# 7
# AU=BAYRAKTAR BEDIZ
# 0
# AU=AKTAS BEKIR
# 36
# AU=ATIK BEKIR
# 42
# AU=DOGAN BEKIR
# 35
# AU=GUNAY BEKIR
# 0
# AU=KARAARSLAN BEKIR
# 5
# AU=KOLE BEKIR
# 0
# AU=MUMYAKMAZ BEKIR
# 5
# AU=UNLU BEKIR
# 28
# AU=KARATAS BEKIR
# 7
# AU=YILDIZ BEKIR
# 44
# AU=CAKILDERE BEKIR
# 0
# AU=CAGLI BEKIR
# 15
# AU=CENGELCI BEKIR
# 0
# AU=SANAL BEKIR
# 23
# AU=ERES BENAN
# 2
# AU=KILBAS BENAN
# 17
# AU=KADERLI BERKANT
# 13
# AU=OZDEMIR BESIME
# 0
# AU=SEKER BETUL
# 2
# AU=ESER BETUL
# 13
# AU=CEYHAN BETUL
# 16
# AU=OKUTAN BETUL
# 0
# AU=YARAR BETUL
# 0
# AU=ISKENDER BETUL
# 0
# AU=SEYHAN BEYAZIT
# 0
# AU=CENGIZ BEYHAN
# 50
# AU=KURT BEYZA
# 0
# AU=ERDOGMUS BESIR
# 27
# AU=GOZUBENLI BESIR
# 0
# AU=ALTUNTOP BESIR
# 0
# AU=OZTURK BORA
# 10
# AU=TANYERI BUKET
# 0
# AU=CITIL BURAK
# 6
# AU=SUVAK BURAK
# 32
# AU=UZ BURAK
# 52
# AU=ULMAN BURAK
# 2
# AU=GUNAY BURCU
# 1
# AU=OGUZTURK BURCU
# 0
# AU=KOCA BURCU
# 2
# AU=CAKAR BURCU
# 18
# AU=KABADAYI BURHAN
# 0
# AU=YAZICI BURHAN
# 21
# AU=UNAL BURHAN
# 5
# AU=AKYUZ BULENT
# 3
# AU=ASLAN BULENT
# 14
# AU=TELEF BULENT
# 4
# AU=BASARAN BULENT
# 3
# AU=DOGRU BULENT
# 1
# AU=DURU BULENT
# 0
# AU=GOGEBAKAN BULENT
# 34
# AU=KILIC BULENT
# 51
# AU=ICTEN BULENT
# 22
# AU=MIRAN BULENT
# 17
# AU=KILAVUZ BULENT
# 0
# AU=ORAN BULENT
# 39
# AU=PETIK BULENT
# 9
# AU=TARMAN BULENT
# 9
# AU=VURAL BULENT
# 9
# AU=YAVUZ BULENT
# 0
# AU=YILDIRIM BULENT
# 16
# AU=CATALBAS BULENT
# 6
# AU=COBANOGLU BULENT
# 1
# AU=OZ BULENT
# 2
# AU=OZBAY BULENT
# 21
# AU=OZDEMIR BULENT
# 55
# AU=SIK BULENT
# 1
# AU=ALTINOLUK BULNET
# 0
# AU=OZOGUL BUNYAMI
# 34
# AU=UNAL BUNYAMI
# 48
# AU=TURAN BUNYAMIN
# 2
# AU=DIKICI BUNYAMIN
# 5
# AU=ISIK BUNYAMIN
# 12
# AU=KARABULUT BUNYAMIN
# 33
# AU=KISACIK BUNYAMIN
# 112
# AU=KOC BUNYAMIN
# 18
# AU=SOZUTOK BUNYAMIN
# 0
# AU=GUL BILAL
# 1
# AU=GURBUZ BILAL
# 17
# AU=SAVAS BILAL
# 0
# AU=TEMIZ BILAL
# 0
# AU=YILDIZ BILAL
# 35
# AU=YILDIZ BILAL
# 35
# AU=YORULMAZ BILAL
# 0
# AU=SEKER BILAL
# 7
# AU=SINIK BILAL
# 0
# AU=ANNAGUR BILGE
# 28
# AU=SEN BILGE
# 49
# AU=KARA BILGE
# 41
# AU=PAMUK BILGEHAN
# 3
# AU=YILMAZ BINNAZ
# 0
# AU=ASIK BIRAY
# 6
# AU=ALAN BIRCAN
# 12
# AU=SAVRAN BIRCAN
# 13
# AU=ISIK BIRHAN
# 6
# AU=TOPCU BIRKAN
# 4
# AU=UNAL BIRSEN
# 7
# AU=DOGAN CABIR
# 0
# AU=EROGLU CAFER
# 25
# AU=ULU CAFER
# 0
# AU=SAHBAZ CAFER
# 4
# AU=YILMAZ CAHIDE
# 39
# AU=BAGCI CAHIT
# 21
# AU=KURBANOGLU CAHIT
# 12
# AU=BENLIOGLU CAN
# 11
# AU=OZBAY CAN
# 7
# AU=KAYGUSUZ CANANI
# 4
# AU=SAHIN CANAY
# 0
# AU=BADEM CANDAN
# 3
# AU=ARSLAN CANER
# 28
# AU=DINCER CANER
# 0
# AU=TOKUC CANER
# 0
# AU=GUNER CANSEVER
# 0
# AU=AKDENIZ CELAL
# 54
# AU=IRGIN CELAL
# 7
# AU=KOCATEPE CELAL
# 7
# AU=KILIT CELAL
# 27
# AU=CAYIR CELAL
# 1
# AU=OZPINAR CELAL
# 4
# AU=CAMCI CELALETDIN
# 29
# AU=BAYKARA CELALETTIN
# 0
# AU=KARADAS CELALETTIN
# 0
# AU=AYHAN CEM
# 1
# AU=GUREL CEM
# 3
# AU=KAPTANOGLU CEM
# 8
# AU=ORUC CEM
# 17
# AU=SARAC CEM
# 1
# AU=ZEREN CEM
# 19
# AU=BALTACI CEMAL
# 0
# AU=ELITAS CEMAL
# 2
# AU=GUNDOGDU CEMAL
# 82
# AU=ISIK CEMAL
# 0
# AU=SANDALLI CEMAL
# 37
# AU=SARAC CEMAL
# 1
# AU=TUNCER CEMAL
# 23
# AU=YESILYURT CEMAL
# 24
# AU=AYAS CEMALETTIN
# 4
# AU=DEMIRELI CEMALETTIN
# 0
# AU=BULBUL CEMIL
# 0
# AU=KARA CEMIL
# 5
# AU=CELIK CEMIL
# 41
# AU=SAHIN CEMIL
# 0
# AU=CAKMAK CENAP
# 4
# AU=ATASOGLU CENGIZ
# 6
# AU=BASAK CENGIZ
# 0
# AU=DEMIREL CENGIZ
# 16
# AU=DEMIR CENGIZ
# 30
# AU=DURUCU CENGIZ
# 35
# AU=ERDIK CENGIZ
# 0
# AU=INCE CENGIZ
# 3
# AU=KOCAK CENGIZ
# 55
# AU=ORMAN CENGIZ
# 0
# AU=SARIKURKCU CENGIZ
# 65
# AU=TORAMAN CENGIZ
# 3
# AU=YALCIN CENGIZ
# 11
# AU=CEVIK CENGIZ
# 25
# AU=AKBIYIK CENK
# 8
# AU=EKEN CENKER
# 66
# AU=ATAS CESIM
# 18
# AU=AKTAS CEVAT
# 42
# AU=TOSUN CEVAT
# 3
# AU=DEMIR CEVDET
# 30
# AU=GOLOGLU CEVDET
# 8
# AU=JR CLYDE
# 0
# AU=CHIFANE CRISTINA
# 2
# AU=CICEK CUMA
# 1
# AU=GOKCE CUMALI
# 39
# AU=AKINLAR CUNEYT
# 26
# AU=BERKDEMIR CUNEYT
# 15
# AU=DEMIR CUNEYT
# 3
# AU=KAHRAMAN CUNEYT
# 12
# AU=HAMIDI CIHAD
# 29
# AU=TOKTAS CIHAN
# 6
# AU=TURK CIHAN
# 0
# AU=YILDIRIM CIHAN
# 19
# AU=ALIAGAOGLU CIHANGIR
# 30
# AU=EREM CIHANGIR
# 67
# AU=GURKAN CIHAT
# 5
# AU=POLAT CIHAT
# 1
# AU=AKTAS DAVUT
# 3
# AU=AYDUZ DAVUT
# 0
# AU=BALTACI DAVUT
# 44
# AU=DAMA DAVUT
# 1
# AU=DEMIRKIRAN DAVUT
# 7
# AU=OZDEMIR DAVUT
# 23
# AU=INCEBACAK DAVUT
# 10
# AU=ISIK DAGHAN
# 45
# AU=ARSLAN DEMET
# 12
# AU=KORUCU DEMET
# 7
# AU=SEBAN DEMET
# 4
# AU=EKINCI DENIZ
# 83
# AU=GUNEY DENIZ
# 14
# AU=TOKAT DENIZ
# 2
# AU=UNAL DENIZ
# 56
# AU=DUNDAR DERYA
# 0
# AU=DEMIRER DERYA
# 1
# AU=SAGLAM DERYA
# 6
# AU=YILDIZ DERYA
# 9
# AU=TARHAN DEVRIM
# 8
# AU=ERDOGAN DOGAN
# 96
# AU=KILKIS DOGAN
# 8
# AU=KURT DOGAN
# 5
# AU=CETIN DOGAN
# 4
# AU=KARATAS DURA
# 0
# AU=ARSLAN DURAN
# 20
# AU=YAVSAN DURDU
# 5
# AU=OZCAN DURDU
# 0
# AU=BAL DURMUS
# 9
# AU=BOZKURT DURMUS
# 31
# AU=BUNARCIOGLU DURMUS
# 0
# AU=TATLIOGLU DURMUS
# 0
# AU=TURKMEN DURMUS
# 4
# AU=SAHIN DURSUN
# 22
# AU=YAGIZ DURSUN
# 8
# AU=AKKOYUN DURSUN
# 29
# AU=GUCLU DUNYAMIN
# 11
# AU=CAKIRCA DUZGUN
# 0
# AU=DOGAN DIDEM
# 4
# AU=GURSES DIDEM
# 1
# AU=ER DILEK
# 0
# AU=KUTANIS DILEK
# 8
# AU=SELEK DILEK
# 0
# AU=KOCAK DILEK
# 1
# AU=ESSIZ DINC
# 23
# AU=TEKBAS EBRU
# 23
# AU=UZ EBRU
# 40
# AU=TOY EBUBEKIR
# 13
# AU=CAKMAK EBUBEKIR
# 2
# AU=KALENDER EBUZER
# 15
# AU=CAKMAK ECIR
# 17
# AU=ERDENER EDA
# 1
# AU=LLUKACAJ EDONA
# 1
# AU=MINARECI EDIBE
# 4
# AU=POLAT EDIZ
# 8
# AU=TUTAR EDIZ
# 32
# AU=POLAT EFDAL
# 1
# AU=UZ EFKAN
# 46
# AU=IRKICATAL EFTAL
# 0
# AU=AKCICEK EKREM
# 16
# AU=AYDIN EKREM
# 6
# AU=DEMIR EKREM
# 0
# AU=DUNDAR EKREM
# 17
# AU=GULER EKREM
# 75
# AU=KARA EKREM
# 43
# AU=MUS EKREM
# 1
# AU=YETER EKREM
# 89
# AU=UZGEL ELCIN
# 0
# AU=TERZI ELCIN
# 15
# AU=UYSAL ELIF
# 16
# AU=ERDOGAN ELIF
# 8
# AU=FIRAT ELIF
# 1
# AU=TAS ELIF
# 1
# AU=GOZEMIR ELIF
# 0
# AU=GULTURK ELIF
# 0
# AU=ERTAS ELIF
# 20
# AU=BEIGMOHAMMADI ELIF
# 2
# AU=BERK ELIFE
# 14
# AU=KILICBEYLI ELIFE
# 0
# AU=BOZKURT ELIFE
# 0
# AU=ASLAN EMEL
# 8
# AU=BULCUN EMEL
# 20
# AU=CAGLAYAN EMEL
# 15
# AU=ERGIN EMEL
# 1
# AU=KARAKAS EMEL
# 18
# AU=AKCAY EMRAH
# 7
# AU=BULUT EMRAH
# 28
# AU=GUNOK EMRAH
# 0
# AU=GIZIROGLU EMRAH
# 11
# AU=UYANIK EMRAH
# 9
# AU=OZBUGUTU EMRAH
# 0
# AU=UNAL EMRAH
# 5
# AU=BENDES EMRE
# 4
# AU=CAN EMRE
# 5
# AU=EROGLU EMRE
# 10
# AU=GUNBEY EMRE
# 35
# AU=HOCAOGLU EMRE
# 19
# AU=KARAKUS EMRE
# 54
# AU=SANCAK EMRE
# 8
# AU=SEVINDIK EMRE
# 8
# AU=CAVDAR EMRE
# 0
# AU=COMAK EMRE
# 8
# AU=AYDIN EMSAL
# 12
# AU=ERGUN EMIN
# 12
# AU=KARA EMIN
# 0
# AU=KILINC EMIN
# 2
# AU=MADEN EMIN
# 17
# AU=METE EMIN
# 27
# AU=BASKENT EMIN
# 50
# AU=OZDEMIR EMIN
# 4
# AU=OZYILMAZ EMIN
# 5
# AU=SAVIK EMIN
# 17
# AU=TAVIL EMINE
# 2
# AU=BINNETOGLU EMINE
# 27
# AU=MALKOC EMINE
# 20
# AU=MESTAN EMINE
# 3
# AU=MESE EMINE
# 8
# AU=HERKEN EMINE
# 28
# AU=RIFAIOGLU EMINE
# 30
# AU=PANCAR EMINE
# 0
# AU=KOC EMINE
# 67
# AU=KOC EMINE
# 67
# AU=KARAKOC EMINE
# 3
# AU=COSAR EMINE
# 46
# AU=OZEL EMINE
# 6
# AU=TAN ENES
# 5
# AU=YILMAZ ENES
# 10
# AU=DOGAN ENFEL
# 0
# AU=AKAR ENGIN
# 6
# AU=AKMAN ENGIN
# 5
# AU=BASARAN ENGIN
# 3
# AU=DELICE ENGIN
# 0
# AU=SELCUK ENGIN
# 16
# AU=YAZICI ENGIN
# 0
# AU=ERDEM ENGIN
# 1
# AU=SENGUL ENGIN
# 11
# AU=YEKELER ENSAR
# 46
# AU=SANCAKDAR ENVER
# 30
# AU=ALBAYRAK ENVER
# 3
# AU=TATAR ENVER
# 12
# AU=USLU ENVER
# 3
# AU=TOPCU ERAL
# 0
# AU=EKICI ERAN
# 0
# AU=AKBAY ERCAN
# 15
# AU=ARI ERCAN
# 0
# AU=BALCIOGLU ERCAN
# 1
# AU=BALDEMIR ERCAN
# 9
# AU=GENCER ERCAN
# 5
# AU=MADENCI ERCAN
# 19
# AU=PILICER ERCAN
# 9
# AU=SUNGER ERCAN
# 0
# AU=SIVASLI ERCAN
# 20
# AU=UCGUN ERCAN
# 2
# AU=AKSAKAL ERCUMENT
# 17
# AU=TEZCAN ERCUMENT
# 1
# AU=ABDULHAKIMOGULLARI ERDAL
# 0
# AU=ARAS ERDAL
# 11
# AU=BAYIR ERDAL
# 2
# AU=BULGAN ERDAL
# 4
# AU=BIBER ERDAL
# 0
# AU=CANIYILMAZ ERDAL
# 8
# AU=DEMIR ERDAL
# 2
# AU=DIKMEN ERDAL
# 8
# AU=ELKOCA ERDAL
# 12
# AU=EREN ERDAL
# 67
# AU=GISI ERDAL
# 0
# AU=KARA ERDAL
# 12
# AU=KACAN ERDAL
# 4
# AU=PEKER ERDAL
# 54
# AU=TATAR ERDAL
# 4
# AU=YAYLAK ERDAL
# 7
# AU=OZCAN ERDAL
# 4
# AU=OZSUNAR ERDAL
# 0
# AU=AYYILDIZ ERDEM
# 2
# AU=GUVEN ERDEM
# 34
# AU=SURUCU ERDEM
# 16
# AU=YUKSEL ERDEM
# 27
# AU=OZCAN ERDEM
# 6
# AU=SAGLAM ERDL
# 0
# AU=ARI ERDOGAN
# 0
# AU=BOZ ERDOGAN
# 0
# AU=GULTEKIN ERDOGAN
# 15
# AU=HALAT ERDOGAN
# 3
# AU=KILICASLAN ERDOGAN
# 1
# AU=KOCAMAZ ERDOGAN
# 16
# AU=OZBAY ERDOGAN
# 39
# AU=OZEL ERDOGAN
# 0
# AU=OZKAYA ERDOGAN
# 4
# AU=SENTURK ERDOGAN
# 6
# AU=AKYILDIRIM ERDINC
# 7
# AU=AKSU EREN
# 0
# AU=YILDIRIM EREN
# 6
# AU=GONCA ERGUN
# 18
# AU=GUNTEKIN ERGUN
# 13
# AU=KARAVELIOGLU ERGUN
# 25
# AU=NART ERGUN
# 5
# AU=YASAR ERGUN
# 3
# AU=SAKALAR ERGUN
# 13
# AU=BINGOLBALI ERHAN
# 11
# AU=DELEN ERHAN
# 11
# AU=GENC ERHAN
# 24
# AU=GUNEYISI ERHAN
# 66
# AU=KELESOGLU ERHAN
# 0
# AU=METIN ERHAN
# 0
# AU=SARI ERHAN
# 28
# AU=TAHAN ERHAN
# 4
# AU=VAROGLU ERHAN
# 29
# AU=OZCAN ERHAN
# 14
# AU=UNLU ERHAN
# 23
# AU=KOMURCU ERKAM
# 30
# AU=CURE ERKAN
# 51
# AU=EFE ERKAN
# 13
# AU=GOCEN ERKAN
# 4
# AU=KAVAS ERKAN
# 0
# AU=KACAN ERKAN
# 6
# AU=KURT ERKAN
# 10
# AU=SOGUT ERKAN
# 29
# AU=YAMAN ERKAN
# 5
# AU=YULA ERKAN
# 31
# AU=CALISKAN ERKAN
# 10
# AU=SIMSEK ERKAN
# 2
# AU=BAGCIOGLU ERMAN
# 23
# AU=GENC ERNUR
# 0
# AU=ALBAYRAK EROL
# 5
# AU=ERCAG EROL
# 25
# AU=GUNDUZ EROL
# 1
# AU=TOKSEN EROL
# 5
# AU=CELIK EROL
# 0
# AU=COSKUN EROL
# 25
# AU=ONEN EROL
# 4
# AU=CICEK ERSAN
# 14
# AU=DAG ERSEL
# 27
# AU=OBUZ ERSEL
# 16
# AU=ERKAN ERSIN
# 0
# AU=FADILLIOGLU ERSIN
# 32
# AU=KARAPAZARLIOGLU ERSIN
# 0
# AU=TERES ERSIN
# 1
# AU=ERDEN ERSIN
# 9
# AU=BESE ERTAN
# 0
# AU=DURMUSOGLU ERTAN
# 16
# AU=ERSOY ERTAN
# 0
# AU=YANIK ERTAN
# 9
# AU=OZTURK ERTAN
# 20
# AU=ACARTURK ERTUGRUL
# 0
# AU=ERCAN ERTUGRUL
# 49
# AU=KARGI ERTUGRUL
# 15
# AU=MAVILI ERTUGRUL
# 43
# AU=UZUN ERTUGRUL
# 3
# AU=BOZKURT ESAT
# 18
# AU=CETIN ESAT
# 3
# AU=SAVAS ESEN
# 24
# AU=BAKIR ESENGUL
# 0
# AU=KARAKAS ESER
# 0
# AU=BOZKURT ESHABIL
# 0
# AU=AKCAN ESMA
# 2
# AU=KAYA ESMA
# 19
# AU=UGURLU ESMA
# 0
# AU=USAK ESMA
# 3
# AU=YILDIZ ESMA
# 7
# AU=AKBALIK ESRA
# 1
# AU=TUZCU ESRA
# 33
# AU=OZTURK ESRA
# 48
# AU=INAL ESRA
# 32
# AU=KIZILCI ESRA
# 1
# AU=COLAK ESRA
# 2
# AU=OZDEMIR ESIN
# 1
# AU=KARAKAYA ETEM
# 2
# AU=KOKLUKAYA ETEM
# 23
# AU=SOYUCOK ETEM
# 4
# AU=YESILYURT ETEM
# 4
# AU=OZDEMIR EVREN
# 33
# AU=ERBILGIN EVRIM
# 6
# AU=KILIC EYLEM
# 23
# AU=SAHIN EYLEM
# 1
# AU=CIG EYLEM
# 1
# AU=COSKUN EYYUP
# 7
# AU=AYYILDIZ EYUP
# 0
# AU=BUYUKKAYA EYUP
# 34
# AU=KOC EYUP
# 21
# AU=YURT EYUP
# 10
# AU=ZENGIN EYUP
# 8
# AU=CETIN EYUP
# 5
# AU=CEVHER EZGI
# 1
# AU=ARSLAN FAHRETTIN
# 6
# AU=TALAY FAHRETTIN
# 25
# AU=GUNES FAHRI
# 32
# AU=BESIR FAHRI
# 31
# AU=TERCAN FAHRI
# 25
# AU=OZ FAHRI
# 1
# AU=BASCIFTCI FARUK
# 28
# AU=BAGIRCI FARUK
# 0
# AU=DEMIR FARUK
# 21
# AU=GEYIK FARUK
# 9
# AU=TUNCER FARUK
# 1
# AU=YILMAZ FARUK
# 61
# AU=YILMAZ FARUK
# 61
# AU=CAVDAR FARUK
# 9
# AU=OZ FARUK
# 0
# AU=OZTURK FARUK
# 61
# AU=UCAR FARUK
# 33
# AU=BOYACI FATIMA
# 16
# AU=BAYRAKTAR FATMA
# 4
# AU=BOZKURT FATMA
# 30
# AU=CEBE FATMA
# 9
# AU=DEMIREL FATMA
# 72
# AU=KILICER FATMA
# 0
# AU=ERDEM FATMA
# 36
# AU=GUNDOGDU FATMA
# 8
# AU=NIYAZIOGLU FATMA
# 0
# AU=TURKMENOGLU FATMA
# 5
# AU=TURALIOGLU FATMA
# 2
# AU=FIDAN FATMA
# 34
# AU=AKCAY FATIH
# 55
# AU=ALTUNKAS FATIH
# 32
# AU=ANDIRAN FATIH
# 10
# AU=AY FATIH
# 0
# AU=AYDOGAN FATIH
# 85
# AU=BAYANSAL FATIH
# 7
# AU=BAYRAM FATIH
# 10
# AU=BOLAT FATIH
# 22
# AU=CAN FATIH
# 5
# AU=DEMIRCI FATIH
# 91
# AU=DEMIRCIOGLU FATIH
# 37
# AU=EKICI FATIH
# 17
# AU=ERBAY FATIH
# 1
# AU=ERMIS FATIH
# 38
# AU=FIRINCI FATIH
# 28
# AU=GURSUL FATIH
# 2
# AU=HATTATOGLU FATIH
# 3
# AU=KANTARCI FATIH
# 81
# AU=KARAKAS FATIH
# 7
# AU=KARAOSMANOGLU FATIH
# 0
# AU=KAYA FATIH
# 27
# AU=KAYHAN FATIH
# 30
# AU=KIRAC FATIH
# 0
# AU=KOC FATIH
# 87
# AU=KOCTURK FATIH
# 1
# AU=KURNAZ FATIH
# 28
# AU=BINNETOGLU FATIH
# 21
# AU=ADIBELLI FATIH
# 10
# AU=TURKCU FATIH
# 69
# AU=TURKER FATIH
# 3
# AU=MUTLU FATIH
# 73
# AU=DURAN FATIH
# 0
# AU=SEFIL FATIH
# 28
# AU=SIVRIKAYA FATIH
# 25
# AU=TEMIZTURK FATIH
# 4
# AU=TUFAN FATIH
# 83
# AU=YAR FATIH
# 0
# AU=YAGMUR FATIH
# 14
# AU=YILDIRIM FATIH
# 9
# AU=YILDIZ FATIH
# 65
# AU=YUKSEL FATIH
# 17
# AU=CELEBIOGLU FATIH
# 3
# AU=CELENK FATIH
# 33
# AU=CELIK FATIH
# 54
# AU=CELIK FATIH
# 54
# AU=CERMIK FATIH
# 0
# AU=COSKUN FATIH
# 9
# AU=COMEZ FATIH
# 0
# AU=OZAN FATIH
# 17
# AU=OZBAY FATIH
# 15
# AU=OZTURK FATIH
# 7
# AU=OCAL FATIH
# 9
# AU=OGRETMEN FATIH
# 21
# AU=ILKAYA FATIH
# 23
# AU=IMAT FATIH
# 1
# AU=SAHPAZ FATIH
# 7
# AU=SENOL FAZIL
# 0
# AU=OMUR FAIK
# 0
# AU=AKIN FEHMI
# 0
# AU=AKCABAY FEHMIYE
# 0
# AU=ARMUTCU FERAH
# 43
# AU=YAMAN FERDA
# 6
# AU=BULBUL FERDI
# 0
# AU=GOKSEL FERDI
# 22
# AU=KARABUGA FERHAN
# 0
# AU=YAMAN FERHAN
# 22
# AU=ASLAN FERHAT
# 23
# AU=OZGEN FERHAT
# 0
# AU=BOZKUS FERHAT
# 13
# AU=BULBUL FERHAT
# 13
# AU=CELEP FERHAT
# 53
# AU=DIKBIYIK FERHAT
# 29
# AU=ENSAR FERHAT
# 0
# AU=GOKMEN FERHAT
# 42
# AU=TASKIN FERHAT
# 11
# AU=OZMAN FERHAT
# 0
# AU=TANIK FERIDE
# 9
# AU=BULBUL FERIDUN
# 40
# AU=FICICI FERIT
# 18
# AU=SONMEZ FERIT
# 6
# AU=KARABIBER FETHULLAH
# 21
# AU=KENAR FETHULLAH
# 11
# AU=TULUBAS FETI
# 26
# AU=SARITAS FEVZI
# 1
# AU=YILDIZ FEYYAZ
# 0
# AU=ONDER FEYYAZ
# 3
# AU=EKSI FEYZETTIN
# 0
# AU=UYGUR FIRAT
# 18
# AU=MENGELOGLU FIRAT
# 12
# AU=CELIK FIRAT
# 0
# AU=AHMETOGLU FUAT
# 13
# AU=BOYACIOGLU FUAT
# 2
# AU=KARAKAYA FUAT
# 8
# AU=LEBE FUAT
# 3
# AU=OZDINC FUAT
# 0
# AU=ATACAN FULYA
# 1
# AU=KENTLI FULYA
# 6
# AU=DOGRUEL FULYA
# 2
# AU=CATIR FULYA
# 0
# AU=OZDEMIR FUNDA
# 27
# AU=BIRDAL FURKAN
# 0
# AU=DINCER FURKAN
# 58
# AU=AYDOGAN FUSUN
# 10
# AU=SAHIN FIGEN
# 64
# AU=KOCYIGIT FIGEN
# 19
# AU=SELIMOGLU FIGEN
# 0
# AU=TASER FIGEN
# 12
# AU=ELMA FIKRET
# 0
# AU=KOCABAS FIKRET
# 12
# AU=KUYUCU FIKRET
# 1
# AU=MAZI FIKRET
# 0
# AU=UYAR FIKRET
# 9
# AU=DEMIR FIKRI
# 28
# AU=CEVIK FILIZ
# 2
# AU=OZDEMIR FILIZ
# 52
# AU=OZDEMIROGLU FILIZ
# 10
# AU=OZKAN FILIZ
# 16
# AU=IYIDIL FILIZ
# 0
# AU=CETIN FIRDEVS
# 0
# AU=SONMEZGOZ FITNET
# 10
# AU=OTURANC GALIP
# 8
# AU=CAG GALIP
# 0
# AU=YUCEL GERCEK
# 0
# AU=OZKUK GOKAN
# 0
# AU=ALPAK GOKAY
# 33
# AU=ERBAG GOKHAN
# 22
# AU=KARS GOKHAN
# 11
# AU=KUTLAR GOKHAN
# 8
# AU=SERIN GOKHAN
# 1
# AU=DEMIR GOKHAN
# 71
# AU=OZDAMAR GOKHAN
# 0
# AU=BILGILI GOKMEN
# 7
# AU=AKPINAR GOKSAN
# 3
# AU=ERDEN GONUL
# 46
# AU=SARI GOZDE
# 11
# AU=DEMIR GOZDE
# 0
# AU=SEN GUL
# 2
# AU=PINAR GUL
# 23
# AU=OZPINAR GUL
# 9
# AU=BULUT GULAY
# 64
# AU=YUCEKAYA GULAY
# 0
# AU=OZKECECI GULAY
# 22
# AU=CILGI GULBANU
# 12
# AU=SARICI GULBEN
# 1
# AU=OZATAGAN GULDEM
# 3
# AU=AKIN GULDEN
# 1
# AU=KOKEN GULEN
# 0
# AU=KAMAK GULEN
# 3
# AU=KOCA GULER
# 2
# AU=TOK GULER
# 0
# AU=YAVUZ GULER
# 4
# AU=GULER GULNUR
# 46
# AU=OZGUNER GULNUR
# 10
# AU=DOGAN GULNIHAL
# 5
# AU=ADAKLI GULSEREN
# 0
# AU=PAMUK GULSUM
# 57
# AU=INCE GULSUM
# 1
# AU=OZYALVACLI GULZADE
# 24
# AU=DOGANLI GULUMSER
# 5
# AU=ASIK GULSAH
# 25
# AU=KAYIKCI GULSEN
# 0
# AU=KURSUN GUNAL
# 0
# AU=ASAN GUNES
# 0
# AU=TURGUT GUNFER
# 30
# AU=AY GUNGOR
# 2
# AU=SOBACI GUNGOR
# 60
# AU=BAHADIR GURHAN
# 0
# AU=GUNDUZ GURHAN
# 4
# AU=ACAR GURKAN
# 49
# AU=ALTAN GURKAN
# 10
# AU=GAZIOGLU GURKAN
# 7
# AU=SAKAR GURKAN
# 2
# AU=ACARTURK GURSEL
# 28
# AU=DUZENLI GURSEL
# 4
# AU=MERIC GURSOY
# 0
# AU=BAKIREZER GUVEN
# 1
# AU=TEKBAS GUVEN
# 38
# AU=SEKER GUVEN
# 0
# AU=AYNALI GIRAY
# 16
# AU=EMRE HABIB
# 21
# AU=OZDEMIR HABIB
# 0
# AU=KALKAN HABIL
# 25
# AU=EROGLU HABIP
# 8
# AU=AYDOGMUS HACER
# 2
# AU=SEN HACER
# 32
# AU=TASPINAR HACI
# 0
# AU=AKTAS HACI
# 8
# AU=ATA HACI
# 0
# AU=CETINKARA HACI
# 5
# AU=BAYKARA HACI
# 15
# AU=SOY HACI
# 0
# AU=TOSUN HACI
# 20
# AU=YILMAZ HACI
# 6
# AU=KAYMAZ HACI
# 4
# AU=TASCI HACI
# 0
# AU=SAHIN HACI
# 29
# AU=EMUL HACI
# 4
# AU=SAGDIK HACI
# 22
# AU=CAKMAK HACI
# 2
# AU=DEMIR HACI
# 52
# AU=TURKMEN HAFIZE
# 2
# AU=AKIN HAKAN
# 62
# AU=AKCAY HAKAN
# 6
# AU=ALTINTAS HAKAN
# 3
# AU=ALTUN HAKAN
# 0
# AU=AYDOGAN HAKAN
# 15
# AU=BAKAN HAKAN
# 0
# AU=BAYIR HAKAN
# 14
# AU=BASARAN HAKAN
# 6
# AU=BOLAT HAKAN
# 4
# AU=BOYACI HAKAN
# 7
# AU=BUYUKHATIPOGLU HAKAN
# 70
# AU=BUYUKOGLAN HAKAN
# 29
# AU=DEMIRBOGA HAKAN
# 0
# AU=DEMIRTAS HAKAN
# 78
# AU=DEGIRMENCI HAKAN
# 0
# AU=DOGAN HAKAN
# 76
# AU=GENCHELLAC HAKAN
# 27
# AU=HEKIM HAKAN
# 2
# AU=KAPTAN HAKAN
# 3
# AU=AKMAZ HAKAN
# 4
# AU=MERTCAN HAKAN
# 0
# AU=OFLAZ HAKAN
# 13
# AU=SARMAN HAKAN
# 18
# AU=SEVINDIK HAKAN
# 1
# AU=SOYUT HAKAN
# 11
# AU=TANRIVERDI HAKAN
# 22
# AU=TURAN HAKAN
# 66
# AU=ULUCAN HAKAN
# 12
# AU=UZUN HAKAN
# 37
# AU=YAMAN HAKAN
# 42
# AU=YAMAN HAKAN
# 42
# AU=CALIS HAKAN
# 6
# AU=CATLIOGLU HAKAN
# 13
# AU=CETIN HAKAN
# 16
# AU=CETINEL HAKAN
# 15
# AU=OZHAN HAKAN
# 69
# AU=OZKOKELI HAKAN
# 0
# AU=SARI HAKAN
# 15
# AU=SAHIN HAKAN
# 28
# AU=SANDIR HAKAN
# 3
# AU=FINDIK HAKKI
# 0
# AU=GOKBEL HAKKI
# 35
# AU=SARNEL HALDUN
# 5
# AU=BORAZAN HALE
# 17
# AU=SAVAS HALUK
# 91
# AU=CEYLAN HALUK
# 12
# AU=SOYLEMEZ HALUK
# 97
# AU=PEKTEZEL HALID
# 1
# AU=AKMAN HALIL
# 0
# AU=AYKUL HALIL
# 9
# AU=BEYDILLI HALIL
# 18
# AU=BILECEN HALIL
# 0
# AU=KUNT HALIL
# 2
# AU=OZLER HALIL
# 3
# AU=SEN HALIL
# 24
# AU=TOSUN HALIL
# 13
# AU=UCAL HALIL
# 0
# AU=YILDIRIM HALIL
# 11
# AU=CALISKAN HALIL
# 14
# AU=CETIN HALIL
# 3
# AU=OZGUNER HALIL
# 3
# AU=BAHAR HALIL
# 1
# AU=DEMIRCI HALIL
# 2
# AU=ESKIKURT HALIL
# 5
# AU=HALILOGLU HALIL
# 3
# AU=KILINC HALIL
# 15
# AU=OKUTAN HALIL
# 0
# AU=TANC HALIL
# 0
# AU=ONDER HALIL
# 66
# AU=UNAL HALIL
# 54
# AU=INAN HALIL
# 7
# AU=SAHAN HALIL
# 23
# AU=SAHMAN HALIL
# 8
# AU=SIMSEK HALIL
# 11
# AU=AKBULUT HALIM
# 0
# AU=KORUCU HALIM
# 0
# AU=NALIN HALIME
# 0
# AU=BORAN HALIS
# 18
# AU=CANATAN HALIT
# 31
# AU=KARACA HALIT
# 73
# AU=ZENGIN HALIT
# 26
# AU=CICEK HALIT
# 2
# AU=AKCAKOCA HAMDI
# 3
# AU=AYDIN HAMDI
# 10
# AU=KAMCI HAMDI
# 0
# AU=SOZEN HAMDI
# 21
# AU=TUTKUN HAMDI
# 3
# AU=TOSUN HAMZA
# 0
# AU=UZUM HAMZA
# 0
# AU=ACEMOGLU HAMIT
# 39
# AU=MERMERKAYA HAMIT
# 0
# AU=OKUR HAMIT
# 11
# AU=PALABIYIK HAMIT
# 0
# AU=UNAL HAMIYET
# 17
# AU=CIPIL HANDAN
# 9
# AU=USTUNDAG HANDAN
# 3
# AU=GURSES HANDE
# 1
# AU=TOPAL HANIFE
# 0
# AU=BINICI HANIFI
# 45
# AU=KURT HANIFI
# 1
# AU=SARAC HANIFI
# 11
# AU=ANAY HARUN
# 1
# AU=AYDOGAN HARUN
# 17
# AU=BAYRAKDAR HARUN
# 6
# AU=EVRENGUL HARUN
# 56
# AU=KAYA HARUN
# 12
# AU=KUCUK HARUN
# 6
# AU=YAZAR HARUN
# 12
# AU=TOY HARUN
# 22
# AU=YENICERI HARUN
# 1
# AU=YILDIZ HARUN
# 24
# AU=YILMAZ HARUN
# 18
# AU=YUKSEL HARUN
# 60
# AU=CIRALIK HARUN
# 42
# AU=COBAN HARUN
# 6
# AU=SIMSEK HARUN
# 3
# AU=DELIGOZ HASALETTIN
# 28
# AU=ABDIOGLU HASAN
# 3
# AU=ACAR HASAN
# 35
# AU=AKCA HASAN
# 7
# AU=ALLI HASAN
# 14
# AU=YUKSEKKAYA HASAN
# 29
# AU=ATIK HASAN
# 7
# AU=AYDIN HASAN
# 112
# AU=BABACAN HASAN
# 22
# AU=BAL HASAN
# 14
# AU=ERTAS HASAN
# 25
# AU=ULUSOY HASAN
# 40
# AU=BAYRAKTAR HASAN
# 3
# AU=BOZKURT HASAN
# 30
# AU=BUKER HASAN
# 5
# AU=BUYUKASLAN HASAN
# 14
# AU=BILINC HASAN
# 13
# AU=EKER HASAN
# 31
# AU=ELLEK HASAN
# 0
# AU=ERDOGAN HASAN
# 50
# AU=ERDOGAN HASAN
# 50
# AU=ERTAS HASAN
# 25
# AU=ERCELIK HASAN
# 0
# AU=EROL HASAN
# 2
# AU=GOK HASAN
# 35
# AU=GUNGOR HASAN
# 59
# AU=ULUTIN HASAN
# 0
# AU=DULGER HASAN
# 1
# AU=HERKEN HASAN
# 65
# AU=KART HASAN
# 3
# AU=KOSGER HASAN
# 0
# AU=SATILMIS HASAN
# 6
# AU=YURTCU HASAN
# 1
# AU=CALI HASAN
# 0
# AU=CEVIK HASAN
# 3
# AU=OZDEMIR HASAN
# 82
# AU=YUCE HASAN
# 23
# AU=KAFALI HASAN
# 52
# AU=KALA HASAN
# 0
# AU=KAMAK HASAN
# 11
# AU=KAPLAN HASAN
# 26
# AU=KARACAN HASAN
# 0
# AU=KARAKURT HASAN
# 3
# AU=KAYA HASAN
# 155
# AU=KURT HASAN
# 15
# AU=METINEREN HASAN
# 11
# AU=MUTLU HASAN
# 83
# AU=OZER HASAN
# 59
# AU=SARAL HASAN
# 7
# AU=GERGERLIOGLU HASAN
# 15
# AU=TAK HASAN
# 1
# AU=ATMACA HASAN
# 26
# AU=TURKMEN HASAN
# 14
# AU=UCMAK HASAN
# 18
# AU=YILDI HASAN
# 0
# AU=YILDIZHAN HASAN
# 6
# AU=YUMAK HASAN
# 8
# AU=CANKAYA HASAN
# 0
# AU=CEVIKOGLU HASAN
# 0
# AU=CECE HASAN
# 47
# AU=CINAR HASAN
# 1
# AU=OZTURK HASAN
# 74
# AU=ULKER HASAN
# 5
# AU=IBICIOGLU HASAN
# 0
# AU=MUTAF HASAN
# 1
# AU=ASLAN HASBI
# 0
# AU=KARA HATIBE
# 4
# AU=CANSUNAR HATICE
# 3
# AU=BALABAN HATICE
# 20
# AU=CAN HATICE
# 37
# AU=AKIN HATICE
# 0
# AU=SENOGUZ HATICE
# 1
# AU=SEZAN HATICE
# 0
# AU=TEBER HATICE
# 0
# AU=TOY HATICE
# 68
# AU=YESILDAL HATICE
# 0
# AU=YUKSEL HATICE
# 50
# AU=AKBAS HATICE
# 5
# AU=INAN HATICE
# 16
# AU=OZBILGE HATICE
# 17
# AU=AYDIN HATIP
# 20
# AU=YILMAZ HAUDAI
# 0
# AU=YILMAZ HAVA
# 28
# AU=SAHIN HAVANUR
# 0
# AU=EVRENGUL HAVVA
# 22
# AU=KOCA HAVVA
# 0
# AU=YAMAN HAVVA
# 6
# AU=DEMIRASLAN HAYATI
# 30
# AU=GUNES HAYATI
# 15
# AU=KANDIS HAYATI
# 50
# AU=SINIR HAYATI
# 3
# AU=SEKER HAYATI
# 6
# AU=UCAK HAYDAR
# 29
# AU=EROGLU HAYRETTIN
# 13
# AU=TUNCEL HAYRETTIN
# 0
# AU=CETIN HAYRULLAH
# 1
# AU=UN HAYRI
# 1
# AU=KARABULUT HAYRIYE
# 40
# AU=YILMAZ HAYRIYE
# 9
# AU=YILMAZ HASIM
# 20
# AU=DAVAS HEDIYE
# 0
# AU=ULVI HIZIR
# 21
# AU=COKADAR HULUSI
# 9
# AU=HATIPOGLU HURISEL
# 0
# AU=CAN HUDAYI
# 0
# AU=KIZILTUNC HUKMI
# 19
# AU=AKSOY HULYA
# 36
# AU=ELIBUYUK HULYA
# 0
# AU=GOKNAR HULYA
# 0
# AU=OGELMAN HULYA
# 14
# AU=OZDINC HULYA
# 1
# AU=KOYUNCU HULYA
# 3
# AU=BURUCU HUMEYRA
# 0
# AU=CAN HUMEYRA
# 1
# AU=BICICI HUR
# 0
# AU=AKYUZOGLU HUSEYIN
# 0
# AU=AKCAY HUSEYIN
# 55
# AU=ALKIS HUSEYIN
# 17
# AU=ALPSOY HUSEYIN
# 0
# AU=ALTAY HUSEYIN
# 3
# AU=ASLAN HUSEYIN
# 49
# AU=ASLAN HUSEYIN
# 49
# AU=ATALAY HUSEYIN
# 39
# AU=BARGAN HUSEYIN
# 0
# AU=BAYRAMLAR HUSEYIN
# 50
# AU=BAGCI HUSEYIN
# 13
# AU=BEGENIK HUSEYIN
# 27
# AU=BULGURCU HUSEYIN
# 2
# AU=KAYHAN HUSEYIN
# 0
# AU=CAN HUSEYIN
# 33
# AU=TURGUT HUSEYIN
# 33
# AU=CINOGLU HUSEYIN
# 0
# AU=DAS HUSEYIN
# 3
# AU=ERISIK HUSEYIN
# 0
# AU=ERTAS HUSEYIN
# 33
# AU=ERTUC HUSEYIN
# 0
# AU=ERTIK HUSEYIN
# 6
# AU=ESEN HUSEYIN
# 7
# AU=GOKTEPE HUSEYIN
# 10
# AU=GUMUS HUSEYIN
# 8
# AU=KAVAS HUSEYIN
# 12
# AU=KAYA HUSEYIN
# 43
# AU=KORKMAZ HUSEYIN
# 67
# AU=KURT HUSEYIN
# 43
# AU=OFLAZ HUSEYIN
# 75
# AU=POLAT HUSEYIN
# 65
# AU=KUYUK HUSEYIN
# 3
# AU=SIMAVLI HUSEYIN
# 29
# AU=TOMAN HUSEYIN
# 25
# AU=UYSAL HUSEYIN
# 11
# AU=UYSAL HUSEYIN
# 11
# AU=YAZICI HUSEYIN
# 25
# AU=VAROL HUSEYIN
# 44
# AU=YAMAN HUSEYIN
# 31
# AU=YASAR HUSEYIN
# 10
# AU=ZENGIN HUSEYIN
# 38
# AU=OKSUZ HUSEYIN
# 23
# AU=ONEN HUSEYIN
# 9
# AU=OZDEMIR HUSEYIN
# 66
# AU=OZYURT HUSEYIN
# 53
# AU=IMREK HUSEYIN
# 10
# AU=GONEL HUSEIN
# 0
# AU=GUDER HUSNU
# 3
# AU=DEMIRULUS HUSREV
# 2
# AU=BAKKAL HIDAYET
# 0
# AU=ERDOGAN HIDAYET
# 24
# AU=CIGLIK HIKMET
# 0
# AU=BOZOGLAN HILAL
# 1
# AU=OZEN HILAL
# 6
# AU=ALTINYAZAR HILMI
# 10
# AU=ERGOREN HILMI
# 7
# AU=KIRLIOGLU HILMI
# 0
# AU=SUNGU HILMI
# 5
# AU=YAZICI HILMI
# 7
# AU=KORKMAZ HIMMET
# 3
# AU=AKDOGAN ILGAZ
# 11
# AU=DAVARCI ISIL
# 20
# AU=DIRLIKYAPAN JALE
# 1
# AU=MERAL KADEM
# 52
# AU=ERDEN KADRIYE
# 5
# AU=AKSAY KADIR
# 1
# AU=ALPER KADIR
# 0
# AU=AGLADIOGLU KADIR
# 32
# AU=BASER KADIR
# 0
# AU=CEYLAN KADIR
# 21
# AU=DUNDAR KADIR
# 6
# AU=GEDIK KADIR
# 19
# AU=GUMRAH KADIR
# 0
# AU=KAN KADIR
# 1
# AU=KARAKUS KADIR
# 30
# AU=KIRKBOGA KADIR
# 0
# AU=PAKSOY KADIR
# 0
# AU=PEKER KADIR
# 7
# AU=TAN KADIR
# 0
# AU=CEYHANLI KADIR
# 10
# AU=TUZLAK KADIR
# 0
# AU=YILMAZ KADIR
# 40
# AU=YILDIRIM KADIR
# 73
# AU=YILDIZ KADIR
# 12
# AU=YERDELEN KADIR
# 17
# AU=ISA KADIR
# 1
# AU=SARI KAMRAN
# 6
# AU=AYDIN KAMIL
# 13
# AU=AYDIN KAMIL
# 13
# AU=KUCUKYILMAZ KAMIL
# 12
# AU=SEYREK KAMIL
# 25
# AU=TUNAY KAMIL
# 9
# AU=KOSE KAMIL
# 38
# AU=OZDIN KAMIL
# 3
# AU=AKBAS KASIM
# 1
# AU=KARAGOZ KASIM
# 0
# AU=TUZCU KASIM
# 20
# AU=CAGLAYA KASIM
# 0
# AU=GULEZ KAYHAN
# 54
# AU=MENEMENCIOGLU KAYHAN
# 3
# AU=INCE KAYHAN
# 3
# AU=KESLIOGLU KAZIM
# 21
# AU=SARICI KAZIM
# 0
# AU=GUMUS KAZIM
# 21
# AU=BESIRLI KAZIM
# 18
# AU=DEVELIOGLU KAZIM
# 1
# AU=UCOK KAGAN
# 27
# AU=ATIK KEMAL
# 7
# AU=BASLAR KEMAL
# 0
# AU=EKICI KEMAL
# 11
# AU=HACIEFENDIOGLU KEMAL
# 22
# AU=TURKYILMAZ KEMAL
# 22
# AU=ZORBAZ KEMAL
# 1
# AU=COMAKLI KEMAL
# 10
# AU=ORNEK KEMAL
# 48
# AU=INAL KEMAL
# 1
# AU=SAHIN KEMAL
# 12
# AU=BULUT KENAN
# 0
# AU=CANTEKIN KENAN
# 28
# AU=GUMUSTEKIN KENAN
# 22
# AU=KAYISIZ KENAN
# 0
# AU=MELEMEZ KENAN
# 10
# AU=UCAN KENAN
# 3
# AU=COYAN KENAN
# 18
# AU=IZGI KENAN
# 28
# AU=YANIK KERAMETTIN
# 38
# AU=OK KEREM
# 12
# AU=COSKUN KEREM
# 24
# AU=USTA KEZIBAN
# 7
# AU=YUCEL KIVILCIM
# 1
# AU=KOCOGLU KIYASETTIN
# 1
# AU=GEZER KUTRET
# 4
# AU=LORDOGLU KUVVET
# 0
# AU=CEYHAN KOKSAL
# 47
# AU=GULTEKIN KUBRA
# 0
# AU=CINAR KUBRA
# 1
# AU=OZKUL KUBRA
# 3
# AU=AGPAK KURSAD
# 13
# AU=ORAL KURSAT
# 14
# AU=YAYKASLI KURSAT
# 32
# AU=SOLAK KURSAT
# 2
# AU=UZUN KURSAT
# 11
# AU=KAHVECI KUCUK
# 0
# AU=AKYUZ LATIFE
# 0
# AU=CANTEK LAIKA
# 0
# AU=AKIN LEMI
# 0
# AU=AKKAYA LEVENT
# 18
# AU=ALTINEL LEVENT
# 34
# AU=GURBUZLER LEVENT
# 22
# AU=KARA LEVENT
# 69
# AU=AKTURK LEVENT
# 0
# AU=BAYAR LEVENT
# 1
# AU=SEVI LEVENT
# 1
# AU=YAZMALAR LEVENT
# 29
# AU=ONAL LEVENT
# 12
# AU=UNSALDI LEVENT
# 0
# AU=SAHIN LEVENT
# 51
# AU=SIMSEK LEVENT
# 0
# AU=UNAL LEYLA
# 0
# AU=AYDIN LEYLA
# 44
# AU=RATHKE LEYLA
# 0
# AU=SAHAN LEYLA
# 9
# AU=ASLAN LOKMAN
# 22
# AU=ERDEMIR LOKMAN
# 0
# AU=KARAKURT LOKMAN
# 15
# AU=KAYCI LOKMAN
# 6
# AU=SOYORAL LOKMAN
# 10
# AU=VARISLI LOKMAN
# 13
# AU=USTYOL LOKMAN
# 20
# AU=YAVUZ LUTFULLAH
# 0
# AU=CAKIR LUTFULLAH
# 6
# AU=GENC LUTFI
# 15
# AU=OZCAN LUTFI
# 0
# AU=OZEL LUTFI
# 10
# AU=YARGIC LUTFI
# 1
# AU=KAYA LILUFER
# 0
# AU=CHIFANE LIVIU-AUGUSTIN
# 1
# AU=ERCEVAHIR MACIT
# 0
# AU=BASTURK MAHMET
# 0
# AU=ABUHANDAN MAHMUT
# 27
# AU=AKYOL MAHMUT
# 9
# AU=ALPAYCI MAHMUT
# 24
# AU=ARABUL MAHMUT
# 34
# AU=AYPEK MAHMUT
# 0
# AU=BIRGUN MAHMUT
# 0
# AU=BUYUKBOZDUGAN MAHMUT
# 0
# AU=YILDIZ MAHMUT
# 2
# AU=DAGLI MAHMUT
# 0
# AU=DASCI MAHMUT
# 16
# AU=DEMIRTAS MAHMUT
# 21
# AU=DUYMUS MAHMUT
# 38
# AU=GUZEL MAHMUT
# 6
# AU=KOCAK MAHMUT
# 1
# AU=NALBANTCILAR MAHMUT
# 3
# AU=ULUSOY MAHMUT
# 51
# AU=YALCIN MAHMUT
# 3
# AU=YENER MAHMUT
# 22
# AU=ZKAN MAHMUT
# 0
# AU=OZDEVECIOGLU MAHMUT
# 5
# AU=ULESIN MAHMUT
# 0
# AU=INANC MAHMUT
# 0
# AU=SEKER MAHMUT
# 5
# AU=ALKAN MAHIR
# 59
# AU=ERKURAN MANSUR
# 4
# AU=NART MARUF
# 1
# AU=GOK MAIDE
# 1
# AU=AYHAN MEDIHA
# 8
# AU=CURE MEDINE
# 51
# AU=KARA MEDINE
# 6
# AU=PAKDEMIRLI MEFKURE
# 0
# AU=YEKSAN MEHDI
# 21
# AU=AKBULAK MEHMET
# 7
# AU=AKBULUT MEHMET
# 80
# AU=AKIN MEHMET
# 99
# AU=AKKOSE MEHMET
# 14
# AU=AKSOY MEHMET
# 97
# AU=AKTAS MEHMET
# 157
# AU=CEVIZ MEHMET
# 6
# AU=DOKUZOGLU MEHMET
# 4
# AU=KILAVUZ MEHMET
# 0
# AU=KUTUK MEHMET
# 32
# AU=KUTUKCU MEHMET
# 2
# AU=SARICA MEHMET
# 14
# AU=CECEN MEHMET
# 3
# AU=CUKURCAYIR MEHMET
# 0
# AU=ALACALI MEHMET
# 1
# AU=SOZER MEHMET
# 1
# AU=BASTURK MEHMET
# 5
# AU=BALKANLIOGLU MEHMET
# 1
# AU=ELBEY MEHMET
# 28
# AU=EROGLU MEHMET
# 58
# AU=SEVEN MEHMET
# 28
# AU=SOGUT MEHMET
# 15
# AU=UCAR MEHMET
# 70
# AU=CALGAN MEHMET
# 1
# AU=ARDICLIOGLU MEHMET
# 11
# AU=ARICAN MEHMET
# 5
# AU=ARSLAN MEHMET
# 223
# AU=ASLANTAS MEHMET
# 13
# AU=ASMALI MEHMET
# 2
# AU=CEBE MEHMET
# 9
# AU=BUYUKGUCLU MEHMET
# 0
# AU=AVCI MEHMET
# 30
# AU=AYAN MEHMET
# 0
# AU=ASKIN MEHMET
# 9
# AU=ACAT MEHMET
# 0
# AU=BAYINDIR MEHMET
# 77
# AU=BAYRAM MEHMET
# 70
# AU=BASLAR MEHMET
# 24
# AU=BASOREN MEHMET
# 0
# AU=BOSTAN MEHMET
# 31
# AU=BOSNAK MEHMET
# 23
# AU=BULUT MEHMET
# 119
# AU=KAHYAOGLU MEHMET
# 4
# AU=YUKSEL MEHMET
# 108
# AU=CENGIL MEHMET
# 0
# AU=ERCIN MEHMET
# 2
# AU=CEVRI MEHMET
# 1
# AU=EROGLU MEHMET
# 58
# AU=UNIVERSITYER MEHMET
# 0
# AU=CIVAN MEHMET
# 4
# AU=DALLI MEHMET
# 14
# AU=DAVUTOGLU MEHMET
# 27
# AU=DAYIK MEHMET
# 10
# AU=BULUT MEHMET
# 119
# AU=DEVEER MEHMET
# 18
# AU=DEGERLIYURT MEHMET
# 1
# AU=DURU MEHMET
# 72
# AU=CAMAN MEHMET
# 0
# AU=KALENDER MEHMET
# 76
# AU=KILIC MEHMET
# 154
# AU=KUYUMCU MEHMET
# 38
# AU=KOK MEHMET
# 6
# AU=SAKARYA MEHMET
# 15
# AU=TASDELEN MEHMET
# 72
# AU=YUKSEKKAYA MEHMET
# 18
# AU=OZYALVACLI MEHMET
# 10
# AU=INAL MEHMET
# 34
# AU=SEN MEHMET
# 65
# AU=UNLU MEHMET
# 158
# AU=ERDEM MEHMET
# 182
# AU=ERDOGAN MEHMET
# 193
# AU=EROGLU MEHMET
# 58
# AU=CIFTCI MEHMET
# 88
# AU=ESGIN MEHMET
# 0
# AU=GEYIK MEHMET
# 36
# AU=CATAL MEHMET
# 0
# AU=BARIS MEHMET
# 9
# AU=CANBOLAT MEHMET
# 1
# AU=GARCA MEHMET
# 15
# AU=GUNER MEHMET
# 7
# AU=KARAASLAN MEHMET
# 34
# AU=KARAKAS MEHMET
# 60
# AU=KAYA MEHMET
# 498
# AU=SONMEZ MEHMET
# 200
# AU=CAGLAR MEHMET
# 27
# AU=OZLU MEHMET
# 37
# AU=GOKALP MEHMET
# 9
# AU=GURKAN MEHMET
# 8
# AU=GEDIK MEHMET
# 1
# AU=GESOGLU MEHMET
# 72
# AU=TETIN MEHMET
# 0
# AU=GOKTEPE MEHMET
# 4
# AU=GORAL MEHMET
# 3
# AU=GUL MEHMET
# 212
# AU=GUNAY MEHMET
# 18
# AU=GUNDUZ MEHMET
# 188
# AU=KAYA MEHMET
# 498
# AU=GURBUZ MEHMET
# 31
# AU=SOLAK MEHMET
# 7
# AU=TANRIVERDI MEHMET
# 17
# AU=KIZILCI MEHMET
# 0
# AU=ALTAN MEHMET
# 36
# AU=HAZAR MEHMET
# 0
# AU=ATMACA MEHMET
# 2
# AU=KABA MEHMET
# 21
# AU=KABACIK MEHMET
# 0
# AU=KAHRAMAN MEHMET
# 58
# AU=KANDAZ MEHMET
# 55
# AU=KANTER MEHMET
# 108
# AU=KARAASLAN MEHMET
# 34
# AU=KARABACAK MEHMET
# 60
# AU=KARABIBER MEHMET
# 5
# AU=KARACA MEHMET
# 159
# AU=KARAKIZ MEHMET
# 2
# AU=KARAKOC MEHMET
# 37
# AU=KAYGANA MEHMET
# 0
# AU=KAYRAK MEHMET
# 112
# AU=KASLI MEHMET
# 3
# AU=KARAAGAC MEHMET
# 2
# AU=KIDIR MEHMET
# 0
# AU=KILIC MEHMET
# 154
# AU=KURTULMUS MEHMET
# 1
# AU=KOROGLU MEHMET
# 63
# AU=KIR MEHMET
# 22
# AU=TASLI MEHMET
# 2
# AU=OCAK MEHMET
# 6
# AU=KUCUK MEHMET
# 56
# AU=MELEK MEHMET
# 60
# AU=MERCAN MEHMET
# 10
# AU=METE MEHMET
# 2
# AU=EROL MEHMET
# 43
# AU=RIFAIOGLU MEHMET
# 9
# AU=HAMIDI MEHMET
# 11
# AU=NAM MEHMET
# 0
# AU=NEBIOGLU MEHMET
# 12
# AU=KUMRU MEHMET
# 7
# AU=TURAN MEHMET
# 98
# AU=KANBUR MEHMET
# 1
# AU=OZYURTKAN MEHMET
# 18
# AU=PAKDEMIRLI MEHMET
# 42
# AU=PENCECIOGLU MEHMET
# 0
# AU=HELVACI MEHMET
# 77
# AU=KESICI MEHMET
# 1
# AU=BURUNGUZ MEHMET
# 0
# AU=DEMIRAY MEHMET
# 9
# AU=ERSOY MEHMET
# 39
# AU=AYDIN MEHMET
# 342
# AU=ARBATLI MEHMET
# 0
# AU=ARIK MEHMET
# 79
# AU=SAKCALI MEHMET
# 6
# AU=BAL MEHMET
# 16
# AU=SUBASI MEHMET
# 17
# AU=TAN MEHMET
# 34
# AU=YASEMIN MEHMET
# 2
# AU=TEKKOYUN MEHMET
# 5
# AU=TEKINKUS MEHMET
# 1
# AU=TEMEL MEHMET
# 13
# AU=TERZI MEHMET
# 0
# AU=TETIKOGLU MEHMET
# 21
# AU=GULSOY MEHMET
# 0
# AU=TOK MEHMET
# 0
# AU=TOSUN MEHMET
# 71
# AU=TURMUS MEHMET
# 0
# AU=TUZCU MEHMET
# 119
# AU=SEZER MEHMET
# 108
# AU=TURKELI MEHMET
# 17
# AU=TURKER MEHMET
# 53
# AU=TIKICI MEHMET
# 2
# AU=ULUKAN MEHMET
# 6
# AU=UMRUL MEHMET
# 0
# AU=UYGUN MEHMET
# 3
# AU=UZKUT MEHMET
# 5
# AU=UZUNOGLU MEHMET
# 14
# AU=UZUNOGLU MEHMET
# 14
# AU=PAZARLIOGLU MEHMET
# 1
# AU=VURAL MEHMET
# 74
# AU=YAKUT MEHMET
# 14
# AU=YAMAN MEHMET
# 158
# AU=SEKER MEHMET
# 39
# AU=YAZICI MEHMET
# 125
# AU=YAZICI MEHMET
# 125
# AU=YENITERZI MEHMET
# 27
# AU=YILDIRIM MEHMET
# 300
# AU=YILMAZ MEHMET
# 672
# AU=YILMAZ MEHMET
# 672
# AU=YUCEL MEHMET
# 101
# AU=ZENCIR MEHMET
# 24
# AU=YILMAZ MEHMET
# 672
# AU=CABUK MEHMET
# 26
# AU=CARDAK MEHMET
# 0
# AU=CEBER MEHMET
# 11
# AU=CELIKBILEK MEHMET
# 39
# AU=CETE MEHMET
# 7
# AU=COBAN MEHMET
# 26
# AU=COLAK MEHMET
# 83
# AU=COLAKOGLU MEHMET
# 14
# AU=ONDER MEHMET
# 25
# AU=OZ MEHMET
# 105
# AU=OZBILGIN MEHMET
# 3
# AU=OZCAN MEHMET
# 252
# AU=OZDAMAR MEHMET
# 2
# AU=OZEL MEHMET
# 18
# AU=ULGER MEHMET
# 4
# AU=UNLU MEHMET
# 158
# AU=TURAN MEHMET
# 98
# AU=ILI MEHMET
# 0
# AU=INCI MEHMET
# 86
# AU=SAHIN MEHMET
# 278
# AU=SENEL MEHMET
# 69
# AU=SENGONUL MEHMET
# 5
# AU=SENGUL MEHMET
# 7
# AU=ARSLAN MEHMET
# 223
# AU=IGCI MEHRI
# 27
# AU=KORUCU MEHTAP
# 3
# AU=TATAR MEHTAP
# 10
# AU=YIGIN MEHTAP
# 0
# AU=GURGEN MELAHAT
# 0
# AU=YAMAN MELDA
# 0
# AU=BULUT MELEK
# 1
# AU=GOREGENLI MELEK
# 5
# AU=CETINKAYA MELEK
# 1
# AU=INCI MELEK
# 12
# AU=KARS MELTEM
# 25
# AU=BORUBAN MELIH
# 19
# AU=ERKAN MELIH
# 28
# AU=YUKSEL MELIH
# 11
# AU=BAKIRCI MELIKE
# 0
# AU=SENGUL MELIKE
# 7
# AU=ULU MELIKE
# 21
# AU=ISIK MEMET
# 8
# AU=KILDIRAN MENDERES
# 0
# AU=COSKUN MENDERES
# 3
# AU=MALKOC MERAL
# 17
# AU=CAMCI MERAL
# 0
# AU=GURBUZ MERAL
# 0
# AU=SERVI MERAL
# 0
# AU=SULAK MERAL
# 7
# AU=KURDOGLU MERTIHAN
# 54
# AU=KOIZHAIGANOVA MERUYERT
# 5
# AU=SEKER MERYAM
# 0
# AU=GENCER MERYEM
# 24
# AU=ERYILMAZ MESUR
# 0
# AU=ALBEN MESUT
# 0
# AU=AYDIN MESUT
# 65
# AU=DURAT MESUT
# 5
# AU=ERDAL MESUT
# 0
# AU=ERDURMUS MESUT
# 40
# AU=GARIPARDIC MESUT
# 37
# AU=GORUR MESUT
# 15
# AU=HAZIR MESUT
# 0
# AU=KESKIN MESUT
# 3
# AU=KILIC MESUT
# 18
# AU=KOAN MESUT
# 0
# AU=SIMSEK MESUT
# 24
# AU=KARAYEL METE
# 0
# AU=GUMUS METEHAN
# 43
# AU=AKBULUT METIN
# 50
# AU=AKDAG METIN
# 6
# AU=ALTIOK METIN
# 0
# AU=AYTEKIN METIN
# 21
# AU=DEVECI METIN
# 5
# AU=DIGRAK METIN
# 16
# AU=DOGAN METIN
# 60
# AU=DURU METIN
# 11
# AU=GULER METIN
# 0
# AU=KABA METIN
# 8
# AU=KERTMEN METIN
# 6
# AU=MERIC METIN
# 0
# AU=TEMEL METIN
# 26
# AU=ULUKOY METIN
# 2
# AU=YILMAZ METIN
# 46
# AU=OZTURK METIN
# 32
# AU=OZDEMIR MEVCI
# 22
# AU=TUNC MEVLUNT
# 0
# AU=ARAS MEVLUT
# 4
# AU=DEMIROZU MEVLUT
# 0
# AU=DOGAN MEVLUT
# 37
# AU=KARAOGLU MEVLUT
# 5
# AU=KURT MEVLUT
# 106
# AU=YAPRAK MEVLUT
# 1
# AU=CELIKOGLU MEVLUT
# 62
# AU=IKBAL MEVLUT
# 1
# AU=YILMAZ MHMET
# 0
# AU=OZKAN MUAMMED
# 0
# AU=ALTOK MUAMMER
# 31
# AU=CENGIZ MUAMMER
# 1
# AU=DOGAN MUAMMER
# 11
# AU=GUL MUAMMER
# 0
# AU=KAVANOZ MUAMMER
# 10
# AU=TILKI MUAMMER
# 18
# AU=OZGOREN MUAMMER
# 26
# AU=OZTURK MUAMMER
# 0
# AU=AYVAZ MUAVVIZ
# 6
# AU=GUNGOREN MUAZ
# 1
# AU=CETINER MUAZZEZ
# 0
# AU=HOSNUTER MUBIN
# 13
# AU=ASLAN MUHAMMED
# 10
# AU=AYDIN MUHAMMED
# 35
# AU=ERCETIN MUHAMMED
# 0
# AU=ATILA MUHAMMED
# 0
# AU=TURAN MUHAMMED
# 3
# AU=KIZILTUNC MUHAMMED
# 0
# AU=OZLEN MUHAMMED
# 0
# AU=DEMIR MUHAMMED
# 9
# AU=OYLUMLU MUHAMMED
# 24
# AU=SARIKAYA MUHAMMED
# 0
# AU=BAYINDIR MUHAMMED
# 0
# AU=KIR MUHAMMED
# 0
# AU=CINKAYA MUHAMMED
# 1
# AU=CICEK MUHAMMED
# 7
# AU=KARA MUHAMMED
# 9
# AU=AKAYDIN MUHAMMET
# 8
# AU=ALTUNOK MUHAMMET
# 7
# AU=DURAN MUHAMMET
# 1
# AU=ARIK MUHAMMET
# 4
# AU=CERIT MUHAMMET
# 9
# AU=DERVISOGLU MUHAMMET
# 21
# AU=KOSE MUHAMMET
# 67
# AU=ALKAYIS MUHAMMET
# 0
# AU=GENC MUHAMMET
# 0
# AU=CINSDIKICI MUHAMMET
# 0
# AU=ISIKLAN MUHAMMET
# 11
# AU=CAYCI MUHAMMET
# 3
# AU=KOCAK MUHAMMET
# 3
# AU=KUZUBAS MUHAMMET
# 0
# AU=KOKSAL MUHAMMET
# 13
# AU=ARSLAN MUHAMMET
# 14
# AU=SERVI MUHAMMET
# 0
# AU=USAK MUHAMMET
# 59
# AU=YALCIN MUHAMMET
# 13
# AU=KAHRAMAN MUHAMMET
# 1
# AU=AKSU MUHAMMET
# 19
# AU=SAKIROGLU MUHAMMET
# 18
# AU=PAKSU MUHAMMET
# 26
# AU=AKSU MUHARREM
# 0
# AU=AKTAS MUHARREM
# 8
# AU=AKTUMEN MUHARREM
# 2
# AU=DURAN MUHARREM
# 3
# AU=GENCTURK MUHARREM
# 0
# AU=KAYA MUHARREM
# 50
# AU=KAYA MUHARREM
# 50
# AU=VAROL MUHARREM
# 1
# AU=YILDIZ MUHARREM
# 3
# AU=INAN MUHARREM
# 31
# AU=UYAR MUHEMMET
# 6
# AU=BAGDIGEN MUHLIS
# 1
# AU=CAN MUHLIS
# 11
# AU=SARIDEDE MUHLIS
# 16
# AU=SAVAS MUHMMET
# 0
# AU=CELIK MUHSIN
# 5
# AU=OZDEM MUHSIN
# 5
# AU=OZDEMIR MUHSIN
# 32
# AU=BAGCI MUHIDDIN
# 8
# AU=AKUL MUHITTIN
# 0
# AU=KARAKAYA MUHITTIN
# 0
# AU=ASLANKURT MURAT
# 29
# AU=ATAR MURAT
# 84
# AU=ATES MURAT
# 80
# AU=ATIK MURAT
# 0
# AU=ATIS MURAT
# 18
# AU=AYAN MURAT
# 12
# AU=AYDEMIR MURAT
# 91
# AU=AYDIN MURAT
# 172
# AU=AYDIN MURAT
# 172
# AU=AYDIN MURAT
# 172
# AU=BAKIS MURAT
# 2
# AU=BALCI MURAT
# 30
# AU=BAGLIBEL MURAT
# 4
# AU=BIRICIK MURAT
# 10
# AU=CANKURT MURAT
# 11
# AU=DAMAR MURAT
# 20
# AU=DOGAN MURAT
# 163
# AU=DUNDAR MURAT
# 32
# AU=DIRLIKLI MURAT
# 2
# AU=EMEKSIZ MURAT
# 2
# AU=ERDOGAN MURAT
# 74
# AU=ERDURAN MURAT
# 8
# AU=ERSOZ MURAT
# 54
# AU=GORGULU MURAT
# 10
# AU=GUNAYDIN MURAT
# 54
# AU=HOKELEK MURAT
# 22
# AU=YARIKTAS MURAT
# 13
# AU=KAHVECI MURAT
# 3
# AU=KAPAN MURAT
# 40
# AU=KAPSIZ MURAT
# 5
# AU=KARA MURAT
# 164
# AU=KARAGOZ MURAT
# 6
# AU=KARAGOZ MURAT
# 6
# AU=KARAHAN MURAT
# 13
# AU=KARCIOGLU MURAT
# 20
# AU=KAYA MURAT
# 173
# AU=KECE MURAT
# 3
# AU=KIZIL MURAT
# 32
# AU=KOYUNCU MURAT
# 45
# AU=KUCUKTUFEKCI MURAT
# 0
# AU=KIRACI MURAT
# 0
# AU=NAVRUZ MURAT
# 1
# AU=OKTAY MURAT
# 32
# AU=ORTANCA MURAT
# 0
# AU=SARI MURAT
# 78
# AU=SARITEMUR MURAT
# 19
# AU=SAVAS MURAT
# 53
# AU=SAYILI MURAT
# 11
# AU=SEVER MURAT
# 5
# AU=SEVINC MURAT
# 3
# AU=SEVINC MURAT
# 3
# AU=SEYMEN MURAT
# 0
# AU=TURNA MURAT
# 0
# AU=ULUDAG MURAT
# 36
# AU=UYSAL MURAT
# 258
# AU=YANIK MURAT
# 1
# AU=YILDAR MURAT
# 12
# AU=YILDIZ MURAT
# 35
# AU=YILDIZ MURAT
# 35
# AU=YUCE MURAT
# 65
# AU=YUCE MURAT
# 65
# AU=YUKSEL MURAT
# 168
# AU=CAKIROGLU MURAT
# 14
# AU=CAGLAROGLU MURAT
# 9
# AU=CELEBI MURAT
# 0
# AU=CITIR MURAT
# 30
# AU=COBANER MURAT
# 27
# AU=COSAR MURAT
# 78
# AU=CIMENCAN MURAT
# 7
# AU=OZBAY MURAT
# 0
# AU=OZEL MURAT
# 19
# AU=OZOGLU MURAT
# 5
# AU=OZSARAC MURAT
# 10
# AU=OZSAKER MURAT
# 6
# AU=UNALACAK MURAT
# 8
# AU=ISCAN MURAT
# 9
# AU=SAT MURAT
# 9
# AU=SEREFLICAN MURAT
# 17
# AU=KAYIM MURATHAN
# 16
# AU=KOSE MURTAZA
# 0
# AU=AVCI MUSA
# 5
# AU=AKCE MUSA
# 0
# AU=AYDIN MUSA
# 21
# AU=UCAN MUSA
# 8
# AU=GUNAY MUSA
# 0
# AU=ASYALI MUSA
# 23
# AU=GULCUR MUSA
# 0
# AU=SAGLAM MUSA
# 1
# AU=YIGIN MUSA
# 0
# AU=ZORLU MUSA
# 3
# AU=CAKICI MUSA
# 29
# AU=CAPKIN MUSA
# 9
# AU=OKSUZ MUSA
# 0
# AU=OZBAY MUSA
# 18
# AU=YUCE MUSAFA
# 0
# AU=ACAR MUSTAFA
# 82
# AU=AKCAY MUSTAFA
# 3
# AU=SARIYILDIZ MUSTAFA
# 38
# AU=ALDEMIR MUSTAFA
# 58
# AU=ANAR MUSTAFA
# 16
# AU=ARIKAN MUSTAFA
# 9
# AU=ATASOY MUSTAFA
# 43
# AU=AKDEMIR MUSTAFA
# 0
# AU=AYDIN MUSTAFA
# 206
# AU=BAKIR MUSTAFA
# 81
# AU=BAYTAR MUSTAFA
# 0
# AU=BASER MUSTAFA
# 1
# AU=BENEKLI MUSTAFA
# 155
# AU=BIRINCIOGLU MUSTAFA
# 10
# AU=BICER MUSTAFA
# 24
# AU=CEMEK MUSTAFA
# 46
# AU=KARACADAG MUSTAFA
# 0
# AU=CENGIZ MUSTAFA
# 142
# AU=IZGI MUSTAFA
# 2
# AU=HOSCOSKUN MUSTAFA
# 0
# AU=DEMETGUL MUSTAFA
# 14
# AU=DEMIR MUSTAFA
# 276
# AU=DEMIRCI MUSTAFA
# 95
# AU=DEMIRCI MUSTAFA
# 95
# AU=DEMIREL MUSTAFA
# 3
# AU=DENIZ MUSTAFA
# 41
# AU=YILDIRIM MUSTAFA
# 179
# AU=DOGAN MUSTAFA
# 105
# AU=DURMAN MUSTAFA
# 0
# AU=DURMUS MUSTAFA
# 58
# AU=DONMEZ MUSTAFA
# 8
# AU=ERAYMAN MUSTAFA
# 16
# AU=ERBOGA MUSTAFA
# 50
# AU=EROL MUSTAFA
# 62
# AU=ERSOZ MUSTAFA
# 100
# AU=USMAN MUSTAFA
# 1
# AU=GOLCU MUSTAFA
# 8
# AU=GUL MUSTAFA
# 102
# AU=GUNES MUSTAFA
# 80
# AU=GUVEN MUSTAFA
# 47
# AU=GUVEN MUSTAFA
# 47
# AU=DINCKAL MUSTAFA
# 19
# AU=ERTAN MUSTAFA
# 0
# AU=SUCAKLI MUSTAFA
# 21
# AU=HOPAC MUSTAFA
# 0
# AU=HOTAMISLI MUSTAFA
# 0
# AU=IRAZ MUSTAFA
# 22
# AU=ISIK MUSTAFA
# 33
# AU=ALTUNDAG MUSTAFA
# 8
# AU=KALAFAT MUSTAFA
# 8
# AU=KALAY MUSTAFA
# 7
# AU=KAPLANOGLU MUSTAFA
# 12
# AU=KARA MUSTAFA
# 83
# AU=KARABULUT MUSTAFA
# 14
# AU=KARAPIRLI MUSTAFA
# 25
# AU=KARATAS MUSTAFA
# 23
# AU=KAVACIK MUSTAFA
# 0
# AU=KAYIK MUSTAFA
# 0
# AU=KAYMAKCI MUSTAFA
# 13
# AU=KELEN MUSTAFA
# 2
# AU=COSKUN MUSTAFA
# 32
# AU=DEMIRCI MUSTAFA
# 95
# AU=ISMAN MUSTAFA
# 4
# AU=KINSIZ MUSTAFA
# 1
# AU=KOYUNCU MUSTAFA
# 13
# AU=KULAC MUSTAFA
# 24
# AU=KURT MUSTAFA
# 183
# AU=KURT MUSTAFA
# 183
# AU=KURUL MUSTAFA
# 0
# AU=KUTANIS MUSTAFA
# 9
# AU=KOKSAL MUSTAFA
# 17
# AU=KUCUKAYDIN MUSTAFA
# 11
# AU=KUCUKONER MUSTAFA
# 0
# AU=KIRKIT MUSTAFA
# 2
# AU=LAMAN MUSTAFA
# 24
# AU=MAMAK MUSTAFA
# 5
# AU=TATLI MUSTAFA
# 44
# AU=MENCUTEKIN MUSTAFA
# 0
# AU=ARIKAN MUSTAFA
# 9
# AU=METIN MUSTAFA
# 17
# AU=ATANAK MUSTAFA
# 6
# AU=MUJDECI MUSTAFA
# 0
# AU=MUSTA MUSTAFA
# 3
# AU=OBAY MUSTAFA
# 0
# AU=OFLAZ MUSTAFA
# 0
# AU=OGUZ MUSTAFA
# 27
# AU=SINEMILLIOGLU MUSTAFA
# 0
# AU=SAMANCIOGLU MUSTAFA
# 3
# AU=SARICA MUSTAFA
# 0
# AU=SACAR MUSTAFA
# 46
# AU=SAGIR MUSTAFA
# 11
# AU=SEKMEN MUSTAFA
# 1
# AU=YAVUZ MUSTAFA
# 180
# AU=SELCUK MUSTAFA
# 20
# AU=KARA MUSTAFA
# 83
# AU=KEMALOGLU MUSTAFA
# 2
# AU=KARAKAS MUSTAFA
# 45
# AU=SERINKEN MUSTAFA
# 62
# AU=SUNBUL MUSTAFA
# 49
# AU=TEKPINAR MUSTAFA
# 13
# AU=TEKIN MUSTAFA
# 173
# AU=ERDEM MUSTAFA
# 24
# AU=BALTA MUSTAFA
# 2
# AU=TOPARLI MUSTAFA
# 14
# AU=TURKAL MUSTAFA
# 1
# AU=TUTAK MUSTAFA
# 26
# AU=GOKTAS MUSTAFA
# 25
# AU=TURKMEN MUSTAFA
# 82
# AU=TIMUR MUSTAFA
# 4
# AU=ULASLI MUSTAFA
# 30
# AU=UZKESER MUSTAFA
# 24
# AU=UGURLU MUSTAFA
# 43
# AU=VEKLI MUSTAFA
# 5
# AU=YAPRAK MUSTAFA
# 36
# AU=YAZICI MUSTAFA
# 35
# AU=YESILYURT MUSTAFA
# 3
# AU=YILDIRIM MUSTAFA
# 179
# AU=YILDIRIM MUSTAFA
# 179
# AU=YILDIRIM MUSTAFA
# 179
# AU=YILDIZ MUSTAFA
# 366
# AU=YILMAZ MUSTAFA
# 731
# AU=YILMAZ MUSTAFA
# 731
# AU=YURTTUTAR MUSTAFA
# 0
# AU=ZINCIRKIRAN MUSTAFA
# 0
# AU=CAMAS MUSTAFA
# 17
# AU=CATIR MUSTAFA
# 8
# AU=CEKER MUSTAFA
# 0
# AU=CELIK MUSTAFA
# 165
# AU=OKMEN MUSTAFA
# 2
# AU=ONDER MUSTAFA
# 24
# AU=OZ MUSTAFA
# 9
# AU=OZBAYRAK MUSTAFA
# 30
# AU=OZDEN MUSTAFA
# 27
# AU=OZDEN MUSTAFA
# 27
# AU=OZEN MUSTAFA
# 112
# AU=OZGEN MUSTAFA
# 34
# AU=OZSAHIN MUSTAFA
# 33
# AU=ULKER MUSTAFA
# 34
# AU=UNAL MUSTAFA
# 123
# AU=IZMIRLI MUSTAFA
# 6
# AU=SAHAN MUSTAFA
# 21
# AU=SENER MUSTAFA
# 10
# AU=SENGUN MUSTAFA
# 0
# AU=ARAS MUTAN
# 29
# AU=ADAK MUTLU
# 0
# AU=DAGLIOGLU MUTLU
# 22
# AU=AYDEMIR MUZAFFER
# 1
# AU=DOGAN MUZAFFER
# 4
# AU=ERDOGAN MUZAFFER
# 9
# AU=ERDOGAN MUZAFFER
# 9
# AU=MALKOC MUZAFFER
# 1
# AU=SARIAYDIN MUZAFFER
# 19
# AU=TOPCU MUZAFFER
# 22
# AU=TANRIOVEN MUGDESEM
# 6
# AU=ARPACI MUCAHIT
# 0
# AU=EMET MUCAHIT
# 57
# AU=OZCELIK MUCAHIT
# 1
# AU=UNAL MUCAHIT
# 2
# AU=OZDEMIR MUKERREM
# 0
# AU=GURE MULAYIM
# 0
# AU=NAZLI MUMTAZ
# 8
# AU=AKMAZ MUNTEHA
# 0
# AU=CERRAHOGLU MUNIR
# 0
# AU=KARABEKIR MUNIRE
# 0
# AU=AKYUZ MURSEL
# 0
# AU=ATA MURSEL
# 0
# AU=DAVARCI MURSEL
# 26
# AU=GURSES MURSEL
# 0
# AU=CEPNI MURSEL
# 1
# AU=TUFAN MURSIT
# 10
# AU=DEMIR MUSLIM
# 0
# AU=IZMIRLI MUZEYYEN
# 13
# AU=ALTAN MIKAIL
# 0
# AU=SOYLEMEZ MIKAIL
# 1
# AU=TURKKAHRAMAN MIMAR
# 2
# AU=BEK MINE
# 6
# AU=SIMSEK MINE
# 3
# AU=KISACIKOGLU MITHAT
# 15
# AU=GUNAYDIN MITHAT
# 17
# AU=YAYLAGUL MIYASE
# 1
# AU=AKCAY MIGRAC
# 6
# AU=TOPALOGLU NACI
# 34
# AU=KARKINER NADIDE
# 0
# AU=GOKSUGUR NADIR
# 26
# AU=YILMAZ NAFIYE
# 78
# AU=ARSLAN NAGEHAN
# 0
# AU=SARI NAGIHAN
# 7
# AU=DELIBAS NAMIK
# 42
# AU=HATIPOGLU NAMIK
# 82
# AU=KARABIBER NAMIK
# 0
# AU=COSKUN NART
# 6
# AU=AYDN NASUHI
# 0
# AU=KERIMOV NAZIM
# 10
# AU=ISLAM NAZIR
# 0
# AU=ATASOY NAZMI
# 0
# AU=YASITLI NAZMI
# 4
# AU=CETIN NAZMI
# 8
# AU=KERVAN NAZMIYE
# 30
# AU=KARAGOZOGLU NAZIKE
# 1
# AU=YILMAZ NAZIRE
# 13
# AU=BILMEDI NAIF
# 0
# AU=GUNEY NAIL
# 0
# AU=BILGIN NCEDET
# 0
# AU=YILMAZ NEBI
# 26
# AU=BOZKURT NECATI
# 2
# AU=HIRCA NECATI
# 2
# AU=KOCYIGIT NECATI
# 3
# AU=SALTEK NECDET
# 0
# AU=ERTURK NECLA
# 0
# AU=AYDIN NECMEDDIN
# 0
# AU=ERDOGAN NECMETTIN
# 4
# AU=KILINC NECMETTIN
# 38
# AU=PENABGUL NECMETTIN
# 0
# AU=ARSLAN NECMI
# 23
# AU=BIYIKLI NECMI
# 78
# AU=GOKAY NECMI
# 2
# AU=DEMIRCI NEDRET
# 0
# AU=ELMAS NEDRET
# 0
# AU=TEIK NEDIM
# 0
# AU=KARAKAYA NEJDET
# 0
# AU=SIMSEK NEJDET
# 27
# AU=GULTEPE NEJLA
# 1
# AU=KURUL NEJLA
# 1
# AU=KIYMAZ NEJMI
# 20
# AU=CORDUK NERGUL
# 11
# AU=CELIK NERMIN
# 7
# AU=BARUT NESLI
# 0
# AU=BAYRAK NESLIHAN
# 5
# AU=BULUT NESLIHAN
# 7
# AU=KADIKOYLU NESLIHAN
# 0
# AU=ATCI NESRIN
# 15
# AU=GURSAN NESRIN
# 51
# AU=ANDIRAN NESIBI
# 0
# AU=KARABULUT NEVZA
# 0
# AU=DAMLA NEVZAT
# 10
# AU=TARIM NEVZAT
# 1
# AU=TUZCU NEVIN
# 12
# AU=SARIBOGA NEZAKET
# 2
# AU=ONDUL NEZIHA
# 0
# AU=AKGUL NESE
# 2
# AU=AKAR NESET
# 10
# AU=DEMIRCI NESET
# 4
# AU=YILDIZ NUERTTIN
# 0
# AU=KONUK NUMAN
# 30
# AU=YUKSEL NUMAN
# 4
# AU=OZEN NUMAN
# 0
# AU=CELIK NUR
# 1
# AU=KAYABASI NURAN
# 6
# AU=BUYUKBERBER NURAY
# 3
# AU=MEMIS NURAY
# 0
# AU=KAHRAMAN NURCAN
# 5
# AU=ATA NURCAN
# 0
# AU=PAZARLIOGLU NURDAN
# 34
# AU=AYDEMIR NURDANE
# 2
# AU=TOMBAK NURDOGAN
# 0
# AU=VAN NUREDDIN
# 0
# AU=CELIMLI NUREDDIN
# 8
# AU=BILGEN NURETTIN
# 0
# AU=DOGAN NURETTIN
# 44
# AU=ISMAN NURETTIN
# 0
# AU=KUZHAN NURETTIN
# 1
# AU=SAVAS NURETTIN
# 0
# AU=YOREK NURETTIN
# 6
# AU=OZKOKELI NURETTIN
# 0
# AU=OZTURK NURETTIN
# 0
# AU=IBRAHIMOGLU NURETTIN
# 1
# AU=SENYER NURETTIN
# 15
# AU=ATMACA NURGUL
# 16
# AU=BOZKURT NURGUL
# 2
# AU=TANKUT NURGUL
# 14
# AU=YAGIZ NURKAN
# 23
# AU=SAHIN NURSEL
# 32
# AU=AKSOY NURTEN
# 144
# AU=AKKOC NURULLAH
# 153
# AU=ALTUN NURULLAH
# 0
# AU=ANKARALIOGLU NURULLAH
# 4
# AU=KAYA NURULLAH
# 3
# AU=KAYISOGLU NURULLAH
# 0
# AU=KOKSAL NURULLAH
# 2
# AU=TABAKCI NURULLAH
# 0
# AU=AYDOGDU NURI
# 0
# AU=BOZALI NURI
# 4
# AU=KIRAZ NURI
# 36
# AU=OK NURI
# 1
# AU=COLAK NUSRET
# 0
# AU=BAYINDIR NIDA
# 3
# AU=BOZ NIHAT
# 5
# AU=KAYA NIHAT
# 23
# AU=YAZILITAS NIHAT
# 0
# AU=YAGMUR NIHAT
# 16
# AU=YILMAZ NIHAT
# 28
# AU=CETINKAYA NIHAT
# 3
# AU=ILHAN NIHAT
# 8
# AU=SEN NIHAT
# 79
# AU=LODOGLU NILAY
# 0
# AU=SAMANCI NILAY
# 8
# AU=USTUN NILGUL
# 9
# AU=ERDEM NILGUN
# 0
# AU=KILINC NILGUN
# 0
# AU=ATALAY NILGUN
# 25
# AU=KOCA NILUFER
# 0
# AU=KORKMAZ NILUFER
# 7
# AU=ILHAN NILUFER
# 25
# AU=KAHYA NIMET
# 4
# AU=ERDOGAN NIYAZI
# 6
# AU=KILIC NIYAZI
# 23
# AU=ODABASIOGLU NIYAZI
# 26
# AU=KOC OKAN
# 5
# AU=SAGLAMBILEN OKAN
# 1
# AU=SOLAK OKAN
# 24
# AU=DEMIRDAG OKTAY
# 7
# AU=OZTURK OKTAY
# Authenticated (SID: E66LbcTKDdqpWdBbukY)
# 30
# AU=HATIPOGLU OKTAY
# 0
# AU=SARI OKTAY
# 36
# AU=OKSUZLER OKTAY
# 0
# AU=ESER OLCAY
# 57
# AU=HISAR OLCAY
# 26
# AU=KARAATLI OLCAY
# 10
# AU=KURSUN OLCAY
# 44
# AU=SINAN OLCAY
# 4
# AU=HAMZAOGLU ONUR
# 17
# AU=NANE ONUR
# 5
# AU=OKTAY ONUR
# 6
# AU=SOKUCU ORAL
# 21
# AU=ADIGUZEL ORHAN
# 0
# AU=AKMAN ORHAN
# 16
# AU=ATES ORHAN
# 20
# AU=BOZOGLAN ORHAN
# 14
# AU=DOGDU ORHAN
# 48
# AU=ER ORHAN
# 12
# AU=FILIZ ORHAN
# 0
# AU=GOZENELI ORHAN
# 13
# AU=GUNAY ORHAN
# 0
# AU=KARATAS ORHAN
# 4
# AU=KARPUZ ORHAN
# 1
# AU=KOCAK ORHAN
# 20
# AU=SARIKAYA ORHAN
# 0
# AU=TEZCAN ORHAN
# 14
# AU=TOKGOZ ORHAN
# 24
# AU=OZKAN ORHAN
# 48
# AU=CELTIKCI ORHAN
# 0
# AU=OZBEK ORHAN
# 59
# AU=UNAL ORHAN
# 48
# AU=ZORBA ORHAN
# 18
# AU=ALKILINC ORUC
# 0
# AU=ABALI OSMAN
# 16
# AU=ETOZ OSMAN
# 21
# AU=BARAK OSMAN
# 0
# AU=BILGEN OSMAN
# 1
# AU=BILGIN OSMAN
# 19
# AU=CANKO OSMAN
# 46
# AU=CENET OSMAN
# 2
# AU=DOLU OSMAN
# 1
# AU=YILDIZ OSMAN
# 12
# AU=EGRI OSMAN
# 0
# AU=GENC OSMAN
# 44
# AU=GOKALP OSMAN
# 26
# AU=GUNER OSMAN
# 9
# AU=LEBLEBICIOGLU OSMAN
# 0
# AU=KABAKCILI OSMAN
# 0
# AU=KARABACAK OSMAN
# 29
# AU=KULAK OSMAN
# 14
# AU=ORAL OSMAN
# 0
# AU=SALIS OSMAN
# 23
# AU=SULAK OSMAN
# 13
# AU=TEMIZOZ OSMAN
# 40
# AU=TOPAC OSMAN
# 0
# AU=VIRIT OSMAN
# 32
# AU=YILDIRIM OSMAN
# 64
# AU=YUKSEL OSMAN
# 143
# AU=SAHIN OSMAN
# 57
# AU=OZDEMIR OSMAN
# 84
# AU=ULKER OSMAN
# 0
# AU=UNAL OSMAN
# 4
# AU=SAHIN OSMAN
# 57
# AU=SISMAN OSMAN
# 0
# AU=SARI OYA
# 0
# AU=ALKOC OZAN
# 8
# AU=BALAKAN OZAN
# 36
# AU=YAY OZAN
# 10
# AU=OZEN OGUZ
# 24
# AU=BURNAZ OGUZ
# 1
# AU=CINCIOGLU OGUZ
# 0
# AU=ERDOGAN OGUZ
# 2
# AU=KARAHAN OGUZ
# 59
# AU=KAYMAKCI OGUZ
# 0
# AU=TEKELIOGLU OGUZ
# 1
# AU=BASIBUYUK OGUZHAN
# 4
# AU=DINCEL OGUZHAN
# 8
# AU=DEMIR OGUZHAN
# 12
# AU=BUCAKTEPE PAKIZE
# 5
# AU=BAYRAM PARVANA
# 0
# AU=YALCINOGLU PELIN
# 0
# AU=ULUS PERVIN
# 0
# AU=SEKMEN PERIHAN
# 1
# AU=ECEVITOGLU PINAR
# 0
# AU=OZUGUZ PINAR
# 34
# AU=ARSLAN RAMAZAN
# 2
# AU=BALCI RAMAZAN
# 0
# AU=BASTURK RAMAZAN
# 8
# AU=BOZKURT RAMAZAN
# 0
# AU=BUYUKKAYA RAMAZAN
# 57
# AU=DERDIMAN RAMAZAN
# 0
# AU=DAVRAN RAMAZAN
# 29
# AU=DURAN RAMAZAN
# 0
# AU=GULENDAM RAMAZAN
# 0
# AU=GUN RAMAZAN
# 33
# AU=GUNAY RAMAZAN
# 0
# AU=KARANFIL RAMAZAN
# 9
# AU=KAYIKCI RAMAZAN
# 16
# AU=KAYNAK RAMAZAN
# 11
# AU=KILIC RAMAZAN
# 1
# AU=KILICARSLAN RAMAZAN
# 0
# AU=KOCABAS RAMAZAN
# 11
# AU=KOZAN RAMAZAN
# 21
# AU=KURT RAMAZAN
# 59
# AU=MEMISOGULLARI RAMAZAN
# 25
# AU=MERT RAMAZAN
# 11
# AU=TURKMEN RAMAZAN
# 12
# AU=USLU RAMAZAN
# 3
# AU=UYGUR RAMAZAN
# 15
# AU=YAGCI RAMAZAN
# 66
# AU=YILDIZ RAMAZAN
# 106
# AU=ZENGIN RAMAZAN
# 0
# AU=CELIK RAMAZAN
# 2
# ...
# 83
# AU=ULKER SERDAR
# 26
# AU=SIVGIN SERDAR
# 50
# AU=AYDIN SERGULEN
# 10
# AU=DERIN SERHAN
# 22
# AU=DEMIRER SERHAT
# 7
# AU=ERCAN SERHAT
# 0
# AU=MERTOGLU SERHAT
# 1
# AU=TANIK SERHAT
# 28
# AU=AYDIN SERKAN
# 11
# AU=BALTA SERKAN
# 3
# AU=BAYRAKTAROGLU SERKAN
# 0
# AU=BOYAR SERKAN
# 3
# AU=ELCIN SERKAN
# 12
# AU=ERDAL SERKAN
# 44
# AU=KARATAS SERKAN
# 6
# AU=KIRBAS SERKAN
# 25
# AU=KURTGOZ SERKAN
# 5
# AU=PERKMEN SERKAN
# 9
# AU=CAKIR SERKAN
# 8
# AU=OZTURK SERKAN
# 94
# AU=SAHIN SERKAN
# 31
# AU=SENOL SERKAN
# 41
# AU=ALTAY SERPIL
# 0
# AU=KOCAMAN SERPIL
# 0
# AU=YAGCI SERVER
# 16
# AU=DEMIR SERVET
# 3
# AU=KACAR SEVAL
# 27
# AU=BULDUK SEVDA
# 0
# AU=SEZER SEVGI
# 2
# AU=YUCA SEVIL
# 27
# AU=GOKSUGUR SEVIL
# 21
# AU=KAMALI SEVIL
# 60
# AU=OZEN SEVILAY
# 0
# AU=BERTLEK SEYDI
# 1
# AU=OKUMUS SEYDI
# 32
# AU=KOKLU SEYFETTIN
# 210
# AU=TURKMEN SEYFULLAH
# 0
# AU=EMIR SEYFI
# 20
# AU=SARGIN SEYIT
# 0
# AU=KOSE SEYIT
# 10
# AU=DELIDUMAN SEYITHAN
# 0
# AU=CAKMAK SEYITHAN
# 0
# AU=APILIOGULLARI SEZA
# 61
# AU=KALAFAT SEZAI
# 1
# AU=TEMELLI SEZAI
# 1
# AU=SASMAZ SEZAI
# 12
# AU=OCAK SEZEN
# 12
# AU=KISA SEZER
# 21
# AU=OZSOY SECKIN
# 1
# AU=ARSLAN SIDDIK
# 7
# AU=KUTSAL SIDDIK
# 0
# AU=MALKOC SIDDIK
# 31
# AU=BAYTAK SITKI
# 14
# AU=DUMAN SITKI
# 7
# AU=ERMIS SITKI
# 28
# AU=CORBACIOGLU SITKI
# 7
# AU=AKKOC SONER
# 2
# AU=GIREN SONGUL
# 0
# AU=ACAR SRDAR
# 0
# AU=ASKIN SUAT
# 2
# AU=KESKIN SUAT
# 24
# AU=SOYDEMIR SUAT
# 0
# AU=ZEYREK SUAT
# 1
# AU=BISKIN SULTAN
# 14
# AU=KABA SULTAN
# 22
# AU=KURT SULTAN
# 2
# AU=BASAK SUNA
# 2
# AU=SACAN SUNAY
# 0
# AU=SACAR SUZAN
# 32
# AU=YAZICI SUZAN
# 2
# AU=KARAKUS SUZAN
# 3
# AU=AYHAN SUZI
# 8
# AU=ARSLAN SONMEZ
# 6
# AU=PAMUK SONMEZ
# 4
# AU=DIKICI SUBER
# 21
# AU=ZOROGLU SULEMAN
# 0
# AU=CARSANCAKLI SULEYMAN
# 5
# AU=ALTINTAS SULEYMAN
# 2
# AU=AYDIN SULEYMAN
# 152
# AU=AYVAZ SULEYMAN
# 24
# AU=BASLAR SULEYMAN
# 7
# AU=BOREKCI SULEYMAN
# 0
# AU=BUYUKBERBER SULEYMAN
# 149
# AU=CENGIZ SULEYMAN
# 3
# AU=CENKCI SULEYMAN
# 8
# AU=DEMIR SULEYMAN
# 62
# AU=DEMIRCI SULEYMAN
# 2
# AU=ERCAN SULEYMAN
# 55
# AU=GOREN SULEYMAN
# 1
# AU=SEVILGEN SULEYMAN
# 6
# AU=SAHIN SULEYMAN
# 52
# AU=KAHRAMAN SULEYMAN
# 9
# AU=KARACELIL SULEYMAN
# 1
# AU=KARSLI SULEYMAN
# 4
# AU=KAVAK SULEYMAN
# 3
# AU=KIZIL SULEYMAN
# 27
# AU=SARIBAS SULEYMAN
# 1
# AU=SEMIZ SULEYMAN
# 4
# AU=SEYDI SULEYMAN
# 2
# AU=TERZIOGLU SULEYMAN
# 0
# AU=SIVRI SULEYMAN
# 0
# AU=TURK SULEYMAN
# 60
# AU=ULUTURK SULEYMAN
# 0
# AU=YAZAR SULEYMAN
# 38
# AU=YUKSEL SULEYMAN
# 3
# AU=CAKICI SULEYMAN
# 3
# AU=CELIK SULEYMAN
# 34
# AU=OZEREN SULEYMAN
# 2
# AU=ULGER SULEYMAN
# 2
# AU=IC SULEYMAN
# 0
# AU=SIMSEK SULEYMAN
# 8
# AU=KOCTURK SUMEYRA
# 1
# AU=BAHSI SUMEYYE
# 0
# AU=KARACABEY SUREYYA
# 0
# AU=UNAL SUZAN
# 0
# AU=AYIK SIBEL
# 14
# AU=DOGRU SIBEL
# 2
# AU=DIKMEN SIBEL
# 5
# AU=PERCINEL SIBEL
# 19
# AU=AYDIN SINAN
# 11
# AU=KOCAMAN SINAN
# 80
# AU=SARISOY SINAN
# 0
# AU=TAN SINAN
# 41
# AU=TOZOGLU SINAN
# 20
# AU=TUNCEL SINAN
# 6
# AU=ULU SINAN
# 6
# AU=YASAR SINAN
# 3
# AU=YORUK SINAN
# 1
# AU=CIFTCI SINAN
# 0
# AU=CITCI SINAN
# 0
# AU=OZGELEN SINAN
# 8
# AU=KOSEOGLU SINEM
# 3
# AU=GOKCESID SINEM
# 0
# AU=AZERI SIYAVES
# 7
# AU=YILDIRIM TACETTIN
# 6
# AU=ORNEK TACETTIN
# 21
# AU=KARAMAN TAHA
# 2
# AU=BOYRAZ TAHSIN
# 6
# AU=DELICAY TAHSIN
# 0
# AU=SOGUT TAHSIN
# 14
# AU=YAKUT TAHSIN
# 51
# AU=YILDIRIM TAHSIN
# 25
# AU=AYATA TAHIR
# 7
# AU=SEVINC TAHIR
# 2
# AU=OZKAN TAHIR
# 0
# AU=ARTUN TALAT
# 0
# AU=KAHYAOGLU TALIP
# 20
# AU=CEVIK TALIP
# 2
# AU=ALISKAN TAMER
# 2
# AU=BASKAL TAMER
# 4
# AU=UCAR TAMER
# 6
# AU=COSKUN TAMER
# 67
# AU=UYSAL TANCAN
# 96
# AU=ARSLAN TANER
# 21
# AU=TOPAL TANER
# 4
# AU=OZBENLI TANER
# 7
# AU=ULUCAY TARIK
# 4
# AU=KORUCU TAYFUN
# 9
# AU=KOC TAYLAN
# 0
# AU=KARGIN TAYYIBE
# 0
# AU=OZDES TASKIN
# 13
# AU=INAN TASKIN
# 1
# AU=BAGLAM TEKIN
# 36
# AU=TAS TEKIN
# 31
# AU=BAYRAK TEMEL
# 4
# AU=DEMIREL TEOMAN
# 0
# AU=AYSU TEVFIK
# 30
# AU=DEMIRCI TEVFIK
# 5
# AU=GUNES TEVFIK
# 36
# AU=ONGAN TEVFIK
# 0
# AU=PINAR TEVFIK
# 16
# AU=YAVUZ TEVFIK
# 20
# AU=ZIYPAK TEVFIK
# 36
# AU=DURNA TEZCAN
# 1
# AU=PARALI TEZCAN
# 3
# AU=ATAY TOLGA
# 31
# AU=KABACA TOLGA
# 5
# AU=TOREN TOLGA
# 1
# AU=ARI TUBA
# 2
# AU=EJDER TUBA
# 0
# AU=KARABOGA TUBA
# 1
# AU=KIYAN TUBA
# 4
# AU=TEMEL TUBA
# 0
# AU=AYTAC TUFAN
# 4
# AU=BAL TUFAN
# 14
# AU=KUZPINARI TUFAN
# 1
# AU=ATALAY TUGAY
# 17
# AU=OZGISI TUNCA
# 0
# AU=DELIBASI TUNCAY
# 136
# AU=DURNA TUNCAY
# 0
# AU=KAMAS TUNCAY
# 10
# AU=KANER TUNCAY
# 29
# AU=DEMIR TUNCER
# 48
# AU=KILIC TUNCER
# 0
# AU=GEYIKLI TURABI
# 4
# AU=AKTAS TURAN
# 6
# AU=BATAR TURAN
# 3
# AU=KARACA TURAN
# 45
# AU=YAZICILAR TURAN
# 7
# AU=TEMUR TURAN
# 3
# AU=USLU TURAN
# 7
# AU=CALBAN TURAN
# 11
# AU=CELEB TURAN
# 0
# AU=ISIK TURGAY
# 65
# AU=POLAT TURGAY
# 9
# AU=TAY TURGAY
# 29
# AU=TEKINAY TURGAY
# 68
# AU=UNIVERSITYER TURGAY
# 0
# AU=YAZAR TURGAY
# 1
# AU=GOKSU TURGUT
# 0
# AU=KOCATURK TURGUT
# 9
# AU=YELOGLU TURGUT
# 2
# AU=GULSAR TUGBA
# 0
# AU=SARISAHIN TUGBA
# 1
# AU=YANIK TUGRUL
# 4
# AU=BORAN TUGCE
# 1
# AU=YENICERI TULAY
# 0
# AU=OZLU TULAY
# 19
# AU=SAGLAM TULIN
# 0
# AU=GUVEN TUMER
# 18
# AU=SERT TIJEN
# 1
# AU=AYHAN TIMUR
# 6
# AU=KESKINTURK TIMUR
# 4
# AU=TEZEL TIMUR
# 7
# AU=AYDOGAN TIMUCIN
# 18
# AU=DOGUC UFUK
# 1
# AU=DURNA UFUK
# 2
# AU=TAS UFUK
# 23
# AU=OZUGUZ UFUK
# 27
# AU=CAGATAY ULUC
# 0
# AU=ARIOZ UMUT
# 12
# AU=GULACTI UMUT
# 32
# AU=GOLGE UMUT
# 28
# AU=ERDOGAN UTKU
# 6
# AU=SAYIN UTKU
# 3
# AU=KERMAN UYSAL
# 2
# AU=ACAR UGUR
# 35
# AU=BAYTUN UGUR
# 0
# AU=CAMCI UGUR
# 7
# AU=FIRAT UGUR
# 41
# AU=GOKTAS UGUR
# 25
# AU=KADAK UGUR
# 24
# AU=KARA UGUR
# 6
# AU=KARAAGAC UGUR
# 0
# AU=KOLTUKSUZ UGUR
# 9
# AU=YILDIRIM UGUR
# 22
# AU=CAKIR UGUR
# 26
# AU=CAKIR UGUR
# 26
# AU=COSKUN UGUR
# 173
# AU=COMLEKCIOGLU UGUR
# 10
# AU=OZCAN UGUR
# 21
# AU=OGUSGIL VAHAP
# 3
# AU=OVACI VAHAP
# 0
# AU=SARICICEK VAHAP
# 19
# AU=AYTEKIN VAHIT
# 0
# AU=KAPLANOGLU VAHIT
# 11
# AU=TANE VAHIT
# 0
# AU=ARSLAN VASFI
# 0
# AU=ARI VEDAT
# 5
# AU=BAL VEDAT
# 1
# AU=DAL VEDAT
# 14
# AU=DAVUTOGLU VEDAT
# 125
# AU=DEMIR VEDAT
# 9
# AU=OZCAN VEDAT
# 0
# AU=KARTALCIK VEDAT
# 0
# AU=LACINER VEDAT
# 0
# AU=KARSLI VEDAT
# 5
# AU=SIAP VEDAT
# 5
# AU=AKSOY VELI
# 0
# AU=GORGEN VELI
# 1
# AU=BERK VELI
# 71
# AU=DENIZ VELI
# 20
# AU=GOK VELI
# 21
# AU=KARAGOZ VELI
# 0
# AU=MERT VELI
# 0
# AU=TURKMENOGLU VELI
# 2
# AU=UGURCU VELI
# 11
# AU=YILDIRIM VELI
# 16
# AU=CAGLAR VELI
# 12
# AU=CITISLI VELI
# 12
# AU=OZTURK VELI
# 19
# AU=ASOGLU VEYSEL
# 0
# AU=AYHAN VEYSEL
# 10
# AU=AGCA VEYSEL
# 4
# AU=DEMIR VEYSEL
# 54
# AU=ERGIN VEYSEL
# 0
# AU=KUSCU VEYSEL
# 1
# AU=NARGUL VEYSEL
# 0
# AU=OKUMUS VEYSI
# 31
# AU=ONER VEYSI
# 41
# AU=OZTURK VEYSI
# 4
# AU=ERTURK VOLKAN
# 0
# AU=SOLMAZ VOLKAN
# 36
# AU=SENYUREK VOLKAN
# 12
# AU=BOSNAK VUSLAT
# 20
# AU=MOTOR VICDAN
# 13
# AU=ZORBA YAHYA
# 17
# AU=YASAR YAHYA
# 0
# AU=CELIK YAHYA
# 53
# AU=ISLAMOGLU YAHYA
# 34
# AU=EGERCIOGLU YAKUP
# 9
# AU=GONEN YAKUP
# 0
# AU=KESKIN YAKUP
# 1
# AU=SEKMEN YAKUP
# 6
# AU=TURKEL YAKUP
# 19
# AU=UMUCU YAKUP
# 7
# AU=YILDIRIM YAKUP
# 68
# AU=BAY YALCIN
# 0
# AU=BAS YALCIN
# 24
# AU=GOLCUK YALCIN
# 17
# AU=YESIL YALCIN
# 8
# AU=COPUR YALCIN
# 9
# AU=ALPER YASEMIN
# 1
# AU=BULUT YASEMIN
# 33
# AU=KAYMAKCI YASEMIN
# 0
# AU=GULUM YASEMIN
# 0
# AU=ISIK YASEMIN
# 19
# AU=BALCI YASEMIN
# 72
# AU=KARACA YASEMIN
# 1
# AU=TEKIN YASEMIN
# 1
# AU=SOYORAL YASEMIN
# 36
# AU=OZGUN YASEMIN
# 0
# AU=ABUL YASIN
# 30
# AU=ASLAN YASIN
# 0
# AU=ATAC YASIN
# 2
# AU=AVCI YASIN
# 1
# AU=BEZ YASIN
# 53
# AU=BULUT YASIN
# 6
# AU=KARADAG YASIN
# 11
# AU=KIRILMIS YASIN
# 0
# AU=SARI YASIN
# 10
# AU=SARIKAYA YASIN
# 9
# AU=KARAKUS YASIN
# 16
# AU=YAYLAR YASIN
# 0
# AU=GULEN YASIR
# 4
# AU=AKBAS YAVUZ
# 16
# AU=GUNES YAVUZ
# 1
# AU=KAPLAN YAVUZ
# 3
# AU=SALIHOGLU YAVUZ
# 14
# AU=SELIM YAVUZ
# 6
# AU=TAMA YAVUZ
# 3
# AU=SOYDAN YAVUZ
# 1
# AU=UYAR YAVUZ
# 73
# AU=UGURLU YAVUZ
# 27
# AU=ADIGUZELLI YASAR
# 1
# AU=BOYACI YASAR
# 1
# AU=DURMAZ YASAR
# 17
# AU=ERTURK YASAR
# 7
# AU=KARAASLAN YASAR
# 39
# AU=KOSAR YASAR
# 1
# AU=USLU YASAR
# 0
# AU=SEKER YASAR
# 2
# AU=SEN YASAR
# 28
# AU=AYDIN YENER
# 71
# AU=ACLAN YENER
# 0
# AU=OZTURK YENER
# 0
# AU=CEKICEL YESIM
# 0
# AU=KALKAN YILDIRAY
# 54
# AU=KESKIN YILDIRAY
# 10
# AU=SISMAN YILDIRAY
# 27
# AU=AKSOY YILMAZ
# 29
# AU=AKYUZ YILMAZ
# 0
# AU=ARI YILMAZ
# 3
# AU=KAYA YILMAZ
# 42
# AU=KILIC YILMAZ
# 3
# AU=KIROGLU YILMAZ
# 30
# AU=PALANCI YILMAZ
# 30
# AU=POLAT YILMAZ
# 7
# AU=POLAT YILMAZ
# 7
# AU=SAGLAM YILMAZ
# 6
# AU=TURGUT YILMAZ
# 20
# AU=ZENGIN YILMAZ
# 29
# AU=OZMEN YILMAZ
# 4
# AU=AYATA YUNUS
# 0
# AU=DOGAN YUNUS
# 39
# AU=EKIN YUNUS
# 0
# AU=UCAN YUNUS
# 0
# AU=YANDI YUNUS
# 3
# AU=KARAKUYU YUNUS
# 4
# AU=YILMAZ YUNUS
# 22
# AU=UGAN YUNUS
# 23
# AU=YILDIRIM YUNUS
# 9
# AU=YILMAZ YUNUS
# 22
# AU=CENGELOGLU YUNUS
# 28
# AU=OZKANLAR YUNUSEMRE
# 11
# AU=KARACA YUNIS
# 0
# AU=ARIKAN YUSUF
# 2
# AU=ATALAY YUSUF
# 90
# AU=AY YUSUF
# 4
# AU=AYDIN YUSUF
# 91
# AU=DEMIR YUSUF
# 47
# AU=DEMIR YUSUF
# 47
# AU=DENIZ YUSUF
# 0
# AU=ESER YUSUF
# 0
# AU=GUNER YUSUF
# 12
# AU=GUNES YUSUF
# 5
# AU=KARAASLAN YUSUF
# 0
# AU=KESKIN YUSUF
# 4
# AU=KILINC YUSUF
# 5
# AU=KOC YUSUF
# 18
# AU=KOCAK YUSUF
# 8
# AU=MACIT YUSUF
# 0
# AU=OYSAL YUSUF
# 15
# AU=PACAL YUSUF
# 0
# AU=SAGIR YUSUF
# 0
# AU=SEZEN YUSUF
# 48
# AU=SOFUOGLU YUSUF
# 1
# AU=SOYUPEK YUSUF
# 0
# AU=TAVIL YUSUF
# 63
# AU=TIRASCI YUSUF
# 0
# AU=TOPAL YUSUF
# 4
# AU=TURAN YUSUF
# 13
# AU=AYDOGDU YUSUF
# 4
# AU=YESIL YUSUF
# 56
# AU=YUCEL YUSUF
# 13
# AU=AKPINAR YUSUF
# 7
# AU=IGCI YUSUF
# 32
# AU=CETINDAG YUSUF
# 0
# AU=OZKAN YUSUF
# 33
# AU=OZCOBAN YUSUF
# 0
# AU=ALIHANOGLU YUSUF
# 55
# AU=SAHHIN YUSUF
# 0
# AU=ASLAN YUCE
# 0
# AU=BASEGIT YUCEL
# 1
# AU=DEMIRCI YUCEL
# 3
# AU=DEMIRER YUCEL
# 0
# AU=GONUL YUCEL
# 31
# AU=YAVUZ YUCEL
# 25
# AU=CENESIZ YUCEL
# 8
# AU=BOLEK YUKSEL
# 15
# AU=ELA YUKSEL
# 24
# AU=ISIK YUKSEL
# 13
# AU=KORKMAZ YUKSEL
# 1
# AU=KOKSAL YUKSEL
# 2
# AU=KOSEOGLU YUKSEL
# 23
# AU=SAYAN YUKSEL
# 0
# AU=TASKIN YUKSEL
# 1
# AU=YILDIZ YUKSEL
# 13
# AU=OZBAY YUKSEL
# 25
# AU=ACER ZABIT
# 0
# AU=AKAN ZAFER
# 16
# AU=AKPINAR ZAFER
# 9
# AU=AYVAZ ZAFER
# 0
# AU=DOGAN ZAFER
# 26
# AU=GURLER ZAFER
# 0
# AU=GUZEY ZAFER
# 0
# AU=SARI ZAFER
# 7
# AU=UYAR ZAFER
# 7
# AU=YILDIZ ZAFER
# 3
# AU=YONDEN ZAFER
# 26
# AU=CETINKAYA ZAFER
# 25
# AU=GUL ZAKIR
# 0
# AU=KARADAG ZAKIR
# 18
# AU=EDISAN ZEHRA
# 0
# AU=EKINCI ZEHRA
# 3
# AU=GUL ZEHRA
# 1
# AU=HASILOGLU ZEHRA
# 24
# AU=ERSOZLU ZEHRA
# 8
# AU=YASAR ZEHRA
# 25
# AU=SENGUL ZEHRA
# 0
# AU=AKMAN ZEKERIYA
# 4
# AU=DOGRUYOL ZEKERIYA
# 10
# AU=KAYA ZEKERIYA
# 56
# AU=KUCUKDURMAZ ZEKERIYA
# 51
# AU=ULGER ZEKERIYA
# 49
# AU=ARSLANOGLU ZEKI
# 4
# AU=DEMIRCI ZEKI
# 0
# AU=HALIS ZEKI
# 0
# AU=KANAY ZEKI
# 4
# AU=KARACA ZEKI
# 26
# AU=KARAKAYA ZEKI
# 1
# AU=TUNAY ZEKI
# 3
# AU=UYANIK ZEKI
# 2
# AU=YILDIRIM ZEKI
# 17
# AU=EKINCI ZELAL
# 36
# AU=ACAR ZELIHA
# 0
# AU=ETOZ ZELIHA
# 0
# AU=KAYAALTI ZELIHA
# 82
# AU=GUNES ZELIHA
# 3
# AU=ZENGINERLER ZEMINE
# 4
# AU=SAHIN ZERRIN
# 4
# AU=INCI ZERIFE
# 0
# AU=BARKOT ZEYNEP
# 0
# AU=HATTATOGLU ZEYNEP
# 0
# AU=EMEKSIZ ZEYNEP
# 5
# AU=GINIS ZEYNEP
# 42
# AU=KIVILCIM ZEYNEP
# 1
# AU=AKKURT ZEYNEP
# 31
# AU=AKKILIK ZEYNEP
# 0
# AU=TASCI ZEYNEP
# 7
# AU=ATILGAN ZUHAL
# 15
# AU=TOKER ZUHAL
# 8
# AU=ULUKOK ZUBEYDE
# 3
# AU=BOZDAG ZUBEYIR
# 18
# AU=KILIC ZUBEYIR
# 18
# AU=ARIKANOGLU ZULFU
# 36
# AU=BAYHAN ZULFU
# 34
# AU=BOZGEYIK ZULKIF
# 19
# AU=KAYA ZIYA
# 83
# AU=CETINER ZIYA
# 12
# AU=OZKECECI ZIYA
# 7
# AU=SEN ZIYA
# 0
# AU=AKTOP ZIYAEDDEIN
# 0
# AU=SUVARI CAKIR
# 2
# AU=CETINKAYA CAGLAR
# 5
# AU=SAKALAR CAGRI
# 23
# AU=DOGAR CETIN
# 20
# AU=ERDOGAN CETIN
# 7
# AU=KARACA CETIN
# 72
# AU=SUMER CETIN
# 7
# AU=VEYSAL CETIN
# 0
# AU=DULGERGIL CORUH
# 4
# AU=ATALAY CISE
# 0
# AU=YAMANER CIGDEM
# 4
# AU=AKYOL OMER
# 53
# AU=ALICI OMER
# 16
# AU=AYDIN OMER
# 63
# AU=BAYRAK OMER
# 94
# AU=BAYRAM OMER
# 1
# AU=BASAR OMER
# 86
# AU=CEVIT OMER
# 23
# AU=DEMIRTAS OMER
# 14
# AU=DEMIRTAS OMER
# 14
# AU=EROGLU OMER
# 3
# AU=EVIRGEN OMER
# 16
# AU=KOKOGLU OMER
# 12
# AU=SELAMET OMER
# 5
# AU=VURAL OMER
# 5
# AU=OZEKEN OMER
# 0
# AU=UNAL OMER
# 39
# AU=FARUKNOYAN OMER
# 0
# AU=GECICI OMER
# 44
# AU=KARAKAS OMER
# 22
# AU=KARATAS OMER
# 61
# AU=KURT OMER
# 89
# AU=MERMER OMER
# 17
# AU=PAMUK OMER
# 99
# AU=SAGLAM OMER
# 16
# AU=SOLAK OMER
# 0
# AU=SOYKASAP OMER
# 10
# AU=ULUKAPI OMER
# 0
# AU=UYSAL OMER
# 107
# AU=UCAR OMER
# 15
# AU=YAZGAN OMER
# 16
# AU=YILDIZ OMER
# 23
# AU=YILMAZ OMER
# 299
# AU=CAKIR OMER
# 47
# AU=CALKA OMER
# 53
# AU=CELIK OMER
# 130
# AU=OZBULUT OMER
# 19
# AU=OZKAN OMER
# 113
# AU=SAYLI OMER
# 13
# AU=SISE OMER
# 22
# AU=AKCI ONDER
# 18
# AU=BARLI ONDER
# 5
# AU=ERCAN ONDER
# 22
# AU=KARAKUS ONDER
# 4
# AU=YILDIZ ONDER
# 14
# AU=OZTURK ONDER
# 71
# AU=SAHIN ONDER
# 55
# AU=AYNIOGLU ONER
# 17
# AU=OZKAN OZALKAN
# 9
# AU=GULES OZAY
# 6
# AU=ASILKAN OZCAN
# 3
# AU=DEVECI OZCAN
# 30
# AU=OTKUN OZCAN
# 4
# AU=CAKIR OZCAN
# 8
# AU=OZEN OZCAN
# 17
# AU=OZTURK OZCAN
# 92
# AU=CETIN OZDEMIR
# 10
# AU=TALO OZER
# 15
# AU=KORKMAZ OZGEN
# 16
# AU=ALDEMIR OZGUR
# 9
# AU=ARPACI OZGUR
# 0
# AU=DEMIRTAS OZGUR
# 11
# AU=ERAKKUS OZGUR
# 0
# AU=KARABAG OZGUR
# 0
# AU=MUFTUOGLU OZGUR
# 0
# AU=OZDAMAR OZGUR
# 14
# AU=OZMEN OZGUR
# 16
# AU=OZTURK OZGUR
# 33
# AU=OZTURK OZGUR
# 33
# AU=ILDES OZGUR
# 0
# AU=ILHAN OZGUR
# 32
# AU=KAYACAN OZHAN
# 12
# AU=BAGCI OZKAN
# 8
# AU=GUNER OZKAN
# 60
# AU=VURAL OZKAN
# 4
# AU=CEGIL OZKAN
# 1
# AU=SIMSEK OZKAN
# 15
# AU=ABAKAY OZLEM
# 36
# AU=ALBAYRAK OZLEM
# 5
# AU=BILGIC OZLEM
# 20
# AU=FEDAI OZLEM
# 0
# AU=ISIK OZLEM
# 4
# AU=AKKAR OZLEM
# 13
# AU=SOLAK OZLEM
# 31
# AU=CAKMAK OZLEM
# 15
# AU=COSKUN OZLEM
# 61
# AU=KARAKUS OZLEM
# 20
# AU=OZKAN OZLEM
# 6
# AU=SENGUL OZLEM
# 18
# AU=KARAKOYUN OZUR
# 0
# AU=CORUMLUOGLU OZSEN
# 15
# AU=TANOR OGET
# 2
# AU=DOGANAY ULKU
# 1
# AU=OZAN ULKU
# 5
# AU=YASAR ULKUHAN
# 5
# AU=AVSAR UMMU
# 9
# AU=TOZOGLU UMMUHAN
# 11
# AU=DAGLI UMMUHAN
# 3
# AU=HARPUT UMMUHAN
# 3
# AU=YILMAZ UMMIHAN
# 16
# AU=AVSAR UMIT
# 19
# AU=BICER UMIT
# 7
# AU=GUL UMIT
# 21
# AU=KARADEMIR UMIT
# 15
# AU=KOC UMIT
# 19
# AU=KURSUN UMIT
# 1
# AU=COPOGLU UMIT
# 26
# AU=TOTUR UMIT
# 44
# AU=YASAR UMIT
# 44
# AU=TEKELIOGLU UMIT
# 21
# AU=OZKAN UMIT
# 148
# AU=INAN UMIT
# 25
# AU=SENER UMIT
# 21
# AU=ADIGUZEL UNAL
# 2
# AU=BILIR UNAL
# 0
# AU=ULUCA UNAL
# 30
# AU=YILDIRIM UNAL
# 7
# AU=ZAL UNAL
# 0
# AU=SEN UNAL
# 27
# AU=SENEL UNAL
# 7
# AU=OGURLU UZEYIR
# 4
# AU=ALTUN IBRAHIM
# 66
# AU=AKPINAR IBRAHIM
# 46
# AU=ARSLAN IBRAHIM
# 6
# AU=BARAN IBRAHIM
# 29
# AU=BUDAK IBRAHIM
# 2
# AU=BILGIN IBRAHIM
# 8
# AU=CAN IBRAHIM
# 15
# AU=DAMLAR IBRAHIM
# 16
# AU=DEMIR IBRAHIM
# 106
# AU=DORUK IBRAHIM
# 1
# AU=ERBAGCI IBRAHIM
# 24
# AU=ERCAN IBRAHIM
# 12
# AU=ERDOGAN IBRAHIM
# 14
# AU=EREN IBRAHIM
# 32
# AU=KARABABA IBRAHIM
# 18
# AU=HEPSEN IBRAHIM
# 27
# AU=GELINCIK IBRAHIM
# 17
# AU=GULER IBRAHIM
# 42
# AU=GUNGOR IBRAHIM
# 5
# AU=HABACI IBRAHIM
# 1
# AU=OZTURK IBRAHIM
# 38
# AU=TASDEMIR IBRAHIM
# 20
# AU=KAYA IBRAHIM
# 64
# AU=KELES IBRAHIM
# 42
# AU=KIR IBRAHIM
# 0
# AU=ONAL IBRAHIM
# 84
# AU=KOSE IBRAHIM
# 4
# AU=OCAK IBRAHIM
# 13
# AU=SARI IBRAHIM
# 159
# AU=ARDIC IBRAHIM
# 0
# AU=SONMEZ IBRAHIM
# 13
# AU=TEGIN IBRAHIM
# 11
# AU=TOBI IBRAHIM
# 4
# AU=TURKYILMAZ IBRAHIM
# 3
# AU=UCAR IBRAHIM
# 60
# AU=YAKUT IBRAHIM
# 15
# AU=USLU IBRAHIM
# 48
# AU=CETINER IBRAHIM
# 3
# AU=OZBEK IBRAHIM
# 10
# AU=KABOGLU IBRAHIM
# 1
# AU=OZDOGRU IBRAHIM
# 64
# AU=OZTURK IBRAHIM
# 38
# AU=SAHIN IBRAHIM
# 121
# AU=SAHIN IBRAHIM
# 121
# AU=SEHITOGLU IBRAHIM
# 35
# AU=IBRAHIMORUNG IBRAHIMORUNG
# 0
# AU=KUCUKKIRCA ICLAL
# 0
# AU=BULUT ICLAL
# 15
# AU=ARDIC IDRIS
# 56
# AU=ARSLAN IDRIS
# 16
# AU=ERDEM IDRIS
# 0
# AU=SARI IDRIS
# 0
# AU=CERKEZ IDRIS
# 30
# AU=CEYLAN IDIL
# 1
# AU=CIRAK IFFET
# 1
# AU=ALUR IHSAN
# 17
# AU=BAKIR IHSAN
# 98
# AU=BAL IHSAN
# 15
# AU=BIRECIKLI IHSAN
# 0
# AU=KIRIK IHSAN
# 12
# AU=AKPINAR IHSAN
# 27
# AU=SATIS IHSAN
# 4
# AU=TASKIN IHSAN
# 2
# AU=DOLAPCI IHSAN
# 6
# AU=YUCE IHSAN
# 59
# AU=CACAN IHSAN
# 0
# AU=CELIK IHSAN
# 13
# AU=UNALDI IHSAN
# 2
# AU=USTUN IHSAN
# 40
# AU=SENTURK IHSAN
# 8
# AU=EGE ILHAMI
# 0
# AU=SOLAK ILHAMI
# 10
# AU=YUKSEL ILHAMI
# 70
# AU=ASILTURK ILHAN
# 13
# AU=BOLUKOGLU ILHAN
# 0
# AU=KARABICAK ILHAN
# 32
# AU=KAYA ILHAN
# 28
# AU=KACIRE ILHAN
# 0
# AU=PEKGOZLU ILHAN
# 15
# AU=TAN ILHAN
# 16
# AU=TAPAN ILHAN
# 9
# AU=TOPUZ ILHAN
# 0
# AU=UZGEL ILHAN
# 1
# AU=BOZKURT ILKAY
# 17
# AU=BAYRAM ILKER
# 38
# AU=SEN ILKER
# 34
# AU=UGULU ILKER
# 18
# AU=AYDINKAYA ILKER
# 0
# AU=EROL ILKNUR
# 60
# AU=ISIK ILKNUR
# 4
# AU=DEMIR IMDAT
# 0
# AU=AKMAN INCI
# 0
# AU=ALTUNTAS IRFAN
# 28
# AU=ATESOGLU IRFAN
# 0
# AU=ACIKGOZ IRFAN
# 10
# AU=BULU IRFAN
# 46
# AU=DEGIRMENCI IRFAN
# 50
# AU=ESER IRFAN
# 19
# AU=KOCA IRFAN
# 50
# AU=KUSCU IRFAN
# 0
# AU=MUKUL IRFAN
# 0
# AU=UCGUN IRFAN
# 6
# AU=YILMAZ IRFAN
# 1
# AU=SAKA IRFAN
# 7
# AU=SIAP IRFAN
# 57
# AU=BALDEMIR ISA
# 0
# AU=DONER ISA
# 0
# AU=SIYPAK ISA
# 0
# AU=TASDELEN ISHAK
# 0
# AU=PARMAKSIZ ISKENDER
# 16
# AU=ACAR ISMAIL
# 7
# AU=AKKAS ISMAIL
# 8
# AU=AKSOY ISMAIL
# 20
# AU=AKTAR ISMAIL
# 0
# AU=ALBAYRAK ISMAIL
# 19
# AU=ALTUNCU ISMAIL
# 0
# AU=ARSEL ISMAIL
# 0
# AU=ARSLAN ISMAIL
# 29
# AU=ERDEN ISMAIL
# 58
# AU=BOYACI ISMAIL
# 122
# AU=BOYRAZ ISMAIL
# 22
# AU=CAPAR ISMAIL
# 42
# AU=DEMIR ISMAIL
# 83
# AU=DOGAN ISMAIL
# 45
# AU=GUNES ISMAIL
# 4
# AU=EREN ISMAIL
# 3
# AU=ERMIS ISMAIL
# 11
# AU=ERTURK ISMAIL
# 35
# AU=GUL ISMAIL
# 15
# AU=GULCU ISMAIL
# 0
# AU=UZUN ISMAIL
# 25
# AU=UGURTAS ISMAIL
# 13
# AU=KARA ISMAIL
# 55
# AU=KATI ISMAIL
# 24
# AU=KENAR ISMAIL
# 2
# AU=KURNAZ ISMAIL
# 6
# AU=KURT ISMAIL
# 49
# AU=KOKSAL ISMAIL
# 16
# AU=KULAHLI ISMAIL
# 6
# AU=MANGALTEPE ISMAIL
# 0
# AU=MARULCU ISMAIL
# 3
# AU=METIN ISMAIL
# 1
# AU=DOGAN ISMAIL
# 45
# AU=UCUN ISMAIL
# 11
# AU=ULUTAS ISMAIL
# 0
# AU=ULUCAY ISMAIL
# 6
# AU=VANLI ISMAIL
# 0
# AU=YILDIZ ISMAIL
# 81
# AU=YUKSEL ISMAIL
# 7
# AU=CAKIR ISMAIL
# 8
# AU=UYSAL ISMAIL
# 87
# AU=OZDEMIR ISMAIL
# 179
# AU=OZTURK ISMAIL
# 33
# AU=SAHIN ISMAIL
# 77
# AU=SAHIN ISMAIL
# 77
# AU=SENER ISMAIL
# 19
# AU=AKCA ISMET
# 1
# AU=BASARAN ISMET
# 12
# AU=BINER ISMET
# 0
# AU=DURAN ISMET
# 3
# AU=GOCER ISMET
# 6
# AU=OZDEMIR ISMET
# 11
# AU=OZTURK ISMET
# 52
# AU=SANLI ISMET
# 0
# AU=BABACAN ISRAFIL
# 1
# AU=DOS IZZET
# 8
# AU=LOFCA IZZET
# 0
# AU=CICEKBILEK IZZET
# 7
# AU=GUCLU SABAN
# 9
# AU=TEZCAN SABAN
# 0
# AU=CETIN SABAN
# 12
# AU=AYDIN SADI
# 0
# AU=BARANOGLU SAHIN
# 0
# AU=BATMAZ SAKIR
# 0
# AU=YILMAZ SAZIYE
# 4
# AU=AKSOY SEFIKA
# 17
# AU=EKIM SEFIKA
# 2
# AU=KARACA SEMSETTIN
# 44
# AU=ULUSAL SEMSETTIN
# 0
# AU=SAHIN SEMSETTIN
# 48
# AU=KARABUGA SEMISTAN
# 19
# AU=TASDEMIR SENER
# 16
# AU=ULUDAG SENER
# 0
# AU=CELIK SENGUL
# 0
# AU=SISE SENGUL
# 2
# AU=OZDEMIR SENNUR
# 1
# AU=OKAY SENOL
# 9
# AU=AYKUT SEREF
# 6
# AU=KURT SEREF
# 21
# AU=OKUDUCU SEREF
# 6
# AU=OLGAR SEREF
# 20
# AU=POYRAZ SEREF
# 0
# AU=YUKSEL SEREF
# 39
# AU=SIMSEK SEREF
# 20
# AU=TUNA SERIF
# 0
# AU=KAHRAMAN SERIF
# 9
# AU=AKALIN SERIFE
# 18
# AU=ALTINDAG SERIFE
# 0
# AU=OZLEN SERIFE
# 0
# AU=ARIKAN SEVKET
# 24
# AU=ATA SEVKET
# 10
# AU=CIVELEK SEVKET
# 2
# AU=TUYLUOGLU SEVKET
# 0
# AU=TARIM SEYDA
# 3
# AU=ARI SEYHMUS
# 42
# AU=YAVUZ SEYMA
# 0
# AU=CIVITCI SULE
# 4
# AU=ATALAY SULE
# 5
# AU=ULGER SUKRAN
# 20
# AU=ARSLAN SUKRU
# 42
# AU=DUZGUN SUKRU
# 10
# AU=BOYLU SUKRU
# 5
# AU=KARAKAYA SUKRU
# 9
# AU=KILIC SUKRU
# 0
# AU=TAKTAK SUKRU
# 18
# AU=CAKMAKTEPE SUKRU
# 3
# AU=HISAR SUKRIYE
# 8
# AU=KARADAS SUKRIYE
# 0

# %%
df = pd.DataFrame([names,lens]).T
df.columns=['Author','NoPapers']

# %%
# 753 out of 3575 people have 0 papers in the web of science dataset
zeropapers = df.loc[df.NoPapers==0].copy()

# %%
# df.to_csv('Publishments.csv')

# %%
zeropapers.to_csv('ZeroPublishment.csv')

# %%
pd.concat([SearchNames,df],axis=1).to_csv('Publishments.csv')

# %%
pd.read_csv('Publishments.csv')
# Out:
#       Unnamed: 0                SearchNames                  Author  NoPapers
# 0              0             AU=AYDIN AYDIN             AYDIN AYDIN         4
# 1              1            AU=GILGIL ERDAL            GILGIL ERDAL         5
# 2              2             AU=HALAC METIN             HALAC METIN        63
# 3              3         AU=YUCE ABDULHAKIM         YUCE ABDULHAKIM         0
# 4              4        AU=KIRIS ABDULKADIR        KIRIS ABDULKADIR        54
# 5              5  AU=KUCUKBAYRAK ABDULKADIR  KUCUKBAYRAK ABDULKADIR        30
# 6              6     AU=YILDIRIM ABDULKADIR     YILDIRIM ABDULKADIR        33
# 7              7        AU=CEKIN ABDULKADIR        CEKIN ABDULKADIR         0
# 8              8       AU=SENGUN ABDULKADIR       SENGUN ABDULKADIR        13
# 9              9        AU=BEDIR ABDULKERIM        BEDIR ABDULKERIM        38
# 10            10        AU=AKPINAR ABDULLAH        AKPINAR ABDULLAH        38
# 11            11            AU=BAL ABDULLAH            BAL ABDULLAH        26
# 12            12         AU=SENGUL ABDULLAH         SENGUL ABDULLAH         3
# 13            13          AU=DEMIR ABDULLAH          DEMIR ABDULLAH        54
# 14            14          AU=DOGAN ABDULLAH          DOGAN ABDULLAH       112
# 15            15         AU=EKIZER ABDULLAH         EKIZER ABDULLAH        13
# 16            16          AU=ERDIL ABDULLAH          ERDIL ABDULLAH         5
# 17            17          AU=ERGIN ABDULLAH          ERGIN ABDULLAH         3
# 18            18         AU=SECKIN ABDULLAH         SECKIN ABDULLAH         1
# 19            19          AU=KIRAN ABDULLAH          KIRAN ABDULLAH         0
# 20            20          AU=USTUN ABDULLAH          USTUN ABDULLAH         5
# 21            21          AU=CINGU ABDULLAH          CINGU ABDULLAH        46
# 22            22          AU=AKSOY ABDULLAH          AKSOY ABDULLAH         1
# 23            23         AU=TUNCER ABDULLAH         TUNCER ABDULLAH         0
# 24            24          AU=MUTLU ABDULLAH          MUTLU ABDULLAH         0
# 25            25         AU=KILDAN ABDULLAH         KILDAN ABDULLAH         2
# 26            26            AU=POS ABDULLAH            POS ABDULLAH         0
# 27            27         AU=SONMEZ ABDULLAH         SONMEZ ABDULLAH        22
# 28            28           AU=URAL ABDULLAH           URAL ABDULLAH         1
# 29            29         AU=YORDEM ABDULLAH         YORDEM ABDULLAH         0
# ...          ...                        ...                     ...       ...
# 3545        3545              AU=KURT SEREF              KURT SEREF        21
# 3546        3546           AU=OKUDUCU SEREF           OKUDUCU SEREF         6
# 3547        3547             AU=OLGAR SEREF             OLGAR SEREF        20
# 3548        3548            AU=POYRAZ SEREF            POYRAZ SEREF         0
# 3549        3549            AU=YUKSEL SEREF            YUKSEL SEREF        39
# 3550        3550            AU=SIMSEK SEREF            SIMSEK SEREF        20
# 3551        3551              AU=TUNA SERIF              TUNA SERIF         0
# 3552        3552          AU=KAHRAMAN SERIF          KAHRAMAN SERIF         9
# 3553        3553           AU=AKALIN SERIFE           AKALIN SERIFE        18
# 3554        3554         AU=ALTINDAG SERIFE         ALTINDAG SERIFE         0
# 3555        3555            AU=OZLEN SERIFE            OZLEN SERIFE         0
# 3556        3556           AU=ARIKAN SEVKET           ARIKAN SEVKET        24
# 3557        3557              AU=ATA SEVKET              ATA SEVKET        10
# 3558        3558          AU=CIVELEK SEVKET          CIVELEK SEVKET         2
# 3559        3559        AU=TUYLUOGLU SEVKET        TUYLUOGLU SEVKET         0
# 3560        3560             AU=TARIM SEYDA             TARIM SEYDA         3
# 3561        3561             AU=ARI SEYHMUS             ARI SEYHMUS        42
# 3562        3562             AU=YAVUZ SEYMA             YAVUZ SEYMA         0
# 3563        3563            AU=CIVITCI SULE            CIVITCI SULE         4
# 3564        3564             AU=ATALAY SULE             ATALAY SULE         5
# 3565        3565            AU=ULGER SUKRAN            ULGER SUKRAN        20
# 3566        3566            AU=ARSLAN SUKRU            ARSLAN SUKRU        42
# 3567        3567            AU=DUZGUN SUKRU            DUZGUN SUKRU        10
# 3568        3568             AU=BOYLU SUKRU             BOYLU SUKRU         5
# 3569        3569          AU=KARAKAYA SUKRU          KARAKAYA SUKRU         9
# 3570        3570             AU=KILIC SUKRU             KILIC SUKRU         0
# 3571        3571            AU=TAKTAK SUKRU            TAKTAK SUKRU        18
# 3572        3572        AU=CAKMAKTEPE SUKRU        CAKMAKTEPE SUKRU         3
# 3573        3573           AU=HISAR SUKRIYE           HISAR SUKRIYE         8
# 3574        3574         AU=KARADAS SUKRIYE         KARADAS SUKRIYE         0
#
# [3575 rows x 4 columns]
