# %% [markdown]
# # WosClient

# %%
# !pip install suds-jurko

from suds import client
from base64 import b64encode as _b64encode
from collections import OrderedDict as _OrderedDict

class WosClient():
    """Query the Web of Science.
       You must provide user and password only to user premium WWS service.
       with WosClient() as wos:
           results = wos.search(...)"""

    base_url = 'http://search.webofknowledge.com'
    auth_url = base_url + '/esti/wokmws/ws/WOKMWSAuthenticate?wsdl'
    search_url = base_url + '/esti/wokmws/ws/WokSearch?wsdl'
    searchlite_url = base_url + '/esti/wokmws/ws/WokSearchLite?wsdl'

    def __init__(self, user=None, password=None, SID=None, close_on_exit=True,
                 lite=False):
        """Create the SOAP clients. user and password for premium access."""

        self._SID = SID
        self._close_on_exit = close_on_exit
        search_wsdl = self.searchlite_url if lite else self.search_url
        self._auth = client.Client(self.auth_url)
        self._search = client.Client(search_wsdl)

        if user and password:
            auth = '%s:%s' % (user, password)
            auth = _b64encode(auth.encode('utf-8')).decode('utf-8')
            headers = {'Authorization': ('Basic %s' % auth).strip()}
            self._auth.set_options(headers=headers)

    def __enter__(self):
        """Automatically connect when used with 'with' statements."""
        self.connect()
        return self

    def __exit__(self, exc_type, exc_value, traceback):
        """Close connection after closing the 'with' statement."""
        if self._close_on_exit:
            self.close()

    def __del__(self):
        """Close connection when deleting the object."""
        if self._close_on_exit:
            self.close()

    def connect(self):
        """Authenticate to WOS and set the SID cookie."""
        if not self._SID:
            self._SID = self._auth.service.authenticate()
            print('Authenticated (SID: %s)' % self._SID)

        self._search.set_options(headers={'Cookie': 'SID="%s"' % self._SID})
        self._auth.options.headers.update({'Cookie': 'SID="%s"' % self._SID})
        return self._SID

    def close(self):
        """Close the session."""
        if self._SID:
            self._auth.service.closeSession()
            self._SID = None

    def search(self, query, count=100, offset=1):
    # def search(self, query, offset=1):
        """Perform a query. Check the WOS documentation for v3 syntax."""
        if not self._SID:
            raise RuntimeError('Session not open. Invoke .connect() before.')

        qparams = _OrderedDict([('databaseId', 'WOS'),
                                ('userQuery', query),
                                ('queryLanguage', 'en')])

        rparams = _OrderedDict([('firstRecord', offset),
                                ('count', count),
                                ('sortField', _OrderedDict([('name', 'RS'),
                                                            ('sort', 'D')]))])

        return self._search.service.search(qparams, rparams)

# %%
from xml.etree import ElementTree as _ET
from xml.dom import minidom as _minidom
import re as _re

def single(wosclient, wos_query, xml_query=None, count=10, offset=1):
    """Perform a single Web of Science query and then XML query the results."""
    result = wosclient.search(wos_query, count, offset)
    print (result)
    xml = _re.sub(' xmlns="[^"]+"', '', result.records, count=1).encode('utf-8')
    if xml_query:
        xml = _ET.fromstring(xml)
        return [el.text for el in xml.findall(xml_query)]
    else:
        return _minidom.parseString(xml).toprettyxml()

def query(wosclient, wos_query, xml_query=None, count=10, offset=1, limit=100):
    """Query Web of Science and XML query results with multiple requests."""
    results = [single(wosclient, wos_query, xml_query, min(limit, count-x+1), x) for x in range(offset, count+1, limit)]
    if xml_query:
        return [el for res in results for el in res]
    else:
        pattern = _re.compile(r'.*?<records>|</records>.*', _re.DOTALL)
        return ('<?xml version="1.0" ?>\n<records>' +
                '\n'.join(pattern.sub('', res) for res in results) +
                '</records>')

def doi_to_wos(wosclient, doi):
    """Convert DOI to WOS identifier."""
    results = query(wosclient, 'DO=%s' % doi, './REC/UID', count=1)
    return results[0].lstrip('WOS:') if results else None

# %%
soap = WosClient(lite=True)
soap.connect()
# Out:
# Authenticated (SID: C53pSTtQ5V2zBW7uKJi)
# C53pSTtQ5V2zBW7uKJi

# %%
import pprint

results = soap.search("AU='YUKSEL SEREF' ")
pprint.pprint(results)
# Out:
# (searchResults){
#    queryId = "2"
#    recordsFound = 39
#    recordsSearched = 69042800
#    records[] =
#       (liteRecord){
#          uid = "WOS:000262673000006"
#          title[] =
#             (labelValuesPair){
#                label = "Title"
#                value[] =
#                   "Does Helicobacter pylori-induced inflammation of gastric mucosa determine the severity of symptoms in functional dyspepsia?",
#             },
#          doctype[] =
#             (labelValuesPair){
#                label = "Doctype"
#                value[] =
#                   "Article",
#             },
#          source[] =
#             (labelValuesPair){
#                label = "Issue"
#                value[] =
#                   "1",
#             },
#             (labelValuesPair){
#                label = "Pages"
#                value[] =
#                   "66-70",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioDate"
#                value[] =
#                   "JAN",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioYear"
#                value[] =
#                   "2009",
#             },
#             (labelValuesPair){
#                label = "SourceTitle"
#                value[] =
#                   "JOURNAL OF GASTROENTEROLOGY",
#             },
#             (labelValuesPair){
#                label = "Volume"
#                value[] =
#                   "44",
#             },
#          authors[] =
#             (labelValuesPair){
#                label = "Authors"
#                value[] =
#                   "Turkkan, Ebru",
#                   "Uslan, Ihsan",
#                   "Acarturk, Gursel",
#                   "Topak, Nevin",
#                   "Kahraman, Ahmet",
#                   "Dilek, Fatma Husniye",
#                   "Akcan, Yusuf",
#                   "Karaman, Ozcan",
#                   "Colbay, Mehmet",
#                   "Yuksel, Seref",
#             },
#          keywords[] =
#             (labelValuesPair){
#                label = "Keywords"
#                value[] =
#                   "oxidative stress",
#                   "chronic gastritis",
#                   "symptom scores",
#             },
#          other[] =
#             (labelValuesPair){
#                label = "Identifier.Doi"
#                value[] =
#                   "10.1007/s00535-008-2271-9",
#             },
#             (labelValuesPair){
#                label = "Identifier.Ids"
#                value[] =
#                   "397OW",
#             },
#             (labelValuesPair){
#                label = "Identifier.Issn"
#                value[] =
#                   "0944-1174",
#             },
#             (labelValuesPair){
#                label = "ResearcherID.Disclaimer"
#                value[] =
#                   "ResearcherID data provided by Clarivate Analytics",
#             },
#       },
#       (liteRecord){
#          uid = "WOS:000258063200036"
#          title[] =
#             (labelValuesPair){
#                label = "Title"
#                value[] =
#                   "Carotid hemodynamic parameters in hemodialysis patients",
#             },
#          doctype[] =
#             (labelValuesPair){
#                label = "Doctype"
#                value[] =
#                   "Article",
#             },
#          source[] =
#             (labelValuesPair){
#                label = "Issue"
#                value[] =
#                   "3",
#             },
#             (labelValuesPair){
#                label = "Pages"
#                value[] =
#                   "779-784",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioDate"
#                value[] =
#                   "SEP",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioYear"
#                value[] =
#                   "2008",
#             },
#             (labelValuesPair){
#                label = "SourceTitle"
#                value[] =
#                   "INTERNATIONAL UROLOGY AND NEPHROLOGY",
#             },
#             (labelValuesPair){
#                label = "Volume"
#                value[] =
#                   "40",
#             },
#          authors[] =
#             (labelValuesPair){
#                label = "Authors"
#                value[] =
#                   "Karaman, Ozcan",
#                   "Albayrak, Ramazan",
#                   "Colbay, Mehmet",
#                   "Yuksel, Seref",
#                   "Uslan, Ihsan",
#                   "Acarturk, Gursel",
#                   "Saglam, Hayrettin",
#             },
#          keywords[] =
#             (labelValuesPair){
#                label = "Keywords"
#                value[] =
#                   "atherosclerosis",
#                   "pulsatility index",
#                   "resistive index",
#                   "intima-media thickness",
#                   "renal failure",
#             },
#          other[] =
#             (labelValuesPair){
#                label = "Identifier.Doi"
#                value[] =
#                   "10.1007/s11255-007-9314-7",
#             },
#             (labelValuesPair){
#                label = "Identifier.Ids"
#                value[] =
#                   "332DV",
#             },
#             (labelValuesPair){
#                label = "Identifier.Issn"
#                value[] =
#                   "0301-1623",
#             },
#             (labelValuesPair){
#                label = "Identifier.Xref_Doi"
#                value[] =
#                   "10.1007/s11255-007-9314-7",
#             },
#             (labelValuesPair){
#                label = "ResearcherID.Disclaimer"
#                value[] =
#                   "ResearcherID data provided by Clarivate Analytics",
#             },
#       },
#       (liteRecord){
#          uid = "WOS:000258063200037"
#          title[] =
#             (labelValuesPair){
#                label = "Title"
#                value[] =
#                   "Comparison of sleep quality between hemodialysis and peritoneal dialysis patients",
#             },
#          doctype[] =
#             (labelValuesPair){
#                label = "Doctype"
#                value[] =
#                   "Article",
#             },
#          source[] =
#             (labelValuesPair){
#                label = "Issue"
#                value[] =
#                   "3",
#             },
#             (labelValuesPair){
#                label = "Pages"
#                value[] =
#                   "785-791",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioDate"
#                value[] =
#                   "SEP",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioYear"
#                value[] =
#                   "2008",
#             },
#             (labelValuesPair){
#                label = "SourceTitle"
#                value[] =
#                   "INTERNATIONAL UROLOGY AND NEPHROLOGY",
#             },
#             (labelValuesPair){
#                label = "Volume"
#                value[] =
#                   "40",
#             },
#          authors[] =
#             (labelValuesPair){
#                label = "Authors"
#                value[] =
#                   "Eryavuz, Nazmiye",
#                   "Yuksel, Seref",
#                   "Acarturk, Gursel",
#                   "Uslan, Ihsan",
#                   "Demir, Serap",
#                   "Demir, Murat",
#                   "Sezer, M. Tugrul",
#             },
#          keywords[] =
#             (labelValuesPair){
#                label = "Keywords"
#                value[] =
#                   "end-stage renal disease",
#                   "hemodialysis",
#                   "peritoneal dialysis",
#                   "Pittsburgh sleep quality index",
#                   "sleep disturbances",
#             },
#          other[] =
#             (labelValuesPair){
#                label = "Identifier.Doi"
#                value[] =
#                   "10.1007/s11255-008-9359-2",
#             },
#             (labelValuesPair){
#                label = "Identifier.Ids"
#                value[] =
#                   "332DV",
#             },
#             (labelValuesPair){
#                label = "Identifier.Issn"
#                value[] =
#                   "0301-1623",
#             },
#             (labelValuesPair){
#                label = "Identifier.Xref_Doi"
#                value[] =
#                   "10.1007/s11255-008-9359-2",
#             },
#             (labelValuesPair){
#                label = "ResearcherID.Disclaimer"
#                value[] =
#                   "ResearcherID data provided by Clarivate Analytics",
#             },
#       },
#       (liteRecord){
#          uid = "WOS:000256194700041"
#          title[] =
#             (labelValuesPair){
#                label = "Title"
#                value[] =
#                   "The relationship between arteriovenous fistula blood flow rate and pulmonary artery pressure in hemodialysis patients",
#             },
#          doctype[] =
#             (labelValuesPair){
#                label = "Doctype"
#                value[] =
#                   "Article",
#             },
#          source[] =
#             (labelValuesPair){
#                label = "Issue"
#                value[] =
#                   "2",
#             },
#             (labelValuesPair){
#                label = "Pages"
#                value[] =
#                   "509-513",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioYear"
#                value[] =
#                   "2008",
#             },
#             (labelValuesPair){
#                label = "SourceTitle"
#                value[] =
#                   "INTERNATIONAL UROLOGY AND NEPHROLOGY",
#             },
#             (labelValuesPair){
#                label = "Volume"
#                value[] =
#                   "40",
#             },
#          authors[] =
#             (labelValuesPair){
#                label = "Authors"
#                value[] =
#                   "Acarturk, Gursel",
#                   "Albayrak, Ramazan",
#                   "Melek, Mehmet",
#                   "Yuksel, Seref",
#                   "Uslan, Ihsan",
#                   "Atli, Huseyin",
#                   "Colbay, Mehmet",
#                   "Unlu, Mehmet",
#                   "Fidan, Fatma",
#                   "Asci, Zerrin",
#                   "Cander, Soner",
#                   "Karaman, Ozcan",
#                   "Acar, Murat",
#             },
#          keywords[] =
#             (labelValuesPair){
#                label = "Keywords"
#                value[] =
#                   "arteriovenous fistula",
#                   "blood flow rate",
#                   "hemodialysis",
#                   "pulmonary artery pressure",
#                   "pulmonary hypertension",
#             },
#          other[] =
#             (labelValuesPair){
#                label = "Contributor.ResearcherID.Names"
#                value[] =
#                   "ACAR, MURAT",
#             },
#             (labelValuesPair){
#                label = "Contributor.ResearcherID.ResearcherIDs"
#                value[] =
#                   "C-7629-2014",
#             },
#             (labelValuesPair){
#                label = "Identifier.Doi"
#                value[] =
#                   "10.1007/s11255-007-9269-8",
#             },
#             (labelValuesPair){
#                label = "Identifier.Ids"
#                value[] =
#                   "305RE",
#             },
#             (labelValuesPair){
#                label = "Identifier.Issn"
#                value[] =
#                   "0301-1623",
#             },
#             (labelValuesPair){
#                label = "Identifier.Xref_Doi"
#                value[] =
#                   "10.1007/s11255-007-9269-8",
#             },
#             (labelValuesPair){
#                label = "ResearcherID.Disclaimer"
#                value[] =
#                   "ResearcherID data provided by Clarivate Analytics",
#             },
#       },
#       (liteRecord){
#          uid = "WOS:000253320601034"
#          title[] =
#             (labelValuesPair){
#                label = "Title"
#                value[] =
#                   "The comparasion of sleep quality between hemodialysis and periton dialysis patients",
#             },
#          doctype[] =
#             (labelValuesPair){
#                label = "Doctype"
#                value[] =
#                   "Meeting Abstract",
#             },
#          source[] =
#             (labelValuesPair){
#                label = "Pages"
#                value[] =
#                   "369-369",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioYear"
#                value[] =
#                   "2007",
#             },
#             (labelValuesPair){
#                label = "SourceTitle"
#                value[] =
#                   "NEPHROLOGY DIALYSIS TRANSPLANTATION",
#             },
#             (labelValuesPair){
#                label = "SupplementNumber"
#                value[] =
#                   "6",
#             },
#             (labelValuesPair){
#                label = "Volume"
#                value[] =
#                   "22",
#             },
#          authors[] =
#             (labelValuesPair){
#                label = "Authors"
#                value[] =
#                   "Eryavuz, Nazmiye",
#                   "Yuksel, Seref",
#                   "Acarturk, Gursel",
#                   "Uslan, Ihsan",
#                   "Demir, Serap",
#                   "Sezer, M. Tugrul",
#             },
#          other[] =
#             (labelValuesPair){
#                label = "Identifier.Ids"
#                value[] =
#                   "264WH",
#             },
#             (labelValuesPair){
#                label = "Identifier.Issn"
#                value[] =
#                   "0931-0509",
#             },
#             (labelValuesPair){
#                label = "ResearcherID.Disclaimer"
#                value[] =
#                   "ResearcherID data provided by Clarivate Analytics",
#             },
#       },
#       (liteRecord){
#          uid = "WOS:000251405700002"
#          title[] =
#             (labelValuesPair){
#                label = "Title"
#                value[] =
#                   "The effects of weight loss on normal transaminase levels in obese patients",
#             },
#          doctype[] =
#             (labelValuesPair){
#                label = "Doctype"
#                value[] =
#                   "Article",
#                   "Proceedings Paper",
#             },
#          source[] =
#             (labelValuesPair){
#                label = "Issue"
#                value[] =
#                   "5",
#             },
#             (labelValuesPair){
#                label = "Pages"
#                value[] =
#                   "327-330",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioDate"
#                value[] =
#                   "NOV",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioYear"
#                value[] =
#                   "2007",
#             },
#             (labelValuesPair){
#                label = "SourceTitle"
#                value[] =
#                   "AMERICAN JOURNAL OF THE MEDICAL SCIENCES",
#             },
#             (labelValuesPair){
#                label = "Volume"
#                value[] =
#                   "334",
#             },
#          authors[] =
#             (labelValuesPair){
#                label = "Authors"
#                value[] =
#                   "Uslan, Ihsan",
#                   "Acarturk, Gursel",
#                   "Karaca, Esen",
#                   "Albayrak, Ramazan",
#                   "Yuksel, Seref",
#                   "Colbay, Mehmet",
#                   "Karaman, Ozcan",
#                   "Akcan, Yusuf",
#             },
#          keywords[] =
#             (labelValuesPair){
#                label = "Keywords"
#                value[] =
#                   "obesity",
#                   "transaminases",
#                   "insulin resistance",
#             },
#          other[] =
#             (labelValuesPair){
#                label = "Identifier.Eissn"
#                value[] =
#                   "1538-2990",
#             },
#             (labelValuesPair){
#                label = "Identifier.Ids"
#                value[] =
#                   "237VY",
#             },
#             (labelValuesPair){
#                label = "Identifier.Issn"
#                value[] =
#                   "0002-9629",
#             },
#             (labelValuesPair){
#                label = "Identifier.Xref_Doi"
#                value[] =
#                   "10.1097/MAJ.0b013e3181557702",
#             },
#             (labelValuesPair){
#                label = "ResearcherID.Disclaimer"
#                value[] =
#                   "ResearcherID data provided by Clarivate Analytics",
#             },
#       },
#       (liteRecord){
#          uid = "WOS:000246913000008"
#          title[] =
#             (labelValuesPair){
#                label = "Title"
#                value[] =
#                   "Investigation of hemodialysis patients in terms of the presence of occult hepatitis B",
#             },
#          doctype[] =
#             (labelValuesPair){
#                label = "Doctype"
#                value[] =
#                   "Article",
#             },
#          source[] =
#             (labelValuesPair){
#                label = "Issue"
#                value[] =
#                   "2",
#             },
#             (labelValuesPair){
#                label = "Pages"
#                value[] =
#                   "227-233",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioDate"
#                value[] =
#                   "APR",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioYear"
#                value[] =
#                   "2007",
#             },
#             (labelValuesPair){
#                label = "SourceTitle"
#                value[] =
#                   "MIKROBIYOLOJI BULTENI",
#             },
#             (labelValuesPair){
#                label = "Volume"
#                value[] =
#                   "41",
#             },
#          authors[] =
#             (labelValuesPair){
#                label = "Authors"
#                value[] =
#                   "Altindis, Mustafa",
#                   "Uslan, Ihsan",
#                   "Cetinkaya, Zafer",
#                   "Yuksel, Seref",
#                   "Ciftci, I. Hakki",
#                   "Demirturk, Nese",
#                   "Ozdemir, Mujgan",
#                   "Arslan, Fadime",
#                   "Aktepe, O. Cem",
#             },
#          keywords[] =
#             (labelValuesPair){
#                label = "Keywords"
#                value[] =
#                   "hepatitis B virus (HBV)",
#                   "occult HBV",
#                   "hemodialysis patients",
#             },
#          other[] =
#             (labelValuesPair){
#                label = "Contributor.ResearcherID.Names"
#                value[] =
#                   "Cetinkaya, Zafer",
#             },
#             (labelValuesPair){
#                label = "Contributor.ResearcherID.ResearcherIDs"
#                value[] =
#                   "J-3330-2013",
#             },
#             (labelValuesPair){
#                label = "Identifier.Ids"
#                value[] =
#                   "174AG",
#             },
#             (labelValuesPair){
#                label = "Identifier.Issn"
#                value[] =
#                   "0374-9096",
#             },
#             (labelValuesPair){
#                label = "ResearcherID.Disclaimer"
#                value[] =
#                   "ResearcherID data provided by Clarivate Analytics",
#             },
#       },
#       (liteRecord){
#          uid = "WOS:000247994900014"
#          title[] =
#             (labelValuesPair){
#                label = "Title"
#                value[] =
#                   "The cutaneous silent period in diabetes mellitus",
#             },
#          doctype[] =
#             (labelValuesPair){
#                label = "Doctype"
#                value[] =
#                   "Article",
#             },
#          source[] =
#             (labelValuesPair){
#                label = "Issue"
#                value[] =
#                   "3",
#             },
#             (labelValuesPair){
#                label = "Pages"
#                value[] =
#                   "258-262",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioDate"
#                value[] =
#                   "JUN 4",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioYear"
#                value[] =
#                   "2007",
#             },
#             (labelValuesPair){
#                label = "SourceTitle"
#                value[] =
#                   "NEUROSCIENCE LETTERS",
#             },
#             (labelValuesPair){
#                label = "Volume"
#                value[] =
#                   "419",
#             },
#          authors[] =
#             (labelValuesPair){
#                label = "Authors"
#                value[] =
#                   "Yaman, Mehmet",
#                   "Uluduz, Derya",
#                   "Yuksel, Seref",
#                   "Pay, Gunes",
#                   "Kiziltan, Meral Erdemir",
#             },
#          keywords[] =
#             (labelValuesPair){
#                label = "Keywords"
#                value[] =
#                   "cutaneous silent period",
#                   "diabetes mellitus",
#                   "small fiber involvement",
#             },
#          other[] =
#             (labelValuesPair){
#                label = "Identifier.Doi"
#                value[] =
#                   "10.1016/j.neulet.2007.04.018",
#             },
#             (labelValuesPair){
#                label = "Identifier.Ids"
#                value[] =
#                   "189NF",
#             },
#             (labelValuesPair){
#                label = "Identifier.Issn"
#                value[] =
#                   "0304-3940",
#             },
#             (labelValuesPair){
#                label = "Identifier.Xref_Doi"
#                value[] =
#                   "10.1016/j.neulet.2007.04.018",
#             },
#             (labelValuesPair){
#                label = "ResearcherID.Disclaimer"
#                value[] =
#                   "ResearcherID data provided by Clarivate Analytics",
#             },
#       },
#       (liteRecord){
#          uid = "WOS:000245883000004"
#          title[] =
#             (labelValuesPair){
#                label = "Title"
#                value[] =
#                   "Hemodynamic changes in the cephalic vein of patients with hemodialysis arteriovenous fistula",
#             },
#          doctype[] =
#             (labelValuesPair){
#                label = "Doctype"
#                value[] =
#                   "Article",
#             },
#          source[] =
#             (labelValuesPair){
#                label = "Issue"
#                value[] =
#                   "3",
#             },
#             (labelValuesPair){
#                label = "Pages"
#                value[] =
#                   "133-137",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioDate"
#                value[] =
#                   "MAR-APR",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioYear"
#                value[] =
#                   "2007",
#             },
#             (labelValuesPair){
#                label = "SourceTitle"
#                value[] =
#                   "JOURNAL OF CLINICAL ULTRASOUND",
#             },
#             (labelValuesPair){
#                label = "Volume"
#                value[] =
#                   "35",
#             },
#          authors[] =
#             (labelValuesPair){
#                label = "Authors"
#                value[] =
#                   "Albayrak, Ramazan",
#                   "Yuksel, Seref",
#                   "Colbay, Mehmet",
#                   "Degirmenci, Bumin",
#                   "Acarturk, Gursel",
#                   "Haktanir, Alpay",
#                   "Karaman, Ozcan",
#             },
#          keywords[] =
#             (labelValuesPair){
#                label = "Keywords"
#                value[] =
#                   "arteriovenous fistula",
#                   "cephalic vein",
#                   "venous access",
#                   "chronic hemodialysis",
#                   "Doppler ultrasonography",
#             },
#          other[] =
#             (labelValuesPair){
#                label = "Identifier.Doi"
#                value[] =
#                   "10.1002/jcu.20307",
#             },
#             (labelValuesPair){
#                label = "Identifier.Ids"
#                value[] =
#                   "159RD",
#             },
#             (labelValuesPair){
#                label = "Identifier.Issn"
#                value[] =
#                   "0091-2751",
#             },
#             (labelValuesPair){
#                label = "Identifier.Xref_Doi"
#                value[] =
#                   "10.1002/jcu.20307",
#             },
#             (labelValuesPair){
#                label = "ResearcherID.Disclaimer"
#                value[] =
#                   "ResearcherID data provided by Clarivate Analytics",
#             },
#       },
#       (liteRecord){
#          uid = "WOS:000245136900009"
#          title[] =
#             (labelValuesPair){
#                label = "Title"
#                value[] =
#                   "Temperament and character profile in patients with essential hyperhidrosis",
#             },
#          doctype[] =
#             (labelValuesPair){
#                label = "Doctype"
#                value[] =
#                   "Article",
#             },
#          source[] =
#             (labelValuesPair){
#                label = "Issue"
#                value[] =
#                   "3",
#             },
#             (labelValuesPair){
#                label = "Pages"
#                value[] =
#                   "240-245",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioYear"
#                value[] =
#                   "2007",
#             },
#             (labelValuesPair){
#                label = "SourceTitle"
#                value[] =
#                   "DERMATOLOGY",
#             },
#             (labelValuesPair){
#                label = "Volume"
#                value[] =
#                   "214",
#             },
#          authors[] =
#             (labelValuesPair){
#                label = "Authors"
#                value[] =
#                   "Karaca, Semsettin",
#                   "Emul, Murat",
#                   "Kulac, Mustafa",
#                   "Yuksel, Seref",
#                   "Ozbulut, Omer",
#                   "Guler, Ozkan",
#                   "Gecici, Omer",
#             },
#          keywords[] =
#             (labelValuesPair){
#                label = "Keywords"
#                value[] =
#                   "essential hyperhidrosis",
#                   "temperament",
#                   "character",
#                   "personality disorder",
#             },
#          other[] =
#             (labelValuesPair){
#                label = "Identifier.Doi"
#                value[] =
#                   "10.1159/000099589",
#             },
#             (labelValuesPair){
#                label = "Identifier.Ids"
#                value[] =
#                   "149HD",
#             },
#             (labelValuesPair){
#                label = "Identifier.Issn"
#                value[] =
#                   "1018-8665",
#             },
#             (labelValuesPair){
#                label = "Identifier.Xref_Doi"
#                value[] =
#                   "10.1159/000099589",
#             },
#             (labelValuesPair){
#                label = "ResearcherID.Disclaimer"
#                value[] =
#                   "ResearcherID data provided by Clarivate Analytics",
#             },
#       },
#       (liteRecord){
#          uid = "WOS:000239919003186"
#          title[] =
#             (labelValuesPair){
#                label = "Title"
#                value[] =
#                   "A research on the sociotrophic-autonomic personality characteristics and the perception about problem solving abilities of hemodialysis patients",
#             },
#          doctype[] =
#             (labelValuesPair){
#                label = "Doctype"
#                value[] =
#                   "Meeting Abstract",
#             },
#          source[] =
#             (labelValuesPair){
#                label = "Pages"
#                value[] =
#                   "478-478",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioDate"
#                value[] =
#                   "JUL",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioYear"
#                value[] =
#                   "2006",
#             },
#             (labelValuesPair){
#                label = "SourceTitle"
#                value[] =
#                   "NEPHROLOGY DIALYSIS TRANSPLANTATION",
#             },
#             (labelValuesPair){
#                label = "SupplementNumber"
#                value[] =
#                   "4",
#             },
#             (labelValuesPair){
#                label = "Volume"
#                value[] =
#                   "21",
#             },
#          authors[] =
#             (labelValuesPair){
#                label = "Authors"
#                value[] =
#                   "Demir, Serap",
#                   "Yuksel, Seref",
#                   "Tufan, Gulnihal",
#                   "Birge, Pervin",
#                   "Yilmaz, Asuman",
#                   "Dincer, Figen",
#                   "Dogan, Mehtap",
#                   "Ozsari, Alev",
#                   "Isik, Ayse",
#                   "Ulupinar, Yasemin",
#             },
#          other[] =
#             (labelValuesPair){
#                label = "Identifier.Ids"
#                value[] =
#                   "075WZ",
#             },
#             (labelValuesPair){
#                label = "Identifier.Issn"
#                value[] =
#                   "0931-0509",
#             },
#             (labelValuesPair){
#                label = "ResearcherID.Disclaimer"
#                value[] =
#                   "ResearcherID data provided by Clarivate Analytics",
#             },
#       },
#       (liteRecord){
#          uid = "WOS:000239919002340"
#          title[] =
#             (labelValuesPair){
#                label = "Title"
#                value[] =
#                   "Clinical factors associated with hyperkalemia in patients during combined therapy with ACEI, ARB and spironolactone",
#             },
#          doctype[] =
#             (labelValuesPair){
#                label = "Doctype"
#                value[] =
#                   "Meeting Abstract",
#             },
#          source[] =
#             (labelValuesPair){
#                label = "Pages"
#                value[] =
#                   "381-381",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioDate"
#                value[] =
#                   "JUL",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioYear"
#                value[] =
#                   "2006",
#             },
#             (labelValuesPair){
#                label = "SourceTitle"
#                value[] =
#                   "NEPHROLOGY DIALYSIS TRANSPLANTATION",
#             },
#             (labelValuesPair){
#                label = "SupplementNumber"
#                value[] =
#                   "4",
#             },
#             (labelValuesPair){
#                label = "Volume"
#                value[] =
#                   "21",
#             },
#          authors[] =
#             (labelValuesPair){
#                label = "Authors"
#                value[] =
#                   "Colbay, Mehmet",
#                   "Yuksel, Seref",
#                   "Uslan, Ihsan",
#                   "Acarturk, Gursel",
#                   "Karaman, Ozcan",
#                   "Maralcan, Meral",
#             },
#          other[] =
#             (labelValuesPair){
#                label = "Identifier.Ids"
#                value[] =
#                   "075WZ",
#             },
#             (labelValuesPair){
#                label = "Identifier.Issn"
#                value[] =
#                   "0931-0509",
#             },
#             (labelValuesPair){
#                label = "ResearcherID.Disclaimer"
#                value[] =
#                   "ResearcherID data provided by Clarivate Analytics",
#             },
#       },
#       (liteRecord){
#          uid = "WOS:000367540700003"
#          title[] =
#             (labelValuesPair){
#                label = "Title"
#                value[] =
#                   "Is Mean Platelet Volume a Possible Marker in Acute Peritonitis?",
#             },
#          doctype[] =
#             (labelValuesPair){
#                label = "Doctype"
#                value[] =
#                   "Article",
#             },
#          source[] =
#             (labelValuesPair){
#                label = "Issue"
#                value[] =
#                   "1",
#             },
#             (labelValuesPair){
#                label = "Pages"
#                value[] =
#                   "13-17",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioYear"
#                value[] =
#                   "2015",
#             },
#             (labelValuesPair){
#                label = "SourceTitle"
#                value[] =
#                   "EUROPEAN JOURNAL OF GENERAL MEDICINE",
#             },
#             (labelValuesPair){
#                label = "Volume"
#                value[] =
#                   "12",
#             },
#          authors[] =
#             (labelValuesPair){
#                label = "Authors"
#                value[] =
#                   "Ulu, Sena Memnune",
#                   "Asik, Gulsah",
#                   "Acay, Akif",
#                   "Ahsen, Ahmet",
#                   "Yaman, Gokhan",
#                   "Altug, Abdullah",
#                   "Yuksel, Seref",
#             },
#          keywords[] =
#             (labelValuesPair){
#                label = "Keywords"
#                value[] =
#                   "Peritoneal dialysis",
#                   "peritonitis",
#                   "mean platelet volume",
#                   "acute-phase reactant",
#                   "platelet function indices",
#             },
#          other[] =
#             (labelValuesPair){
#                label = "Identifier.Eissn"
#                value[] =
#                   "1304-3897",
#             },
#             (labelValuesPair){
#                label = "Identifier.Ids"
#                value[] =
#                   "DA1FC",
#             },
#             (labelValuesPair){
#                label = "Identifier.Issn"
#                value[] =
#                   "1304-3889",
#             },
#             (labelValuesPair){
#                label = "Identifier.Xref_Doi"
#                value[] =
#                   "10.15197/sabad.1.12.03",
#             },
#             (labelValuesPair){
#                label = "ResearcherID.Disclaimer"
#                value[] =
#                   "ResearcherID data provided by Clarivate Analytics",
#             },
#       },
#       (liteRecord){
#          uid = "WOS:000442009200020"
#          title[] =
#             (labelValuesPair){
#                label = "Title"
#                value[] =
#                   "Is Mean Platelet Volume a Possible Marker in Acute Peritonitis?",
#             },
#          doctype[] =
#             (labelValuesPair){
#                label = "Doctype"
#                value[] =
#                   "Article",
#             },
#          source[] =
#             (labelValuesPair){
#                label = "Issue"
#                value[] =
#                   "1",
#             },
#             (labelValuesPair){
#                label = "Pages"
#                value[] =
#                   "13-17",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioYear"
#                value[] =
#                   "2015",
#             },
#             (labelValuesPair){
#                label = "SourceTitle"
#                value[] =
#                   "ELECTRONIC JOURNAL OF GENERAL MEDICINE",
#             },
#             (labelValuesPair){
#                label = "Volume"
#                value[] =
#                   "12",
#             },
#          authors[] =
#             (labelValuesPair){
#                label = "Authors"
#                value[] =
#                   "Ulu, Sena Memnune",
#                   "Asik, Gulsah",
#                   "Acay, Akif",
#                   "Ahsen, Ahmet",
#                   "Yaman, Gokhan",
#                   "Altug, Abdullah",
#                   "Yuksel, Seref",
#             },
#          keywords[] =
#             (labelValuesPair){
#                label = "Keywords"
#                value[] =
#                   "Peritoneal dialysis",
#                   "peritonitis",
#                   "mean platelet volume",
#                   "acute-phase reactant",
#                   "platelet function indices",
#             },
#          other[] =
#             (labelValuesPair){
#                label = "Identifier.Doi"
#                value[] =
#                   "10.15197/sabad.1.12.03",
#             },
#             (labelValuesPair){
#                label = "Identifier.Ids"
#                value[] =
#                   "VF1GW",
#             },
#             (labelValuesPair){
#                label = "Identifier.Issn"
#                value[] =
#                   "2516-3507",
#             },
#             (labelValuesPair){
#                label = "ResearcherID.Disclaimer"
#                value[] =
#                   "ResearcherID data provided by Clarivate Analytics",
#             },
#       },
#       (liteRecord){
#          uid = "WOS:000440319800190"
#          title[] =
#             (labelValuesPair){
#                label = "Title"
#                value[] =
#                   "Atherogenic Index as A Predictor of Atherosclerosis in Subjects with Familial Mediterranean Fever",
#             },
#          doctype[] =
#             (labelValuesPair){
#                label = "Doctype"
#                value[] =
#                   "Meeting Abstract",
#             },
#          source[] =
#             (labelValuesPair){
#                label = "Issue"
#                value[] =
#                   "4",
#             },
#             (labelValuesPair){
#                label = "Pages"
#                value[] =
#                   "S76-S77",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioYear"
#                value[] =
#                   "2014",
#             },
#             (labelValuesPair){
#                label = "SourceTitle"
#                value[] =
#                   "CLINICAL AND EXPERIMENTAL RHEUMATOLOGY",
#             },
#             (labelValuesPair){
#                label = "SupplementNumber"
#                value[] =
#                   "83",
#             },
#             (labelValuesPair){
#                label = "Volume"
#                value[] =
#                   "32",
#             },
#          authors[] =
#             (labelValuesPair){
#                label = "Authors"
#                value[] =
#                   "Acay, Akif",
#                   "Ulu, Memnune Sena",
#                   "Ahsen, Ahmet",
#                   "Demir, Kasim",
#                   "Ozkececi, Gulay",
#                   "Ozuguz, Ufuk",
#                   "Yuksel, Seref",
#                   "Acarturk, Gursel",
#             },
#          keywords[] =
#             (labelValuesPair){
#                label = "Keywords"
#                value[] =
#                   "Familial Mediterranean fever",
#                   "inflammation",
#                   "atherogenic index",
#                   "atherosclerosis",
#             },
#          other[] =
#             (labelValuesPair){
#                label = "Identifier.Eissn"
#                value[] =
#                   "1593-098X",
#             },
#             (labelValuesPair){
#                label = "Identifier.Ids"
#                value[] =
#                   "VE7VA",
#             },
#             (labelValuesPair){
#                label = "Identifier.Issn"
#                value[] =
#                   "0392-856X",
#             },
#             (labelValuesPair){
#                label = "ResearcherID.Disclaimer"
#                value[] =
#                   "ResearcherID data provided by Clarivate Analytics",
#             },
#       },
#       (liteRecord){
#          uid = "WOS:000440319800043"
#          title[] =
#             (labelValuesPair){
#                label = "Title"
#                value[] =
#                   "Assessment of Thyroid Disorders and Autoimmunity in Patients with Rheumatic Diseases",
#             },
#          doctype[] =
#             (labelValuesPair){
#                label = "Doctype"
#                value[] =
#                   "Meeting Abstract",
#             },
#          source[] =
#             (labelValuesPair){
#                label = "Issue"
#                value[] =
#                   "4",
#             },
#             (labelValuesPair){
#                label = "Pages"
#                value[] =
#                   "S23-S23",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioYear"
#                value[] =
#                   "2014",
#             },
#             (labelValuesPair){
#                label = "SourceTitle"
#                value[] =
#                   "CLINICAL AND EXPERIMENTAL RHEUMATOLOGY",
#             },
#             (labelValuesPair){
#                label = "SupplementNumber"
#                value[] =
#                   "83",
#             },
#             (labelValuesPair){
#                label = "Volume"
#                value[] =
#                   "32",
#             },
#          authors[] =
#             (labelValuesPair){
#                label = "Authors"
#                value[] =
#                   "Acay, Akif",
#                   "Ulu, Memnune Sena",
#                   "Ahsen, Ahmet",
#                   "Eroglu, Selma",
#                   "Ozuguz, Ufuk",
#                   "Yuksel, Seref",
#                   "Acarturk, Gursel",
#             },
#          keywords[] =
#             (labelValuesPair){
#                label = "Keywords"
#                value[] =
#                   "Free triiodothyronine",
#                   "rheumatic diseases",
#                   "thyroid autoimmunity",
#                   "thyroid disorders",
#                   "thyroid function tests",
#                   "thyroid stimulating hormone",
#             },
#          other[] =
#             (labelValuesPair){
#                label = "Identifier.Eissn"
#                value[] =
#                   "1593-098X",
#             },
#             (labelValuesPair){
#                label = "Identifier.Ids"
#                value[] =
#                   "VE7VA",
#             },
#             (labelValuesPair){
#                label = "Identifier.Issn"
#                value[] =
#                   "0392-856X",
#             },
#             (labelValuesPair){
#                label = "ResearcherID.Disclaimer"
#                value[] =
#                   "ResearcherID data provided by Clarivate Analytics",
#             },
#       },
#       (liteRecord){
#          uid = "WOS:000382668000012"
#          title[] =
#             (labelValuesPair){
#                label = "Title"
#                value[] =
#                   "Interleukin-18 Binding Protein Pretreatment Attenuates Kidney Injury Induced by Hepatic Ischemia Reperfusion",
#             },
#          doctype[] =
#             (labelValuesPair){
#                label = "Doctype"
#                value[] =
#                   "Article",
#             },
#          source[] =
#             (labelValuesPair){
#                label = "Issue"
#                value[] =
#                   "2",
#             },
#             (labelValuesPair){
#                label = "Pages"
#                value[] =
#                   "200-207",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioDate"
#                value[] =
#                   "AUG",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioYear"
#                value[] =
#                   "2016",
#             },
#             (labelValuesPair){
#                label = "SourceTitle"
#                value[] =
#                   "AMERICAN JOURNAL OF THE MEDICAL SCIENCES",
#             },
#             (labelValuesPair){
#                label = "Volume"
#                value[] =
#                   "352",
#             },
#          authors[] =
#             (labelValuesPair){
#                label = "Authors"
#                value[] =
#                   "Gonul, Yucel",
#                   "Kazandi, Senem",
#                   "Kocak, Ahmet",
#                   "Ahsen, Ahmet",
#                   "Bal, Ahmet",
#                   "Karavelioglu, Afra",
#                   "Hazman, Omer",
#                   "Turamanlar, Ozan",
#                   "Kokulu, Serdar",
#                   "Yuksel, Seref",
#             },
#          keywords[] =
#             (labelValuesPair){
#                label = "Keywords"
#                value[] =
#                   "Interleukin-18 binding protein",
#                   "Liver ischemia-reperfusion",
#                   "Acute kidney injury",
#                   "Inflammation",
#                   "Oxidative stress",
#             },
#          other[] =
#             (labelValuesPair){
#                label = "Identifier.Eissn"
#                value[] =
#                   "1538-2990",
#             },
#             (labelValuesPair){
#                label = "Identifier.Ids"
#                value[] =
#                   "DV1GG",
#             },
#             (labelValuesPair){
#                label = "Identifier.Issn"
#                value[] =
#                   "0002-9629",
#             },
#             (labelValuesPair){
#                label = "Identifier.Xref_Doi"
#                value[] =
#                   "10.1016/j.amjms.2016.04.012",
#             },
#             (labelValuesPair){
#                label = "ResearcherID.Disclaimer"
#                value[] =
#                   "ResearcherID data provided by Clarivate Analytics",
#             },
#       },
#       (liteRecord){
#          uid = "WOS:000365355900002"
#          title[] =
#             (labelValuesPair){
#                label = "Title"
#                value[] =
#                   "L-Carnitine Supplementation Reduces Short-Term Neutrophil-Lymphocyte Ratio in Patients Undergoing Coronary Artery Bypass Grafting",
#             },
#          doctype[] =
#             (labelValuesPair){
#                label = "Doctype"
#                value[] =
#                   "Article",
#             },
#          source[] =
#             (labelValuesPair){
#                label = "Issue"
#                value[] =
#                   "7-8",
#             },
#             (labelValuesPair){
#                label = "Pages"
#                value[] =
#                   "1160-1168",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioDate"
#                value[] =
#                   "JUL",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioYear"
#                value[] =
#                   "2015",
#             },
#             (labelValuesPair){
#                label = "SourceTitle"
#                value[] =
#                   "INTERNATIONAL SURGERY",
#             },
#             (labelValuesPair){
#                label = "Volume"
#                value[] =
#                   "100",
#             },
#          authors[] =
#             (labelValuesPair){
#                label = "Authors"
#                value[] =
#                   "Aldemir, Mustafa",
#                   "Pektas, Mehmet Bilgehan",
#                   "Parlar, Ali Ihsan",
#                   "Akci, Onder",
#                   "Emren, Sadik Volkan",
#                   "Tecer, Evren",
#                   "Adali, Fahri",
#                   "Yuksel, Seref",
#                   "Darcin, Osman Tansel",
#             },
#          keywords[] =
#             (labelValuesPair){
#                label = "Keywords"
#                value[] =
#                   "L-carnitine",
#                   "Neutrophil-to-lymphocyte ratio",
#                   "Coronary artery bypass grafting",
#             },
#          other[] =
#             (labelValuesPair){
#                label = "Contributor.ResearcherID.Names"
#                value[] =
#                   "PEKTAS, MEHMET BILGEHAN",
#             },
#             (labelValuesPair){
#                label = "Contributor.ResearcherID.ResearcherIDs"
#                value[] =
#                   "V-7886-2017",
# ...
#             },
#             (labelValuesPair){
#                label = "Volume"
#                value[] =
#                   "33",
#             },
#          authors[] =
#             (labelValuesPair){
#                label = "Authors"
#                value[] =
#                   "Yuksel, Seref",
#                   "Sezer, Mehmet Tugrul",
#                   "Sahin, Onder",
#                   "Sutcu, Recep",
#                   "Kocogullari, Cevdet",
#                   "Yilmaz, Haci Ramazan",
#                   "Uz, Efkan",
#                   "Kara, Yusuf",
#                   "Aydin, Bunyamin",
#                   "Altuntas, Atilla",
#             },
#          keywords[] =
#             (labelValuesPair){
#                label = "Keywords"
#                value[] =
#                   "Carnitine",
#                   "kidney",
#                   "ischemia-reperfusion",
#                   "aortic cross-clamp",
#                   "free oxygen radical",
#             },
#          other[] =
#             (labelValuesPair){
#                label = "Contributor.ResearcherID.Names"
#                value[] =
#                   "UZ, Efkan",
#             },
#             (labelValuesPair){
#                label = "Contributor.ResearcherID.ResearcherIDs"
#                value[] =
#                   "B-2943-2016",
#             },
#             (labelValuesPair){
#                label = "Identifier.Doi"
#                value[] =
#                   "10.3109/0886022X.2011.568148",
#             },
#             (labelValuesPair){
#                label = "Identifier.Ids"
#                value[] =
#                   "756RU",
#             },
#             (labelValuesPair){
#                label = "Identifier.Issn"
#                value[] =
#                   "0886-022X",
#             },
#             (labelValuesPair){
#                label = "ResearcherID.Disclaimer"
#                value[] =
#                   "ResearcherID data provided by Clarivate Analytics",
#             },
#       },
#       (liteRecord){
#          uid = "WOS:000289476200004"
#          title[] =
#             (labelValuesPair){
#                label = "Title"
#                value[] =
#                   "Cardiac autonomic dysfunction in hemodialysis patients: The value of heart rate turbulence",
#             },
#          doctype[] =
#             (labelValuesPair){
#                label = "Doctype"
#                value[] =
#                   "Article",
#             },
#          source[] =
#             (labelValuesPair){
#                label = "Issue"
#                value[] =
#                   "2",
#             },
#             (labelValuesPair){
#                label = "Pages"
#                value[] =
#                   "193-199",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioDate"
#                value[] =
#                   "APR",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioYear"
#                value[] =
#                   "2011",
#             },
#             (labelValuesPair){
#                label = "SourceTitle"
#                value[] =
#                   "HEMODIALYSIS INTERNATIONAL",
#             },
#             (labelValuesPair){
#                label = "Volume"
#                value[] =
#                   "15",
#             },
#          authors[] =
#             (labelValuesPair){
#                label = "Authors"
#                value[] =
#                   "Celik, Atac",
#                   "Melek, Mehmet",
#                   "Yuksel, Seref",
#                   "Onrat, Ersel",
#                   "Avsar, Alaettin",
#             },
#          keywords[] =
#             (labelValuesPair){
#                label = "Keywords"
#                value[] =
#                   "End-stage renal disease",
#                   "cardiac autonomic dysfunction",
#                   "heart rate variability",
#                   "heart rate turbulence",
#                   "hemodialysis",
#             },
#          other[] =
#             (labelValuesPair){
#                label = "Identifier.Doi"
#                value[] =
#                   "10.1111/j.1542-4758.2011.00529.x",
#             },
#             (labelValuesPair){
#                label = "Identifier.Eissn"
#                value[] =
#                   "1542-4758",
#             },
#             (labelValuesPair){
#                label = "Identifier.Ids"
#                value[] =
#                   "749NW",
#             },
#             (labelValuesPair){
#                label = "Identifier.Issn"
#                value[] =
#                   "1492-7535",
#             },
#             (labelValuesPair){
#                label = "ResearcherID.Disclaimer"
#                value[] =
#                   "ResearcherID data provided by Clarivate Analytics",
#             },
#       },
#       (liteRecord){
#          uid = "WOS:000273842400010"
#          title[] =
#             (labelValuesPair){
#                label = "Title"
#                value[] =
#                   "Novel approach for the prevention of contrast nephropathy",
#             },
#          doctype[] =
#             (labelValuesPair){
#                label = "Doctype"
#                value[] =
#                   "Article",
#             },
#          source[] =
#             (labelValuesPair){
#                label = "Issue"
#                value[] =
#                   "1",
#             },
#             (labelValuesPair){
#                label = "Pages"
#                value[] =
#                   "81-89",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioDate"
#                value[] =
#                   "JAN",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioYear"
#                value[] =
#                   "2010",
#             },
#             (labelValuesPair){
#                label = "SourceTitle"
#                value[] =
#                   "EXPERIMENTAL AND TOXICOLOGIC PATHOLOGY",
#             },
#             (labelValuesPair){
#                label = "Volume"
#                value[] =
#                   "62",
#             },
#          authors[] =
#             (labelValuesPair){
#                label = "Authors"
#                value[] =
#                   "Colbay, Mehmet",
#                   "Yuksel, Seref",
#                   "Uslan, Ihsan",
#                   "Acarturk, Gursel",
#                   "Karaman, Ozcan",
#                   "Bas, Orhan",
#                   "Mollaoglu, Hakan",
#                   "Yagmurca, Murat",
#                   "Ozen, Oguz Aslan",
#             },
#          keywords[] =
#             (labelValuesPair){
#                label = "Keywords"
#                value[] =
#                   "Caffeic acid phenethyl ester",
#                   "N-acetylcystein",
#                   "Contrast medium",
#                   "Nephropathy",
#                   "Oxidant-antioxidant status",
#             },
#          other[] =
#             (labelValuesPair){
#                label = "Contributor.ResearcherID.Names"
#                value[] =
#                   "Mollaoglu, Hakan",
#                   "yagmurca, murat",
#             },
#             (labelValuesPair){
#                label = "Contributor.ResearcherID.ResearcherIDs"
#                value[] =
#                   "C-6987-2013",
#             },
#             (labelValuesPair){
#                label = "Identifier.Doi"
#                value[] =
#                   "10.1016/j.etp.2009.02.119",
#             },
#             (labelValuesPair){
#                label = "Identifier.Ids"
#                value[] =
#                   "546VR",
#             },
#             (labelValuesPair){
#                label = "Identifier.Issn"
#                value[] =
#                   "0940-2993",
#             },
#             (labelValuesPair){
#                label = "ResearcherID.Disclaimer"
#                value[] =
#                   "ResearcherID data provided by Clarivate Analytics",
#             },
#       },
#       (liteRecord){
#          uid = "WOS:000273829300005"
#          title[] =
#             (labelValuesPair){
#                label = "Title"
#                value[] =
#                   "The relationship of amelogenesis imperfecta and nephrocalcinosis syndrome",
#             },
#          doctype[] =
#             (labelValuesPair){
#                label = "Doctype"
#                value[] =
#                   "Article",
#             },
#          source[] =
#             (labelValuesPair){
#                label = "Issue"
#                value[] =
#                   "11",
#             },
#             (labelValuesPair){
#                label = "Pages"
#                value[] =
#                   "E579-E582",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioDate"
#                value[] =
#                   "NOV",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioYear"
#                value[] =
#                   "2009",
#             },
#             (labelValuesPair){
#                label = "SourceTitle"
#                value[] =
#                   "MEDICINA ORAL PATOLOGIA ORAL Y CIRUGIA BUCAL",
#             },
#             (labelValuesPair){
#                label = "Volume"
#                value[] =
#                   "14",
#             },
#          authors[] =
#             (labelValuesPair){
#                label = "Authors"
#                value[] =
#                   "Kirzioglu, Zuhal",
#                   "Ulu, K. Gorkem",
#                   "Sezer, M. Tugrul",
#                   "Yuksel, Seref",
#             },
#          keywords[] =
#             (labelValuesPair){
#                label = "Keywords"
#                value[] =
#                   "Amelogenesis imperfecta",
#                   "nephrocalcinosis",
#             },
#          other[] =
#             (labelValuesPair){
#                label = "Identifier.Doi"
#                value[] =
#                   "10.4317/medoral.14.e579",
#             },
#             (labelValuesPair){
#                label = "Identifier.Ids"
#                value[] =
#                   "546RU",
#             },
#             (labelValuesPair){
#                label = "Identifier.Issn"
#                value[] =
#                   "1698-4447",
#             },
#             (labelValuesPair){
#                label = "Identifier.article_no"
#                value[] =
#                   "ARTN 2555",
#             },
#             (labelValuesPair){
#                label = "ResearcherID.Disclaimer"
#                value[] =
#                   "ResearcherID data provided by Clarivate Analytics",
#             },
#       },
#       (liteRecord){
#          uid = "WOS:000266016400007"
#          title[] =
#             (labelValuesPair){
#                label = "Title"
#                value[] =
#                   "Restless Legs Syndrome and Associated Factors in Dialysis Patients",
#             },
#          doctype[] =
#             (labelValuesPair){
#                label = "Doctype"
#                value[] =
#                   "Article",
#             },
#          source[] =
#             (labelValuesPair){
#                label = "Issue"
#                value[] =
#                   "2",
#             },
#             (labelValuesPair){
#                label = "Pages"
#                value[] =
#                   "344-352",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioDate"
#                value[] =
#                   "APR",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioYear"
#                value[] =
#                   "2009",
#             },
#             (labelValuesPair){
#                label = "SourceTitle"
#                value[] =
#                   "TURKIYE KLINIKLERI TIP BILIMLERI DERGISI",
#             },
#             (labelValuesPair){
#                label = "Volume"
#                value[] =
#                   "29",
#             },
#          authors[] =
#             (labelValuesPair){
#                label = "Authors"
#                value[] =
#                   "Yuksel, Seref",
#                   "Yilmaz, Mustafa",
#                   "Demir, Murat",
#                   "Erturk, Jale",
#                   "Acarturk, Guersel",
#                   "Koyuncuoglu, Hasan Rifat",
#                   "Sezer, Mehmet Tugrul",
#             },
#          keywords[] =
#             (labelValuesPair){
#                label = "Keywords"
#                value[] =
#                   "Restless legs syndrome",
#                   "dialysis",
#                   "hypertension",
#                   "ferritins",
#                   "body mass index",
#             },
#          other[] =
#             (labelValuesPair){
#                label = "Identifier.Eissn"
#                value[] =
#                   "2146-9040",
#             },
#             (labelValuesPair){
#                label = "Identifier.Ids"
#                value[] =
#                   "444YI",
#             },
#             (labelValuesPair){
#                label = "Identifier.Issn"
#                value[] =
#                   "1300-0292",
#             },
#             (labelValuesPair){
#                label = "ResearcherID.Disclaimer"
#                value[] =
#                   "ResearcherID data provided by Clarivate Analytics",
#             },
#       },
#       (liteRecord){
#          uid = "WOS:000265197700010"
#          title[] =
#             (labelValuesPair){
#                label = "Title"
#                value[] =
#                   "Increased Serum Osteoprotegerin Levels Associated with Decreased Bone Mineral Density in Familial Mediterranean Fever",
#             },
#          doctype[] =
#             (labelValuesPair){
#                label = "Doctype"
#                value[] =
#                   "Article",
#             },
#          source[] =
#             (labelValuesPair){
#                label = "Issue"
#                value[] =
#                   "4",
#             },
#             (labelValuesPair){
#                label = "Pages"
#                value[] =
#                   "321-327",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioDate"
#                value[] =
#                   "APR",
#             },
#             (labelValuesPair){
#                label = "Published.BiblioYear"
#                value[] =
#                   "2009",
#             },
#             (labelValuesPair){
#                label = "SourceTitle"
#                value[] =
#                   "TOHOKU JOURNAL OF EXPERIMENTAL MEDICINE",
#             },
#             (labelValuesPair){
#                label = "Volume"
#                value[] =
#                   "217",
#             },
#          authors[] =
#             (labelValuesPair){
#                label = "Authors"
#                value[] =
#                   "Yuksel, Seref",
#                   "Samli, Hale",
#                   "Colbay, Mehmet",
#                   "Dundar, Umit",
#                   "Acarturk, Gursel",
#                   "Demir, Serap",
#                   "Koken, Tulay",
#                   "Aktepe, Orhan Cem",
#                   "Kavuncu, Vural",
#                   "Solak, Mustafa",
#             },
#          keywords[] =
#             (labelValuesPair){
#                label = "Keywords"
#                value[] =
#                   "Familial Mediterranean fever",
#                   "bone density",
#                   "osteoprotegerin",
#                   "leptin",
#                   "Dual X-ray absorptiometry",
#             },
#          other[] =
#             (labelValuesPair){
#                label = "Identifier.Eissn"
#                value[] =
#                   "1349-3329",
#             },
#             (labelValuesPair){
#                label = "Identifier.Ids"
#                value[] =
#                   "433IO",
#             },
#             (labelValuesPair){
#                label = "Identifier.Issn"
#                value[] =
#                   "0040-8727",
#             },
#             (labelValuesPair){
#                label = "Identifier.Xref_Doi"
#                value[] =
#                   "10.1620/tjem.217.321",
#             },
#             (labelValuesPair){
#                label = "ResearcherID.Disclaimer"
#                value[] =
#                   "ResearcherID data provided by Clarivate Analytics",
#             },
#       },
#  }

# %%
# number of publishment
results.recordsFound
# Out:
# 39

# %%
idx_max = results.recordsFound
dict_list = []
for i in range(idx_max):
    # uid
    uid_tmp = results.records[i].uid

    # title of the paper
    title_tmp = results.records[i].title[0].value[0]

    # publishment type
    type_tmp = results.records[i].doctype[0].value[0]

    # name of journal
    journal_tmp = next((item for item in results.records[i].source if item["label"] == "SourceTitle")).value[0]

    # Publish year
    year_tmp = next((item for item in results.records[i].source if item["label"] == "Published.BiblioYear")).value[0]

    # Publish date
    if 'date' in results.records[i].source:
        date_tmp = next((item for item in results.records[i].source if item["label"] == "Published.BiblioDate")).value[0]
    else:
        date_tmp = []

    # co-authors
    coauthor_tmp = results.records[i].authors[0].value

    # keywords
    if 'keywords' in results.records[i]:
        keyword_tmp = results.records[i].keywords[0].value
    else:
        keyword_tmp = []
    
    dict_tmp = {'uid':uid_tmp,'title':title_tmp,'type':type_tmp,'journal':journal_tmp,
                'year':year_tmp,'date':date_tmp,'coauthor':coauthor_tmp,'keyword':keyword_tmp}
    dict_list.append(dict_tmp)

# %%
results.records[0].uid
# Out:
# WOS:000254477800003

# %%
# title of the paper
results.records[0].title[0].value[0]
#next((item for item in results.records[0].title if item['label']=='Title')).value
# Out:
# Assessment of genotoxicity in rats treated with the antidiabetic agent, pioglitazone

# %%
# publishment type
results.records[0].doctype[0].value[0]
#next((item for item in results.records[0].doctype if item['label']=='Doctype')).value
# Out:
# Article

# %%
# name of journal
next((item for item in results.records[0].source if item["label"] == "SourceTitle")).value[0]
# Out:
# ENVIRONMENTAL AND MOLECULAR MUTAGENESIS

# %%
# Publish year
next((item for item in results.records[0].source if item["label"] == "Published.BiblioYear")).value[0]
# Out:
# 2008

# %%
# Publish date
next((item for item in results.records[0].source if item["label"] == "Published.BiblioDate")).value[0]
# Out:
# APR

# %%
# co-authors
results.records[0].authors[0].value
# results[3][0][4][0][1]
# Out:
# [Bedir, Abdulkerim,
#  Aliyazicioglu, Yuksel,
#  Bilgici, Birsen,
#  Yurclakul, Zafer,
#  Uysal, Mehmet,
#  Suvaci, Duygu Erol,
#  Okuyucu, Ali,
#  Kahraman, Hakki,
#  Hokelek, Murat,
#  Alvur, Muhlise]

# %%
results.records[0].keywords[0].value
# Out:
# [genotoxicity, pioglitazone, comet assay, single cell gel electrophoresis]

# %% [markdown]
# **Search and save part**

# %%
import pandas as pd
import time
import pickle

# %%
namelist = pd.read_csv('Publishments.csv').drop(columns='Unnamed: 0')

# %%
namelist
# Out:
#                     SearchNames                  Author  NoPapers
# 0                AU=AYDIN AYDIN             AYDIN AYDIN         4
# 1               AU=GILGIL ERDAL            GILGIL ERDAL         5
# 2                AU=HALAC METIN             HALAC METIN        63
# 3            AU=YUCE ABDULHAKIM         YUCE ABDULHAKIM         0
# 4           AU=KIRIS ABDULKADIR        KIRIS ABDULKADIR        54
# 5     AU=KUCUKBAYRAK ABDULKADIR  KUCUKBAYRAK ABDULKADIR        30
# 6        AU=YILDIRIM ABDULKADIR     YILDIRIM ABDULKADIR        33
# 7           AU=CEKIN ABDULKADIR        CEKIN ABDULKADIR         0
# 8          AU=SENGUN ABDULKADIR       SENGUN ABDULKADIR        13
# 9           AU=BEDIR ABDULKERIM        BEDIR ABDULKERIM        38
# 10          AU=AKPINAR ABDULLAH        AKPINAR ABDULLAH        38
# 11              AU=BAL ABDULLAH            BAL ABDULLAH        26
# 12           AU=SENGUL ABDULLAH         SENGUL ABDULLAH         3
# 13            AU=DEMIR ABDULLAH          DEMIR ABDULLAH        54
# 14            AU=DOGAN ABDULLAH          DOGAN ABDULLAH       112
# 15           AU=EKIZER ABDULLAH         EKIZER ABDULLAH        13
# 16            AU=ERDIL ABDULLAH          ERDIL ABDULLAH         5
# 17            AU=ERGIN ABDULLAH          ERGIN ABDULLAH         3
# 18           AU=SECKIN ABDULLAH         SECKIN ABDULLAH         1
# 19            AU=KIRAN ABDULLAH          KIRAN ABDULLAH         0
# 20            AU=USTUN ABDULLAH          USTUN ABDULLAH         5
# 21            AU=CINGU ABDULLAH          CINGU ABDULLAH        46
# 22            AU=AKSOY ABDULLAH          AKSOY ABDULLAH         1
# 23           AU=TUNCER ABDULLAH         TUNCER ABDULLAH         0
# 24            AU=MUTLU ABDULLAH          MUTLU ABDULLAH         0
# 25           AU=KILDAN ABDULLAH         KILDAN ABDULLAH         2
# 26              AU=POS ABDULLAH            POS ABDULLAH         0
# 27           AU=SONMEZ ABDULLAH         SONMEZ ABDULLAH        22
# 28             AU=URAL ABDULLAH           URAL ABDULLAH         1
# 29           AU=YORDEM ABDULLAH         YORDEM ABDULLAH         0
# ...                         ...                     ...       ...
# 3545              AU=KURT SEREF              KURT SEREF        21
# 3546           AU=OKUDUCU SEREF           OKUDUCU SEREF         6
# 3547             AU=OLGAR SEREF             OLGAR SEREF        20
# 3548            AU=POYRAZ SEREF            POYRAZ SEREF         0
# 3549            AU=YUKSEL SEREF            YUKSEL SEREF        39
# 3550            AU=SIMSEK SEREF            SIMSEK SEREF        20
# 3551              AU=TUNA SERIF              TUNA SERIF         0
# 3552          AU=KAHRAMAN SERIF          KAHRAMAN SERIF         9
# 3553           AU=AKALIN SERIFE           AKALIN SERIFE        18
# 3554         AU=ALTINDAG SERIFE         ALTINDAG SERIFE         0
# 3555            AU=OZLEN SERIFE            OZLEN SERIFE         0
# 3556           AU=ARIKAN SEVKET           ARIKAN SEVKET        24
# 3557              AU=ATA SEVKET              ATA SEVKET        10
# 3558          AU=CIVELEK SEVKET          CIVELEK SEVKET         2
# 3559        AU=TUYLUOGLU SEVKET        TUYLUOGLU SEVKET         0
# 3560             AU=TARIM SEYDA             TARIM SEYDA         3
# 3561             AU=ARI SEYHMUS             ARI SEYHMUS        42
# 3562             AU=YAVUZ SEYMA             YAVUZ SEYMA         0
# 3563            AU=CIVITCI SULE            CIVITCI SULE         4
# 3564             AU=ATALAY SULE             ATALAY SULE         5
# 3565            AU=ULGER SUKRAN            ULGER SUKRAN        20
# 3566            AU=ARSLAN SUKRU            ARSLAN SUKRU        42
# 3567            AU=DUZGUN SUKRU            DUZGUN SUKRU        10
# 3568             AU=BOYLU SUKRU             BOYLU SUKRU         5
# 3569          AU=KARAKAYA SUKRU          KARAKAYA SUKRU         9
# 3570             AU=KILIC SUKRU             KILIC SUKRU         0
# 3571            AU=TAKTAK SUKRU            TAKTAK SUKRU        18
# 3572        AU=CAKMAKTEPE SUKRU        CAKMAKTEPE SUKRU         3
# 3573           AU=HISAR SUKRIYE           HISAR SUKRIYE         8
# 3574         AU=KARADAS SUKRIYE         KARADAS SUKRIYE         0
#
# [3575 rows x 3 columns]

# %%
namelist.count()
# Out:
# SearchNames    3575
# Author         3575
# NoPapers       3575
# dtype: int64

# %% [markdown]
# 3461 out of 3575 have paper less equal to 100. And 2708 people have paper between 1 to 100.
# And 2663 unique names.

# %%
one_hundred = namelist.loc[(namelist.NoPapers<=100) & (namelist.NoPapers>0)].copy()

# %%
one_hundred.drop_duplicates(subset='Author',inplace=True)

# %%
one_hundred = one_hundred.reset_index().drop(columns='index')

# %%
cnt = 0
author_dict = {}
subfolder = './scrab_data'

# %%
for author in one_hundred.Author:
    author = one_hundred.iloc[j].Author
    print(author)
    results = soap.search("AU='%s'"%author)
    with open('%s/%s.txt'%(subfolder,author), 'w') as f:
        for item in results:
            item = str(item)
            f.write("%s\n" % item)
    
    idx_max = results.recordsFound
    dict_list = []
    for i in range(idx_max):
        # uid
        uid_tmp = results.records[i].uid

        # title of the paper
        title_tmp = results.records[i].title[0].value[0]

        # publishment type
        type_tmp = results.records[i].doctype[0].value[0]

        # name of journal
        journal_tmp = next((item for item in results.records[i].source if item["label"] == "SourceTitle")).value[0]

        # Publish year
        year_tmp = next((item for item in results.records[i].source if item["label"] == "Published.BiblioYear")).value[0]

        # Publish date
        if 'date' in results.records[i].source:
            date_tmp = next((item for item in results.records[i].source if item["label"] == "Published.BiblioDate")).value[0]
        else:
            date_tmp = []

        # co-authors
        coauthor_tmp = results.records[i].authors[0].value

        # keywords
        if 'keywords' in results.records[i]:
            keyword_tmp = results.records[i].keywords[0].value
        else:
            keyword_tmp = []

        dict_tmp = {'uid':uid_tmp,'title':title_tmp,'type':type_tmp,'journal':journal_tmp,
                    'year':year_tmp,'date':date_tmp,'coauthor':coauthor_tmp,'keyword':keyword_tmp}
        dict_list.append(dict_tmp)
    author_dict[author]=dict_list
    
    cnt = cnt+1
    
    if cnt % 2400==0: # WOS constraints that each ID can only search for 2500 times. Just set smaller counts to renew the ID.
        soap = WosClient(lite=True)
        soap.connect()
    
    if cnt%100 == 0:
        print('=================================')
        print('=================================')
        print(cnt/len(one_hundred.Author)*100,'%')
        print('=================================')
        print('=================================')
        
    time.sleep(0.5)
# Out:
# BALTA SERKAN
# BOYAR SERKAN
# ELCIN SERKAN
# ERDAL SERKAN
# KARATAS SERKAN
# KIRBAS SERKAN
# KURTGOZ SERKAN
# PERKMEN SERKAN
# CAKIR SERKAN
# OZTURK SERKAN
# SAHIN SERKAN
# SENOL SERKAN
# YAGCI SERVER
# DEMIR SERVET
# KACAR SEVAL
# SEZER SEVGI
# YUCA SEVIL
# GOKSUGUR SEVIL
# KAMALI SEVIL
# BERTLEK SEYDI
# OKUMUS SEYDI
# EMIR SEYFI
# KOSE SEYIT
# APILIOGULLARI SEZA
# KALAFAT SEZAI
# TEMELLI SEZAI
# SASMAZ SEZAI
# OCAK SEZEN
# KISA SEZER
# OZSOY SECKIN
# ARSLAN SIDDIK
# MALKOC SIDDIK
# BAYTAK SITKI
# DUMAN SITKI
# ERMIS SITKI
# CORBACIOGLU SITKI
# AKKOC SONER
# ASKIN SUAT
# KESKIN SUAT
# ZEYREK SUAT
# BISKIN SULTAN
# KABA SULTAN
# KURT SULTAN
# BASAK SUNA
# SACAR SUZAN
# YAZICI SUZAN
# KARAKUS SUZAN
# AYHAN SUZI
# ARSLAN SONMEZ
# PAMUK SONMEZ
# DIKICI SUBER
# CARSANCAKLI SULEYMAN
# ALTINTAS SULEYMAN
# AYVAZ SULEYMAN
# BASLAR SULEYMAN
# CENGIZ SULEYMAN
# CENKCI SULEYMAN
# DEMIR SULEYMAN
# DEMIRCI SULEYMAN
# ERCAN SULEYMAN
# GOREN SULEYMAN
# SEVILGEN SULEYMAN
# SAHIN SULEYMAN
# KAHRAMAN SULEYMAN
# KARACELIL SULEYMAN
# KARSLI SULEYMAN
# KAVAK SULEYMAN
# KIZIL SULEYMAN
# SARIBAS SULEYMAN
# SEMIZ SULEYMAN
# SEYDI SULEYMAN
# TURK SULEYMAN
# YAZAR SULEYMAN
# YUKSEL SULEYMAN
# CAKICI SULEYMAN
# CELIK SULEYMAN
# OZEREN SULEYMAN
# ULGER SULEYMAN
# SIMSEK SULEYMAN
# KOCTURK SUMEYRA
# AYIK SIBEL
# =================================
# =================================
# 78.85843034171987 %
# =================================
# =================================
# DOGRU SIBEL
# DIKMEN SIBEL
# PERCINEL SIBEL
# AYDIN SINAN
# KOCAMAN SINAN
# TAN SINAN
# TOZOGLU SINAN
# TUNCEL SINAN
# ULU SINAN
# YASAR SINAN
# YORUK SINAN
# OZGELEN SINAN
# KOSEOGLU SINEM
# AZERI SIYAVES
# YILDIRIM TACETTIN
# ORNEK TACETTIN
# KARAMAN TAHA
# BOYRAZ TAHSIN
# SOGUT TAHSIN
# YAKUT TAHSIN
# YILDIRIM TAHSIN
# AYATA TAHIR
# SEVINC TAHIR
# KAHYAOGLU TALIP
# CEVIK TALIP
# ALISKAN TAMER
# BASKAL TAMER
# UCAR TAMER
# COSKUN TAMER
# UYSAL TANCAN
# ARSLAN TANER
# TOPAL TANER
# OZBENLI TANER
# ULUCAY TARIK
# KORUCU TAYFUN
# OZDES TASKIN
# INAN TASKIN
# BAGLAM TEKIN
# TAS TEKIN
# BAYRAK TEMEL
# AYSU TEVFIK
# DEMIRCI TEVFIK
# GUNES TEVFIK
# PINAR TEVFIK
# YAVUZ TEVFIK
# ZIYPAK TEVFIK
# DURNA TEZCAN
# PARALI TEZCAN
# ATAY TOLGA
# KABACA TOLGA
# TOREN TOLGA
# ARI TUBA
# KARABOGA TUBA
# KIYAN TUBA
# AYTAC TUFAN
# BAL TUFAN
# KUZPINARI TUFAN
# ATALAY TUGAY
# KAMAS TUNCAY
# KANER TUNCAY
# DEMIR TUNCER
# GEYIKLI TURABI
# AKTAS TURAN
# BATAR TURAN
# KARACA TURAN
# YAZICILAR TURAN
# TEMUR TURAN
# USLU TURAN
# CALBAN TURAN
# ISIK TURGAY
# POLAT TURGAY
# TAY TURGAY
# TEKINAY TURGAY
# YAZAR TURGAY
# KOCATURK TURGUT
# YELOGLU TURGUT
# SARISAHIN TUGBA
# YANIK TUGRUL
# BORAN TUGCE
# OZLU TULAY
# GUVEN TUMER
# SERT TIJEN
# AYHAN TIMUR
# KESKINTURK TIMUR
# TEZEL TIMUR
# AYDOGAN TIMUCIN
# DOGUC UFUK
# DURNA UFUK
# TAS UFUK
# OZUGUZ UFUK
# ARIOZ UMUT
# GULACTI UMUT
# GOLGE UMUT
# ERDOGAN UTKU
# SAYIN UTKU
# KERMAN UYSAL
# ACAR UGUR
# CAMCI UGUR
# FIRAT UGUR
# GOKTAS UGUR
# =================================
# =================================
# 82.61359369132558 %
# =================================
# =================================
# KADAK UGUR
# KARA UGUR
# KOLTUKSUZ UGUR
# YILDIRIM UGUR
# CAKIR UGUR
# COMLEKCIOGLU UGUR
# OZCAN UGUR
# OGUSGIL VAHAP
# SARICICEK VAHAP
# KAPLANOGLU VAHIT
# ARI VEDAT
# BAL VEDAT
# DAL VEDAT
# DEMIR VEDAT
# KARSLI VEDAT
# SIAP VEDAT
# GORGEN VELI
# BERK VELI
# DENIZ VELI
# GOK VELI
# TURKMENOGLU VELI
# UGURCU VELI
# YILDIRIM VELI
# CAGLAR VELI
# CITISLI VELI
# OZTURK VELI
# AYHAN VEYSEL
# AGCA VEYSEL
# DEMIR VEYSEL
# KUSCU VEYSEL
# OKUMUS VEYSI
# ONER VEYSI
# OZTURK VEYSI
# SOLMAZ VOLKAN
# SENYUREK VOLKAN
# BOSNAK VUSLAT
# MOTOR VICDAN
# ZORBA YAHYA
# CELIK YAHYA
# ISLAMOGLU YAHYA
# EGERCIOGLU YAKUP
# KESKIN YAKUP
# SEKMEN YAKUP
# TURKEL YAKUP
# UMUCU YAKUP
# YILDIRIM YAKUP
# BAS YALCIN
# GOLCUK YALCIN
# YESIL YALCIN
# COPUR YALCIN
# ALPER YASEMIN
# BULUT YASEMIN
# ISIK YASEMIN
# BALCI YASEMIN
# KARACA YASEMIN
# TEKIN YASEMIN
# SOYORAL YASEMIN
# ABUL YASIN
# ATAC YASIN
# AVCI YASIN
# BEZ YASIN
# BULUT YASIN
# KARADAG YASIN
# SARI YASIN
# SARIKAYA YASIN
# KARAKUS YASIN
# GULEN YASIR
# AKBAS YAVUZ
# GUNES YAVUZ
# KAPLAN YAVUZ
# SALIHOGLU YAVUZ
# SELIM YAVUZ
# TAMA YAVUZ
# SOYDAN YAVUZ
# UYAR YAVUZ
# UGURLU YAVUZ
# ADIGUZELLI YASAR
# BOYACI YASAR
# DURMAZ YASAR
# ERTURK YASAR
# KARAASLAN YASAR
# KOSAR YASAR
# SEKER YASAR
# SEN YASAR
# AYDIN YENER
# KALKAN YILDIRAY
# KESKIN YILDIRAY
# SISMAN YILDIRAY
# AKSOY YILMAZ
# ARI YILMAZ
# KAYA YILMAZ
# KILIC YILMAZ
# KIROGLU YILMAZ
# PALANCI YILMAZ
# POLAT YILMAZ
# SAGLAM YILMAZ
# TURGUT YILMAZ
# ZENGIN YILMAZ
# OZMEN YILMAZ
# DOGAN YUNUS
# =================================
# =================================
# 86.36875704093127 %
# =================================
# =================================
# YANDI YUNUS
# KARAKUYU YUNUS
# YILMAZ YUNUS
# UGAN YUNUS
# YILDIRIM YUNUS
# CENGELOGLU YUNUS
# OZKANLAR YUNUSEMRE
# ARIKAN YUSUF
# ATALAY YUSUF
# AY YUSUF
# AYDIN YUSUF
# DEMIR YUSUF
# GUNER YUSUF
# GUNES YUSUF
# KESKIN YUSUF
# KILINC YUSUF
# KOC YUSUF
# KOCAK YUSUF
# OYSAL YUSUF
# SEZEN YUSUF
# SOFUOGLU YUSUF
# TAVIL YUSUF
# TOPAL YUSUF
# TURAN YUSUF
# AYDOGDU YUSUF
# YESIL YUSUF
# YUCEL YUSUF
# AKPINAR YUSUF
# IGCI YUSUF
# OZKAN YUSUF
# ALIHANOGLU YUSUF
# BASEGIT YUCEL
# DEMIRCI YUCEL
# GONUL YUCEL
# YAVUZ YUCEL
# CENESIZ YUCEL
# BOLEK YUKSEL
# ELA YUKSEL
# ISIK YUKSEL
# KORKMAZ YUKSEL
# KOKSAL YUKSEL
# KOSEOGLU YUKSEL
# TASKIN YUKSEL
# YILDIZ YUKSEL
# OZBAY YUKSEL
# AKAN ZAFER
# AKPINAR ZAFER
# DOGAN ZAFER
# SARI ZAFER
# UYAR ZAFER
# YILDIZ ZAFER
# YONDEN ZAFER
# CETINKAYA ZAFER
# KARADAG ZAKIR
# EKINCI ZEHRA
# GUL ZEHRA
# HASILOGLU ZEHRA
# ERSOZLU ZEHRA
# YASAR ZEHRA
# AKMAN ZEKERIYA
# DOGRUYOL ZEKERIYA
# KAYA ZEKERIYA
# KUCUKDURMAZ ZEKERIYA
# ULGER ZEKERIYA
# ARSLANOGLU ZEKI
# KANAY ZEKI
# KARACA ZEKI
# KARAKAYA ZEKI
# TUNAY ZEKI
# UYANIK ZEKI
# YILDIRIM ZEKI
# EKINCI ZELAL
# KAYAALTI ZELIHA
# GUNES ZELIHA
# ZENGINERLER ZEMINE
# SAHIN ZERRIN
# EMEKSIZ ZEYNEP
# GINIS ZEYNEP
# KIVILCIM ZEYNEP
# AKKURT ZEYNEP
# TASCI ZEYNEP
# ATILGAN ZUHAL
# TOKER ZUHAL
# ULUKOK ZUBEYDE
# BOZDAG ZUBEYIR
# KILIC ZUBEYIR
# ARIKANOGLU ZULFU
# BAYHAN ZULFU
# BOZGEYIK ZULKIF
# KAYA ZIYA
# CETINER ZIYA
# OZKECECI ZIYA
# SUVARI CAKIR
# CETINKAYA CAGLAR
# SAKALAR CAGRI
# DOGAR CETIN
# ERDOGAN CETIN
# KARACA CETIN
# SUMER CETIN
# DULGERGIL CORUH
# Authenticated (SID: F6QLgjhzLPfr9esIs5q)
# =================================
# =================================
# 90.123920390537 %
# =================================
# =================================
# YAMANER CIGDEM
# AKYOL OMER
# ALICI OMER
# AYDIN OMER
# BAYRAK OMER
# BAYRAM OMER
# BASAR OMER
# CEVIT OMER
# DEMIRTAS OMER
# EROGLU OMER
# EVIRGEN OMER
# KOKOGLU OMER
# SELAMET OMER
# VURAL OMER
# UNAL OMER
# GECICI OMER
# KARAKAS OMER
# KARATAS OMER
# KURT OMER
# MERMER OMER
# PAMUK OMER
# SAGLAM OMER
# SOYKASAP OMER
# UCAR OMER
# YAZGAN OMER
# YILDIZ OMER
# CAKIR OMER
# CALKA OMER
# OZBULUT OMER
# SAYLI OMER
# SISE OMER
# AKCI ONDER
# BARLI ONDER
# ERCAN ONDER
# KARAKUS ONDER
# YILDIZ ONDER
# OZTURK ONDER
# SAHIN ONDER
# AYNIOGLU ONER
# OZKAN OZALKAN
# GULES OZAY
# ASILKAN OZCAN
# DEVECI OZCAN
# OTKUN OZCAN
# CAKIR OZCAN
# OZEN OZCAN
# OZTURK OZCAN
# CETIN OZDEMIR
# TALO OZER
# KORKMAZ OZGEN
# ALDEMIR OZGUR
# DEMIRTAS OZGUR
# OZDAMAR OZGUR
# OZMEN OZGUR
# OZTURK OZGUR
# ILHAN OZGUR
# KAYACAN OZHAN
# BAGCI OZKAN
# GUNER OZKAN
# VURAL OZKAN
# CEGIL OZKAN
# SIMSEK OZKAN
# ABAKAY OZLEM
# ALBAYRAK OZLEM
# BILGIC OZLEM
# ISIK OZLEM
# AKKAR OZLEM
# SOLAK OZLEM
# CAKMAK OZLEM
# COSKUN OZLEM
# KARAKUS OZLEM
# OZKAN OZLEM
# SENGUL OZLEM
# CORUMLUOGLU OZSEN
# TANOR OGET
# DOGANAY ULKU
# OZAN ULKU
# YASAR ULKUHAN
# AVSAR UMMU
# TOZOGLU UMMUHAN
# DAGLI UMMUHAN
# HARPUT UMMUHAN
# YILMAZ UMMIHAN
# AVSAR UMIT
# BICER UMIT
# GUL UMIT
# KARADEMIR UMIT
# KOC UMIT
# KURSUN UMIT
# COPOGLU UMIT
# TOTUR UMIT
# YASAR UMIT
# TEKELIOGLU UMIT
# INAN UMIT
# SENER UMIT
# ADIGUZEL UNAL
# ULUCA UNAL
# YILDIRIM UNAL
# SEN UNAL
# SENEL UNAL
# =================================
# =================================
# 93.8790837401427 %
# =================================
# =================================
# OGURLU UZEYIR
# ALTUN IBRAHIM
# AKPINAR IBRAHIM
# ARSLAN IBRAHIM
# BARAN IBRAHIM
# BUDAK IBRAHIM
# BILGIN IBRAHIM
# CAN IBRAHIM
# DAMLAR IBRAHIM
# DORUK IBRAHIM
# ERBAGCI IBRAHIM
# ERCAN IBRAHIM
# ERDOGAN IBRAHIM
# EREN IBRAHIM
# KARABABA IBRAHIM
# HEPSEN IBRAHIM
# GELINCIK IBRAHIM
# GULER IBRAHIM
# GUNGOR IBRAHIM
# HABACI IBRAHIM
# OZTURK IBRAHIM
# TASDEMIR IBRAHIM
# KAYA IBRAHIM
# KELES IBRAHIM
# ONAL IBRAHIM
# KOSE IBRAHIM
# OCAK IBRAHIM
# SONMEZ IBRAHIM
# TEGIN IBRAHIM
# TOBI IBRAHIM
# TURKYILMAZ IBRAHIM
# UCAR IBRAHIM
# YAKUT IBRAHIM
# USLU IBRAHIM
# CETINER IBRAHIM
# OZBEK IBRAHIM
# KABOGLU IBRAHIM
# OZDOGRU IBRAHIM
# SEHITOGLU IBRAHIM
# BULUT ICLAL
# ARDIC IDRIS
# ARSLAN IDRIS
# CERKEZ IDRIS
# CEYLAN IDIL
# CIRAK IFFET
# ALUR IHSAN
# BAKIR IHSAN
# BAL IHSAN
# KIRIK IHSAN
# AKPINAR IHSAN
# SATIS IHSAN
# TASKIN IHSAN
# DOLAPCI IHSAN
# YUCE IHSAN
# CELIK IHSAN
# UNALDI IHSAN
# USTUN IHSAN
# SENTURK IHSAN
# SOLAK ILHAMI
# YUKSEL ILHAMI
# ASILTURK ILHAN
# KARABICAK ILHAN
# KAYA ILHAN
# PEKGOZLU ILHAN
# TAN ILHAN
# TAPAN ILHAN
# UZGEL ILHAN
# BOZKURT ILKAY
# BAYRAM ILKER
# SEN ILKER
# UGULU ILKER
# EROL ILKNUR
# ISIK ILKNUR
# ALTUNTAS IRFAN
# ACIKGOZ IRFAN
# BULU IRFAN
# DEGIRMENCI IRFAN
# ESER IRFAN
# KOCA IRFAN
# UCGUN IRFAN
# YILMAZ IRFAN
# SAKA IRFAN
# SIAP IRFAN
# PARMAKSIZ ISKENDER
# ACAR ISMAIL
# AKKAS ISMAIL
# AKSOY ISMAIL
# ALBAYRAK ISMAIL
# ARSLAN ISMAIL
# ERDEN ISMAIL
# BOYRAZ ISMAIL
# CAPAR ISMAIL
# DEMIR ISMAIL
# DOGAN ISMAIL
# GUNES ISMAIL
# EREN ISMAIL
# ERMIS ISMAIL
# ERTURK ISMAIL
# GUL ISMAIL
# UZUN ISMAIL
# =================================
# =================================
# 97.6342470897484 %
# =================================
# =================================
# UGURTAS ISMAIL
# KARA ISMAIL
# KATI ISMAIL
# KENAR ISMAIL
# KURNAZ ISMAIL
# KURT ISMAIL
# KOKSAL ISMAIL
# KULAHLI ISMAIL
# MARULCU ISMAIL
# METIN ISMAIL
# UCUN ISMAIL
# ULUCAY ISMAIL
# YILDIZ ISMAIL
# YUKSEL ISMAIL
# CAKIR ISMAIL
# UYSAL ISMAIL
# OZTURK ISMAIL
# SAHIN ISMAIL
# SENER ISMAIL
# AKCA ISMET
# BASARAN ISMET
# DURAN ISMET
# GOCER ISMET
# OZDEMIR ISMET
# OZTURK ISMET
# BABACAN ISRAFIL
# DOS IZZET
# CICEKBILEK IZZET
# GUCLU SABAN
# CETIN SABAN
# YILMAZ SAZIYE
# AKSOY SEFIKA
# EKIM SEFIKA
# KARACA SEMSETTIN
# SAHIN SEMSETTIN
# KARABUGA SEMISTAN
# TASDEMIR SENER
# SISE SENGUL
# OZDEMIR SENNUR
# OKAY SENOL
# AYKUT SEREF
# KURT SEREF
# OKUDUCU SEREF
# OLGAR SEREF
# YUKSEL SEREF
# SIMSEK SEREF
# KAHRAMAN SERIF
# AKALIN SERIFE
# ARIKAN SEVKET
# ATA SEVKET
# CIVELEK SEVKET
# TARIM SEYDA
# ARI SEYHMUS
# CIVITCI SULE
# ATALAY SULE
# ULGER SUKRAN
# ARSLAN SUKRU
# DUZGUN SUKRU
# BOYLU SUKRU
# KARAKAYA SUKRU
# TAKTAK SUKRU
# CAKMAKTEPE SUKRU
# HISAR SUKRIYE

# %%
result = author_dict.copy()

# %% [markdown]
# Deleting ',' between family and given name. Convert the co-author name into upper case.

# %%
for author in one_hundred.Author:
    for i in range(len(result[author])):
        tmp = result[author][i]['coauthor'].copy()
        for j in range(len(tmp)):
            tmp[j]=tmp[j].replace(",","").upper()
        result[author][i]['coauthor'] = tmp

# %%
result['AYDIN AYDIN'][0]['coauthor']
# Out:
# ['KUL SIBEL', 'AYDIN AYDIN', 'DINC HASAN', 'ERDURAN EROL']

# %% [markdown]
# Save the dictionary and re-load it again.

# %%
# the output file is 49.4Mb
with open('author_dict.txt', 'wb') as handle:
    pickle.dump(result, handle)

# %%
with open('author_dict.txt', 'rb') as handle:
    b = pickle.loads(handle.read())

# %%
b['AYDIN AYDIN'][0]['coauthor']
# Out:
# ['KUL SIBEL', 'AYDIN AYDIN', 'DINC HASAN', 'ERDURAN EROL']

# %%
# showing that it's the same dictionary list we want.
result == b
# Out:
# True
